# %% [markdown]
# For all files to read from specific directory

# %%
import os
import re

# %%
"""
Task description: This code is written to add tags for corresponding concepts to feed into LLMs

Read record-XX.txt:
At Vencor Hospital , BP dropped to 90 , and patient was started on NS IVF , with improvement in BP .

Read record-XX.con:
c="bp" 31:20 1:20||t="test"
c="bp dropped" 1:4 1:5||t="problem"
c="ns ivf" 1:14 1:15||t="treatment"

Output record-XX-llm.txt:
At Vencor Hospital , <problem> BP dropped </problem> to 90 , and patient was started on <treatment> NS IVF </treatment> , with improvement in <test> BP </test> .
"""

def generate_llm_file_with_sentence_matching(text_file, concept_file, output_file):
    # Read the text file
    with open(text_file, 'r') as txt_f:
        lines = txt_f.readlines()

    # Read the concept file
    with open(concept_file, 'r') as con_f:
        concepts = con_f.readlines()

    # Parse the concepts
    tag_map = {}
    for concept in concepts:
        if concept.strip():
            match = re.match(r'c="(.+?)" (\d+):(\d+) (\d+):(\d+)\|\|t="(.+?)"', concept.strip())
            if match:
                phrase, start_line, start_word, end_line, end_word, tag = match.groups()
                start_line, start_word, end_line, end_word = map(int, (start_line, start_word, end_line, end_word))
                start_line -= 1  # Convert to zero-based index
                end_line -= 1  # Convert to zero-based index

                if start_line == end_line:  # Ensure the concept is within one sentence
                    if start_line not in tag_map:
                        tag_map[start_line] = []
                    tag_map[start_line].append((start_word, end_word, phrase, tag))

    # Process the text file
    updated_lines = []
    for i, line in enumerate(lines):
        updated_line = line.strip().split()  # Tokenize the line into words
        if i in tag_map:
            # Sort concepts by start and end indices to avoid overlap issues
            concepts = sorted(tag_map[i], key=lambda x: (x[0], x[1]))
            for start_word, end_word, phrase, tag in reversed(concepts):  # Process from end to start
                # Wrap the specific phrase in its tag
                updated_line[start_word:end_word + 1] = [f"<{tag}>"] + updated_line[start_word:end_word + 1] + [f"</{tag}>"]

        # Reconstruct the updated line
        updated_lines.append(" ".join(updated_line) + "\n")

    # Write the updated text to the output file
    with open(output_file, 'w') as out_f:
        out_f.writelines(updated_lines)

# %%
def process_all_files(txt_dir, concept_dir, output_dir):
    # Ensure the output directory exists
    os.makedirs(output_dir, exist_ok=True)

    # Get list of all text files and concept files
    txt_files = {os.path.splitext(f)[0]: os.path.join(txt_dir, f) for f in os.listdir(txt_dir) if f.endswith('.txt')}
    concept_files = {os.path.splitext(f)[0]: os.path.join(concept_dir, f) for f in os.listdir(concept_dir) if f.endswith('.con')}
    
    # Process each matching pair of text and concept files
    #count = 0
    for file_id in txt_files.keys() & concept_files.keys():
        text_file = txt_files[file_id]
        concept_file = concept_files[file_id]
        output_file = os.path.join(output_dir, f"{file_id}-llm.txt")

        print(f"Processing: {text_file} and {concept_file} -> {output_file}")
        generate_llm_file_with_sentence_matching(text_file, concept_file, output_file)
        #count+=1
        #if count > 5: break

# %%
# Directory paths for train data processing
txt_dir = "../Data/raw/concept_assertion_relation_training_data/beth/txt/"
concept_dir = "../Data/raw/concept_assertion_relation_training_data/beth/concept/"
output_dir = "../Data/raw/concept_assertion_relation_training_data/beth/llm/"

# Process all files
process_all_files(txt_dir, concept_dir, output_dir)

# %%
# Directory paths for test data processing
txt_dir = "../Data/raw/test_data"
concept_dir = "../Data/raw/reference_standard_for_test_data/concepts/"
output_dir = "../Data/raw/reference_standard_for_test_data/llm/"

# Process all files
process_all_files(txt_dir, concept_dir, output_dir)
# Out:
# Processing: ../Data/raw/test_data\0094.txt and ../Data/raw/reference_standard_for_test_data/concepts/0094.con -> ../Data/raw/reference_standard_for_test_data/llm/0094-llm.txt
# Processing: ../Data/raw/test_data\0242.txt and ../Data/raw/reference_standard_for_test_data/concepts/0242.con -> ../Data/raw/reference_standard_for_test_data/llm/0242-llm.txt
# Processing: ../Data/raw/test_data\0178.txt and ../Data/raw/reference_standard_for_test_data/concepts/0178.con -> ../Data/raw/reference_standard_for_test_data/llm/0178-llm.txt
# Processing: ../Data/raw/test_data\0257.txt and ../Data/raw/reference_standard_for_test_data/concepts/0257.con -> ../Data/raw/reference_standard_for_test_data/llm/0257-llm.txt
# Processing: ../Data/raw/test_data\0245.txt and ../Data/raw/reference_standard_for_test_data/concepts/0245.con -> ../Data/raw/reference_standard_for_test_data/llm/0245-llm.txt
# Processing: ../Data/raw/test_data\0149.txt and ../Data/raw/reference_standard_for_test_data/concepts/0149.con -> ../Data/raw/reference_standard_for_test_data/llm/0149-llm.txt
# Processing: ../Data/raw/test_data\0418.txt and ../Data/raw/reference_standard_for_test_data/concepts/0418.con -> ../Data/raw/reference_standard_for_test_data/llm/0418-llm.txt
# Processing: ../Data/raw/test_data\0428.txt and ../Data/raw/reference_standard_for_test_data/concepts/0428.con -> ../Data/raw/reference_standard_for_test_data/llm/0428-llm.txt
# Processing: ../Data/raw/test_data\0002.txt and ../Data/raw/reference_standard_for_test_data/concepts/0002.con -> ../Data/raw/reference_standard_for_test_data/llm/0002-llm.txt
# Processing: ../Data/raw/test_data\0161.txt and ../Data/raw/reference_standard_for_test_data/concepts/0161.con -> ../Data/raw/reference_standard_for_test_data/llm/0161-llm.txt
# Processing: ../Data/raw/test_data\0006.txt and ../Data/raw/reference_standard_for_test_data/concepts/0006.con -> ../Data/raw/reference_standard_for_test_data/llm/0006-llm.txt
# Processing: ../Data/raw/test_data\0085.txt and ../Data/raw/reference_standard_for_test_data/concepts/0085.con -> ../Data/raw/reference_standard_for_test_data/llm/0085-llm.txt
# Processing: ../Data/raw/test_data\0078.txt and ../Data/raw/reference_standard_for_test_data/concepts/0078.con -> ../Data/raw/reference_standard_for_test_data/llm/0078-llm.txt
# Processing: ../Data/raw/test_data\0330.txt and ../Data/raw/reference_standard_for_test_data/concepts/0330.con -> ../Data/raw/reference_standard_for_test_data/llm/0330-llm.txt
# Processing: ../Data/raw/test_data\0462.txt and ../Data/raw/reference_standard_for_test_data/concepts/0462.con -> ../Data/raw/reference_standard_for_test_data/llm/0462-llm.txt
# Processing: ../Data/raw/test_data\0082.txt and ../Data/raw/reference_standard_for_test_data/concepts/0082.con -> ../Data/raw/reference_standard_for_test_data/llm/0082-llm.txt
# Processing: ../Data/raw/test_data\0302.txt and ../Data/raw/reference_standard_for_test_data/concepts/0302.con -> ../Data/raw/reference_standard_for_test_data/llm/0302-llm.txt
# Processing: ../Data/raw/test_data\0405.txt and ../Data/raw/reference_standard_for_test_data/concepts/0405.con -> ../Data/raw/reference_standard_for_test_data/llm/0405-llm.txt
# Processing: ../Data/raw/test_data\0476.txt and ../Data/raw/reference_standard_for_test_data/concepts/0476.con -> ../Data/raw/reference_standard_for_test_data/llm/0476-llm.txt
# Processing: ../Data/raw/test_data\0025.txt and ../Data/raw/reference_standard_for_test_data/concepts/0025.con -> ../Data/raw/reference_standard_for_test_data/llm/0025-llm.txt
# Processing: ../Data/raw/test_data\0126.txt and ../Data/raw/reference_standard_for_test_data/concepts/0126.con -> ../Data/raw/reference_standard_for_test_data/llm/0126-llm.txt
# Processing: ../Data/raw/test_data\0154.txt and ../Data/raw/reference_standard_for_test_data/concepts/0154.con -> ../Data/raw/reference_standard_for_test_data/llm/0154-llm.txt
# Processing: ../Data/raw/test_data\0297.txt and ../Data/raw/reference_standard_for_test_data/concepts/0297.con -> ../Data/raw/reference_standard_for_test_data/llm/0297-llm.txt
# Processing: ../Data/raw/test_data\0185.txt and ../Data/raw/reference_standard_for_test_data/concepts/0185.con -> ../Data/raw/reference_standard_for_test_data/llm/0185-llm.txt
# Processing: ../Data/raw/test_data\0301.txt and ../Data/raw/reference_standard_for_test_data/concepts/0301.con -> ../Data/raw/reference_standard_for_test_data/llm/0301-llm.txt
# Processing: ../Data/raw/test_data\0258.txt and ../Data/raw/reference_standard_for_test_data/concepts/0258.con -> ../Data/raw/reference_standard_for_test_data/llm/0258-llm.txt
# Processing: ../Data/raw/test_data\0424.txt and ../Data/raw/reference_standard_for_test_data/concepts/0424.con -> ../Data/raw/reference_standard_for_test_data/llm/0424-llm.txt
# Processing: ../Data/raw/test_data\0129.txt and ../Data/raw/reference_standard_for_test_data/concepts/0129.con -> ../Data/raw/reference_standard_for_test_data/llm/0129-llm.txt
# Processing: ../Data/raw/test_data\0442.txt and ../Data/raw/reference_standard_for_test_data/concepts/0442.con -> ../Data/raw/reference_standard_for_test_data/llm/0442-llm.txt
# Processing: ../Data/raw/test_data\0054.txt and ../Data/raw/reference_standard_for_test_data/concepts/0054.con -> ../Data/raw/reference_standard_for_test_data/llm/0054-llm.txt
# Processing: ../Data/raw/test_data\0105.txt and ../Data/raw/reference_standard_for_test_data/concepts/0105.con -> ../Data/raw/reference_standard_for_test_data/llm/0105-llm.txt
# Processing: ../Data/raw/test_data\0466.txt and ../Data/raw/reference_standard_for_test_data/concepts/0466.con -> ../Data/raw/reference_standard_for_test_data/llm/0466-llm.txt
# Processing: ../Data/raw/test_data\0221.txt and ../Data/raw/reference_standard_for_test_data/concepts/0221.con -> ../Data/raw/reference_standard_for_test_data/llm/0221-llm.txt
# Processing: ../Data/raw/test_data\0150.txt and ../Data/raw/reference_standard_for_test_data/concepts/0150.con -> ../Data/raw/reference_standard_for_test_data/llm/0150-llm.txt
# Processing: ../Data/raw/test_data\0166.txt and ../Data/raw/reference_standard_for_test_data/concepts/0166.con -> ../Data/raw/reference_standard_for_test_data/llm/0166-llm.txt
# Processing: ../Data/raw/test_data\0229.txt and ../Data/raw/reference_standard_for_test_data/concepts/0229.con -> ../Data/raw/reference_standard_for_test_data/llm/0229-llm.txt
# Processing: ../Data/raw/test_data\0162.txt and ../Data/raw/reference_standard_for_test_data/concepts/0162.con -> ../Data/raw/reference_standard_for_test_data/llm/0162-llm.txt
# Processing: ../Data/raw/test_data\0471.txt and ../Data/raw/reference_standard_for_test_data/concepts/0471.con -> ../Data/raw/reference_standard_for_test_data/llm/0471-llm.txt
# Processing: ../Data/raw/test_data\0233.txt and ../Data/raw/reference_standard_for_test_data/concepts/0233.con -> ../Data/raw/reference_standard_for_test_data/llm/0233-llm.txt
# Processing: ../Data/raw/test_data\0345.txt and ../Data/raw/reference_standard_for_test_data/concepts/0345.con -> ../Data/raw/reference_standard_for_test_data/llm/0345-llm.txt
# Processing: ../Data/raw/test_data\0165.txt and ../Data/raw/reference_standard_for_test_data/concepts/0165.con -> ../Data/raw/reference_standard_for_test_data/llm/0165-llm.txt
# Processing: ../Data/raw/test_data\0401.txt and ../Data/raw/reference_standard_for_test_data/concepts/0401.con -> ../Data/raw/reference_standard_for_test_data/llm/0401-llm.txt
# Processing: ../Data/raw/test_data\0074.txt and ../Data/raw/reference_standard_for_test_data/concepts/0074.con -> ../Data/raw/reference_standard_for_test_data/llm/0074-llm.txt
# Processing: ../Data/raw/test_data\0046.txt and ../Data/raw/reference_standard_for_test_data/concepts/0046.con -> ../Data/raw/reference_standard_for_test_data/llm/0046-llm.txt
# Processing: ../Data/raw/test_data\0266.txt and ../Data/raw/reference_standard_for_test_data/concepts/0266.con -> ../Data/raw/reference_standard_for_test_data/llm/0266-llm.txt
# Processing: ../Data/raw/test_data\0443.txt and ../Data/raw/reference_standard_for_test_data/concepts/0443.con -> ../Data/raw/reference_standard_for_test_data/llm/0443-llm.txt
# Processing: ../Data/raw/test_data\0109.txt and ../Data/raw/reference_standard_for_test_data/concepts/0109.con -> ../Data/raw/reference_standard_for_test_data/llm/0109-llm.txt
# Processing: ../Data/raw/test_data\0026.txt and ../Data/raw/reference_standard_for_test_data/concepts/0026.con -> ../Data/raw/reference_standard_for_test_data/llm/0026-llm.txt
# Processing: ../Data/raw/test_data\0034.txt and ../Data/raw/reference_standard_for_test_data/concepts/0034.con -> ../Data/raw/reference_standard_for_test_data/llm/0034-llm.txt
# Processing: ../Data/raw/test_data\0190.txt and ../Data/raw/reference_standard_for_test_data/concepts/0190.con -> ../Data/raw/reference_standard_for_test_data/llm/0190-llm.txt
# Processing: ../Data/raw/test_data\0090.txt and ../Data/raw/reference_standard_for_test_data/concepts/0090.con -> ../Data/raw/reference_standard_for_test_data/llm/0090-llm.txt
# Processing: ../Data/raw/test_data\0142.txt and ../Data/raw/reference_standard_for_test_data/concepts/0142.con -> ../Data/raw/reference_standard_for_test_data/llm/0142-llm.txt
# Processing: ../Data/raw/test_data\0274.txt and ../Data/raw/reference_standard_for_test_data/concepts/0274.con -> ../Data/raw/reference_standard_for_test_data/llm/0274-llm.txt
# Processing: ../Data/raw/test_data\0374.txt and ../Data/raw/reference_standard_for_test_data/concepts/0374.con -> ../Data/raw/reference_standard_for_test_data/llm/0374-llm.txt
# Processing: ../Data/raw/test_data\0464.txt and ../Data/raw/reference_standard_for_test_data/concepts/0464.con -> ../Data/raw/reference_standard_for_test_data/llm/0464-llm.txt
# Processing: ../Data/raw/test_data\0434.txt and ../Data/raw/reference_standard_for_test_data/concepts/0434.con -> ../Data/raw/reference_standard_for_test_data/llm/0434-llm.txt
# Processing: ../Data/raw/test_data\0410.txt and ../Data/raw/reference_standard_for_test_data/concepts/0410.con -> ../Data/raw/reference_standard_for_test_data/llm/0410-llm.txt
# Processing: ../Data/raw/test_data\0110.txt and ../Data/raw/reference_standard_for_test_data/concepts/0110.con -> ../Data/raw/reference_standard_for_test_data/llm/0110-llm.txt
# Processing: ../Data/raw/test_data\0226.txt and ../Data/raw/reference_standard_for_test_data/concepts/0226.con -> ../Data/raw/reference_standard_for_test_data/llm/0226-llm.txt
# Processing: ../Data/raw/test_data\0053.txt and ../Data/raw/reference_standard_for_test_data/concepts/0053.con -> ../Data/raw/reference_standard_for_test_data/llm/0053-llm.txt
# Processing: ../Data/raw/test_data\0246.txt and ../Data/raw/reference_standard_for_test_data/concepts/0246.con -> ../Data/raw/reference_standard_for_test_data/llm/0246-llm.txt
# Processing: ../Data/raw/test_data\0197.txt and ../Data/raw/reference_standard_for_test_data/concepts/0197.con -> ../Data/raw/reference_standard_for_test_data/llm/0197-llm.txt
# Processing: ../Data/raw/test_data\0306.txt and ../Data/raw/reference_standard_for_test_data/concepts/0306.con -> ../Data/raw/reference_standard_for_test_data/llm/0306-llm.txt
# Processing: ../Data/raw/test_data\0473.txt and ../Data/raw/reference_standard_for_test_data/concepts/0473.con -> ../Data/raw/reference_standard_for_test_data/llm/0473-llm.txt
# Processing: ../Data/raw/test_data\0045.txt and ../Data/raw/reference_standard_for_test_data/concepts/0045.con -> ../Data/raw/reference_standard_for_test_data/llm/0045-llm.txt
# Processing: ../Data/raw/test_data\0118.txt and ../Data/raw/reference_standard_for_test_data/concepts/0118.con -> ../Data/raw/reference_standard_for_test_data/llm/0118-llm.txt
# Processing: ../Data/raw/test_data\0089.txt and ../Data/raw/reference_standard_for_test_data/concepts/0089.con -> ../Data/raw/reference_standard_for_test_data/llm/0089-llm.txt
# Processing: ../Data/raw/test_data\0213.txt and ../Data/raw/reference_standard_for_test_data/concepts/0213.con -> ../Data/raw/reference_standard_for_test_data/llm/0213-llm.txt
# Processing: ../Data/raw/test_data\0241.txt and ../Data/raw/reference_standard_for_test_data/concepts/0241.con -> ../Data/raw/reference_standard_for_test_data/llm/0241-llm.txt
# Processing: ../Data/raw/test_data\0433.txt and ../Data/raw/reference_standard_for_test_data/concepts/0433.con -> ../Data/raw/reference_standard_for_test_data/llm/0433-llm.txt
# Processing: ../Data/raw/test_data\0206.txt and ../Data/raw/reference_standard_for_test_data/concepts/0206.con -> ../Data/raw/reference_standard_for_test_data/llm/0206-llm.txt
# Processing: ../Data/raw/test_data\0278.txt and ../Data/raw/reference_standard_for_test_data/concepts/0278.con -> ../Data/raw/reference_standard_for_test_data/llm/0278-llm.txt
# Processing: ../Data/raw/test_data\0009.txt and ../Data/raw/reference_standard_for_test_data/concepts/0009.con -> ../Data/raw/reference_standard_for_test_data/llm/0009-llm.txt
# Processing: ../Data/raw/test_data\0378.txt and ../Data/raw/reference_standard_for_test_data/concepts/0378.con -> ../Data/raw/reference_standard_for_test_data/llm/0378-llm.txt
# Processing: ../Data/raw/test_data\0097.txt and ../Data/raw/reference_standard_for_test_data/concepts/0097.con -> ../Data/raw/reference_standard_for_test_data/llm/0097-llm.txt
# Processing: ../Data/raw/test_data\0177.txt and ../Data/raw/reference_standard_for_test_data/concepts/0177.con -> ../Data/raw/reference_standard_for_test_data/llm/0177-llm.txt
# Processing: ../Data/raw/test_data\0134.txt and ../Data/raw/reference_standard_for_test_data/concepts/0134.con -> ../Data/raw/reference_standard_for_test_data/llm/0134-llm.txt
# Processing: ../Data/raw/test_data\0030.txt and ../Data/raw/reference_standard_for_test_data/concepts/0030.con -> ../Data/raw/reference_standard_for_test_data/llm/0030-llm.txt
# Processing: ../Data/raw/test_data\0133.txt and ../Data/raw/reference_standard_for_test_data/concepts/0133.con -> ../Data/raw/reference_standard_for_test_data/llm/0133-llm.txt
# Processing: ../Data/raw/test_data\0214.txt and ../Data/raw/reference_standard_for_test_data/concepts/0214.con -> ../Data/raw/reference_standard_for_test_data/llm/0214-llm.txt
# Processing: ../Data/raw/test_data\0277.txt and ../Data/raw/reference_standard_for_test_data/concepts/0277.con -> ../Data/raw/reference_standard_for_test_data/llm/0277-llm.txt
# Processing: ../Data/raw/test_data\0329.txt and ../Data/raw/reference_standard_for_test_data/concepts/0329.con -> ../Data/raw/reference_standard_for_test_data/llm/0329-llm.txt
# Processing: ../Data/raw/test_data\0106.txt and ../Data/raw/reference_standard_for_test_data/concepts/0106.con -> ../Data/raw/reference_standard_for_test_data/llm/0106-llm.txt
# Processing: ../Data/raw/test_data\0326.txt and ../Data/raw/reference_standard_for_test_data/concepts/0326.con -> ../Data/raw/reference_standard_for_test_data/llm/0326-llm.txt
# Processing: ../Data/raw/test_data\0077.txt and ../Data/raw/reference_standard_for_test_data/concepts/0077.con -> ../Data/raw/reference_standard_for_test_data/llm/0077-llm.txt
# Processing: ../Data/raw/test_data\0093.txt and ../Data/raw/reference_standard_for_test_data/concepts/0093.con -> ../Data/raw/reference_standard_for_test_data/llm/0093-llm.txt
# Processing: ../Data/raw/test_data\0439.txt and ../Data/raw/reference_standard_for_test_data/concepts/0439.con -> ../Data/raw/reference_standard_for_test_data/llm/0439-llm.txt
# Processing: ../Data/raw/test_data\0073.txt and ../Data/raw/reference_standard_for_test_data/concepts/0073.con -> ../Data/raw/reference_standard_for_test_data/llm/0073-llm.txt
# Processing: ../Data/raw/test_data\0409.txt and ../Data/raw/reference_standard_for_test_data/concepts/0409.con -> ../Data/raw/reference_standard_for_test_data/llm/0409-llm.txt
# Processing: ../Data/raw/test_data\0393.txt and ../Data/raw/reference_standard_for_test_data/concepts/0393.con -> ../Data/raw/reference_standard_for_test_data/llm/0393-llm.txt
# Processing: ../Data/raw/test_data\0346.txt and ../Data/raw/reference_standard_for_test_data/concepts/0346.con -> ../Data/raw/reference_standard_for_test_data/llm/0346-llm.txt
# Processing: ../Data/raw/test_data\0314.txt and ../Data/raw/reference_standard_for_test_data/concepts/0314.con -> ../Data/raw/reference_standard_for_test_data/llm/0314-llm.txt
# Processing: ../Data/raw/test_data\0061.txt and ../Data/raw/reference_standard_for_test_data/concepts/0061.con -> ../Data/raw/reference_standard_for_test_data/llm/0061-llm.txt
# Processing: ../Data/raw/test_data\0313.txt and ../Data/raw/reference_standard_for_test_data/concepts/0313.con -> ../Data/raw/reference_standard_for_test_data/llm/0313-llm.txt
# Processing: ../Data/raw/test_data\0022.txt and ../Data/raw/reference_standard_for_test_data/concepts/0022.con -> ../Data/raw/reference_standard_for_test_data/llm/0022-llm.txt
# Processing: ../Data/raw/test_data\0169.txt and ../Data/raw/reference_standard_for_test_data/concepts/0169.con -> ../Data/raw/reference_standard_for_test_data/llm/0169-llm.txt
# Processing: ../Data/raw/test_data\0389.txt and ../Data/raw/reference_standard_for_test_data/concepts/0389.con -> ../Data/raw/reference_standard_for_test_data/llm/0389-llm.txt
# Processing: ../Data/raw/test_data\0065.txt and ../Data/raw/reference_standard_for_test_data/concepts/0065.con -> ../Data/raw/reference_standard_for_test_data/llm/0065-llm.txt
# Processing: ../Data/raw/test_data\0146.txt and ../Data/raw/reference_standard_for_test_data/concepts/0146.con -> ../Data/raw/reference_standard_for_test_data/llm/0146-llm.txt
# Processing: ../Data/raw/test_data\0234.txt and ../Data/raw/reference_standard_for_test_data/concepts/0234.con -> ../Data/raw/reference_standard_for_test_data/llm/0234-llm.txt
# Processing: ../Data/raw/test_data\0189.txt and ../Data/raw/reference_standard_for_test_data/concepts/0189.con -> ../Data/raw/reference_standard_for_test_data/llm/0189-llm.txt
# Processing: ../Data/raw/test_data\0281.txt and ../Data/raw/reference_standard_for_test_data/concepts/0281.con -> ../Data/raw/reference_standard_for_test_data/llm/0281-llm.txt
# Processing: ../Data/raw/test_data\0253.txt and ../Data/raw/reference_standard_for_test_data/concepts/0253.con -> ../Data/raw/reference_standard_for_test_data/llm/0253-llm.txt
# Processing: ../Data/raw/test_data\0050.txt and ../Data/raw/reference_standard_for_test_data/concepts/0050.con -> ../Data/raw/reference_standard_for_test_data/llm/0050-llm.txt
# Processing: ../Data/raw/test_data\0421.txt and ../Data/raw/reference_standard_for_test_data/concepts/0421.con -> ../Data/raw/reference_standard_for_test_data/llm/0421-llm.txt
# Processing: ../Data/raw/test_data\0049.txt and ../Data/raw/reference_standard_for_test_data/concepts/0049.con -> ../Data/raw/reference_standard_for_test_data/llm/0049-llm.txt
# Processing: ../Data/raw/test_data\0394.txt and ../Data/raw/reference_standard_for_test_data/concepts/0394.con -> ../Data/raw/reference_standard_for_test_data/llm/0394-llm.txt
# Processing: ../Data/raw/test_data\0122.txt and ../Data/raw/reference_standard_for_test_data/concepts/0122.con -> ../Data/raw/reference_standard_for_test_data/llm/0122-llm.txt
# Processing: ../Data/raw/test_data\0041.txt and ../Data/raw/reference_standard_for_test_data/concepts/0041.con -> ../Data/raw/reference_standard_for_test_data/llm/0041-llm.txt
# Processing: ../Data/raw/test_data\0102.txt and ../Data/raw/reference_standard_for_test_data/concepts/0102.con -> ../Data/raw/reference_standard_for_test_data/llm/0102-llm.txt
# Processing: ../Data/raw/test_data\0070.txt and ../Data/raw/reference_standard_for_test_data/concepts/0070.con -> ../Data/raw/reference_standard_for_test_data/llm/0070-llm.txt
# Processing: ../Data/raw/test_data\0001.txt and ../Data/raw/reference_standard_for_test_data/concepts/0001.con -> ../Data/raw/reference_standard_for_test_data/llm/0001-llm.txt
# Processing: ../Data/raw/test_data\0460.txt and ../Data/raw/reference_standard_for_test_data/concepts/0460.con -> ../Data/raw/reference_standard_for_test_data/llm/0460-llm.txt
# Processing: ../Data/raw/test_data\0033.txt and ../Data/raw/reference_standard_for_test_data/concepts/0033.con -> ../Data/raw/reference_standard_for_test_data/llm/0033-llm.txt
# Processing: ../Data/raw/test_data\0416.txt and ../Data/raw/reference_standard_for_test_data/concepts/0416.con -> ../Data/raw/reference_standard_for_test_data/llm/0416-llm.txt
# Processing: ../Data/raw/test_data\0066.txt and ../Data/raw/reference_standard_for_test_data/concepts/0066.con -> ../Data/raw/reference_standard_for_test_data/llm/0066-llm.txt
# Processing: ../Data/raw/test_data\0202.txt and ../Data/raw/reference_standard_for_test_data/concepts/0202.con -> ../Data/raw/reference_standard_for_test_data/llm/0202-llm.txt
# Processing: ../Data/raw/test_data\0250.txt and ../Data/raw/reference_standard_for_test_data/concepts/0250.con -> ../Data/raw/reference_standard_for_test_data/llm/0250-llm.txt
# Processing: ../Data/raw/test_data\0373.txt and ../Data/raw/reference_standard_for_test_data/concepts/0373.con -> ../Data/raw/reference_standard_for_test_data/llm/0373-llm.txt
# Processing: ../Data/raw/test_data\0386.txt and ../Data/raw/reference_standard_for_test_data/concepts/0386.con -> ../Data/raw/reference_standard_for_test_data/llm/0386-llm.txt
# Processing: ../Data/raw/test_data\0461.txt and ../Data/raw/reference_standard_for_test_data/concepts/0461.con -> ../Data/raw/reference_standard_for_test_data/llm/0461-llm.txt
# Processing: ../Data/raw/test_data\0467.txt and ../Data/raw/reference_standard_for_test_data/concepts/0467.con -> ../Data/raw/reference_standard_for_test_data/llm/0467-llm.txt
# Processing: ../Data/raw/test_data\0294.txt and ../Data/raw/reference_standard_for_test_data/concepts/0294.con -> ../Data/raw/reference_standard_for_test_data/llm/0294-llm.txt
# Processing: ../Data/raw/test_data\0318.txt and ../Data/raw/reference_standard_for_test_data/concepts/0318.con -> ../Data/raw/reference_standard_for_test_data/llm/0318-llm.txt
# Processing: ../Data/raw/test_data\0210.txt and ../Data/raw/reference_standard_for_test_data/concepts/0210.con -> ../Data/raw/reference_standard_for_test_data/llm/0210-llm.txt
# Processing: ../Data/raw/test_data\0362.txt and ../Data/raw/reference_standard_for_test_data/concepts/0362.con -> ../Data/raw/reference_standard_for_test_data/llm/0362-llm.txt
# Processing: ../Data/raw/test_data\0381.txt and ../Data/raw/reference_standard_for_test_data/concepts/0381.con -> ../Data/raw/reference_standard_for_test_data/llm/0381-llm.txt
# Processing: ../Data/raw/test_data\0158.txt and ../Data/raw/reference_standard_for_test_data/concepts/0158.con -> ../Data/raw/reference_standard_for_test_data/llm/0158-llm.txt
# Processing: ../Data/raw/test_data\0449.txt and ../Data/raw/reference_standard_for_test_data/concepts/0449.con -> ../Data/raw/reference_standard_for_test_data/llm/0449-llm.txt
# Processing: ../Data/raw/test_data\0058.txt and ../Data/raw/reference_standard_for_test_data/concepts/0058.con -> ../Data/raw/reference_standard_for_test_data/llm/0058-llm.txt
# Processing: ../Data/raw/test_data\0325.txt and ../Data/raw/reference_standard_for_test_data/concepts/0325.con -> ../Data/raw/reference_standard_for_test_data/llm/0325-llm.txt
# Processing: ../Data/raw/test_data\0113.txt and ../Data/raw/reference_standard_for_test_data/concepts/0113.con -> ../Data/raw/reference_standard_for_test_data/llm/0113-llm.txt
# Processing: ../Data/raw/test_data\0081.txt and ../Data/raw/reference_standard_for_test_data/concepts/0081.con -> ../Data/raw/reference_standard_for_test_data/llm/0081-llm.txt
# Processing: ../Data/raw/test_data\0269.txt and ../Data/raw/reference_standard_for_test_data/concepts/0269.con -> ../Data/raw/reference_standard_for_test_data/llm/0269-llm.txt
# Processing: ../Data/raw/test_data\0037.txt and ../Data/raw/reference_standard_for_test_data/concepts/0037.con -> ../Data/raw/reference_standard_for_test_data/llm/0037-llm.txt
# Processing: ../Data/raw/test_data\0334.txt and ../Data/raw/reference_standard_for_test_data/concepts/0334.con -> ../Data/raw/reference_standard_for_test_data/llm/0334-llm.txt
# Processing: ../Data/raw/test_data\0451.txt and ../Data/raw/reference_standard_for_test_data/concepts/0451.con -> ../Data/raw/reference_standard_for_test_data/llm/0451-llm.txt
# Processing: ../Data/raw/test_data\0361.txt and ../Data/raw/reference_standard_for_test_data/concepts/0361.con -> ../Data/raw/reference_standard_for_test_data/llm/0361-llm.txt
# Processing: ../Data/raw/test_data\0397.txt and ../Data/raw/reference_standard_for_test_data/concepts/0397.con -> ../Data/raw/reference_standard_for_test_data/llm/0397-llm.txt
# Processing: ../Data/raw/test_data\0437.txt and ../Data/raw/reference_standard_for_test_data/concepts/0437.con -> ../Data/raw/reference_standard_for_test_data/llm/0437-llm.txt
# Processing: ../Data/raw/test_data\0293.txt and ../Data/raw/reference_standard_for_test_data/concepts/0293.con -> ../Data/raw/reference_standard_for_test_data/llm/0293-llm.txt
# Processing: ../Data/raw/test_data\0454.txt and ../Data/raw/reference_standard_for_test_data/concepts/0454.con -> ../Data/raw/reference_standard_for_test_data/llm/0454-llm.txt
# Processing: ../Data/raw/test_data\0057.txt and ../Data/raw/reference_standard_for_test_data/concepts/0057.con -> ../Data/raw/reference_standard_for_test_data/llm/0057-llm.txt
# Processing: ../Data/raw/test_data\0198.txt and ../Data/raw/reference_standard_for_test_data/concepts/0198.con -> ../Data/raw/reference_standard_for_test_data/llm/0198-llm.txt
# Processing: ../Data/raw/test_data\0341.txt and ../Data/raw/reference_standard_for_test_data/concepts/0341.con -> ../Data/raw/reference_standard_for_test_data/llm/0341-llm.txt
# Processing: ../Data/raw/test_data\0455.txt and ../Data/raw/reference_standard_for_test_data/concepts/0455.con -> ../Data/raw/reference_standard_for_test_data/llm/0455-llm.txt
# Processing: ../Data/raw/test_data\0010.txt and ../Data/raw/reference_standard_for_test_data/concepts/0010.con -> ../Data/raw/reference_standard_for_test_data/llm/0010-llm.txt
# Processing: ../Data/raw/test_data\0270.txt and ../Data/raw/reference_standard_for_test_data/concepts/0270.con -> ../Data/raw/reference_standard_for_test_data/llm/0270-llm.txt
# Processing: ../Data/raw/test_data\0354.txt and ../Data/raw/reference_standard_for_test_data/concepts/0354.con -> ../Data/raw/reference_standard_for_test_data/llm/0354-llm.txt
# Processing: ../Data/raw/test_data\0201.txt and ../Data/raw/reference_standard_for_test_data/concepts/0201.con -> ../Data/raw/reference_standard_for_test_data/llm/0201-llm.txt
# Processing: ../Data/raw/test_data\0465.txt and ../Data/raw/reference_standard_for_test_data/concepts/0465.con -> ../Data/raw/reference_standard_for_test_data/llm/0465-llm.txt
# Processing: ../Data/raw/test_data\0370.txt and ../Data/raw/reference_standard_for_test_data/concepts/0370.con -> ../Data/raw/reference_standard_for_test_data/llm/0370-llm.txt
# Processing: ../Data/raw/test_data\0358.txt and ../Data/raw/reference_standard_for_test_data/concepts/0358.con -> ../Data/raw/reference_standard_for_test_data/llm/0358-llm.txt
# Processing: ../Data/raw/test_data\0385.txt and ../Data/raw/reference_standard_for_test_data/concepts/0385.con -> ../Data/raw/reference_standard_for_test_data/llm/0385-llm.txt
# Processing: ../Data/raw/test_data\0218.txt and ../Data/raw/reference_standard_for_test_data/concepts/0218.con -> ../Data/raw/reference_standard_for_test_data/llm/0218-llm.txt
# Processing: ../Data/raw/test_data\0406.txt and ../Data/raw/reference_standard_for_test_data/concepts/0406.con -> ../Data/raw/reference_standard_for_test_data/llm/0406-llm.txt
# Processing: ../Data/raw/test_data\0013.txt and ../Data/raw/reference_standard_for_test_data/concepts/0013.con -> ../Data/raw/reference_standard_for_test_data/llm/0013-llm.txt
# Processing: ../Data/raw/test_data\0390.txt and ../Data/raw/reference_standard_for_test_data/concepts/0390.con -> ../Data/raw/reference_standard_for_test_data/llm/0390-llm.txt
# Processing: ../Data/raw/test_data\0286.txt and ../Data/raw/reference_standard_for_test_data/concepts/0286.con -> ../Data/raw/reference_standard_for_test_data/llm/0286-llm.txt
# Processing: ../Data/raw/test_data\0310.txt and ../Data/raw/reference_standard_for_test_data/concepts/0310.con -> ../Data/raw/reference_standard_for_test_data/llm/0310-llm.txt
# Processing: ../Data/raw/test_data\0413.txt and ../Data/raw/reference_standard_for_test_data/concepts/0413.con -> ../Data/raw/reference_standard_for_test_data/llm/0413-llm.txt
# Processing: ../Data/raw/test_data\0209.txt and ../Data/raw/reference_standard_for_test_data/concepts/0209.con -> ../Data/raw/reference_standard_for_test_data/llm/0209-llm.txt
# Processing: ../Data/raw/test_data\0321.txt and ../Data/raw/reference_standard_for_test_data/concepts/0321.con -> ../Data/raw/reference_standard_for_test_data/llm/0321-llm.txt
# Processing: ../Data/raw/test_data\0431.txt and ../Data/raw/reference_standard_for_test_data/concepts/0431.con -> ../Data/raw/reference_standard_for_test_data/llm/0431-llm.txt
# Processing: ../Data/raw/test_data\0130.txt and ../Data/raw/reference_standard_for_test_data/concepts/0130.con -> ../Data/raw/reference_standard_for_test_data/llm/0130-llm.txt
# Processing: ../Data/raw/test_data\0225.txt and ../Data/raw/reference_standard_for_test_data/concepts/0225.con -> ../Data/raw/reference_standard_for_test_data/llm/0225-llm.txt
# Processing: ../Data/raw/test_data\0174.txt and ../Data/raw/reference_standard_for_test_data/concepts/0174.con -> ../Data/raw/reference_standard_for_test_data/llm/0174-llm.txt
# Processing: ../Data/raw/test_data\0309.txt and ../Data/raw/reference_standard_for_test_data/concepts/0309.con -> ../Data/raw/reference_standard_for_test_data/llm/0309-llm.txt
# Processing: ../Data/raw/test_data\0377.txt and ../Data/raw/reference_standard_for_test_data/concepts/0377.con -> ../Data/raw/reference_standard_for_test_data/llm/0377-llm.txt
# Processing: ../Data/raw/test_data\0017.txt and ../Data/raw/reference_standard_for_test_data/concepts/0017.con -> ../Data/raw/reference_standard_for_test_data/llm/0017-llm.txt
# Processing: ../Data/raw/test_data\0412.txt and ../Data/raw/reference_standard_for_test_data/concepts/0412.con -> ../Data/raw/reference_standard_for_test_data/llm/0412-llm.txt
# Processing: ../Data/raw/test_data\0005.txt and ../Data/raw/reference_standard_for_test_data/concepts/0005.con -> ../Data/raw/reference_standard_for_test_data/llm/0005-llm.txt
# Processing: ../Data/raw/test_data\0038.txt and ../Data/raw/reference_standard_for_test_data/concepts/0038.con -> ../Data/raw/reference_standard_for_test_data/llm/0038-llm.txt
# Processing: ../Data/raw/test_data\0086.txt and ../Data/raw/reference_standard_for_test_data/concepts/0086.con -> ../Data/raw/reference_standard_for_test_data/llm/0086-llm.txt
# Processing: ../Data/raw/test_data\0402.txt and ../Data/raw/reference_standard_for_test_data/concepts/0402.con -> ../Data/raw/reference_standard_for_test_data/llm/0402-llm.txt
# Processing: ../Data/raw/test_data\0415.txt and ../Data/raw/reference_standard_for_test_data/concepts/0415.con -> ../Data/raw/reference_standard_for_test_data/llm/0415-llm.txt
# Processing: ../Data/raw/test_data\0436.txt and ../Data/raw/reference_standard_for_test_data/concepts/0436.con -> ../Data/raw/reference_standard_for_test_data/llm/0436-llm.txt
# Processing: ../Data/raw/test_data\0470.txt and ../Data/raw/reference_standard_for_test_data/concepts/0470.con -> ../Data/raw/reference_standard_for_test_data/llm/0470-llm.txt
# Processing: ../Data/raw/test_data\0452.txt and ../Data/raw/reference_standard_for_test_data/concepts/0452.con -> ../Data/raw/reference_standard_for_test_data/llm/0452-llm.txt
# Processing: ../Data/raw/test_data\0472.txt and ../Data/raw/reference_standard_for_test_data/concepts/0472.con -> ../Data/raw/reference_standard_for_test_data/llm/0472-llm.txt
# Processing: ../Data/raw/test_data\0121.txt and ../Data/raw/reference_standard_for_test_data/concepts/0121.con -> ../Data/raw/reference_standard_for_test_data/llm/0121-llm.txt
# Processing: ../Data/raw/test_data\0173.txt and ../Data/raw/reference_standard_for_test_data/concepts/0173.con -> ../Data/raw/reference_standard_for_test_data/llm/0173-llm.txt
# Processing: ../Data/raw/test_data\0350.txt and ../Data/raw/reference_standard_for_test_data/concepts/0350.con -> ../Data/raw/reference_standard_for_test_data/llm/0350-llm.txt
# Processing: ../Data/raw/test_data\0238.txt and ../Data/raw/reference_standard_for_test_data/concepts/0238.con -> ../Data/raw/reference_standard_for_test_data/llm/0238-llm.txt
# Processing: ../Data/raw/test_data\0249.txt and ../Data/raw/reference_standard_for_test_data/concepts/0249.con -> ../Data/raw/reference_standard_for_test_data/llm/0249-llm.txt
# Processing: ../Data/raw/test_data\0222.txt and ../Data/raw/reference_standard_for_test_data/concepts/0222.con -> ../Data/raw/reference_standard_for_test_data/llm/0222-llm.txt
# Processing: ../Data/raw/test_data\0448.txt and ../Data/raw/reference_standard_for_test_data/concepts/0448.con -> ../Data/raw/reference_standard_for_test_data/llm/0448-llm.txt
# Processing: ../Data/raw/test_data\0463.txt and ../Data/raw/reference_standard_for_test_data/concepts/0463.con -> ../Data/raw/reference_standard_for_test_data/llm/0463-llm.txt
# Processing: ../Data/raw/test_data\0337.txt and ../Data/raw/reference_standard_for_test_data/concepts/0337.con -> ../Data/raw/reference_standard_for_test_data/llm/0337-llm.txt
# Processing: ../Data/raw/test_data\0125.txt and ../Data/raw/reference_standard_for_test_data/concepts/0125.con -> ../Data/raw/reference_standard_for_test_data/llm/0125-llm.txt
# Processing: ../Data/raw/test_data\0338.txt and ../Data/raw/reference_standard_for_test_data/concepts/0338.con -> ../Data/raw/reference_standard_for_test_data/llm/0338-llm.txt
# Processing: ../Data/raw/test_data\0117.txt and ../Data/raw/reference_standard_for_test_data/concepts/0117.con -> ../Data/raw/reference_standard_for_test_data/llm/0117-llm.txt
# Processing: ../Data/raw/test_data\0182.txt and ../Data/raw/reference_standard_for_test_data/concepts/0182.con -> ../Data/raw/reference_standard_for_test_data/llm/0182-llm.txt
# Processing: ../Data/raw/test_data\0457.txt and ../Data/raw/reference_standard_for_test_data/concepts/0457.con -> ../Data/raw/reference_standard_for_test_data/llm/0457-llm.txt
# Processing: ../Data/raw/test_data\0018.txt and ../Data/raw/reference_standard_for_test_data/concepts/0018.con -> ../Data/raw/reference_standard_for_test_data/llm/0018-llm.txt
# Processing: ../Data/raw/test_data\0365.txt and ../Data/raw/reference_standard_for_test_data/concepts/0365.con -> ../Data/raw/reference_standard_for_test_data/llm/0365-llm.txt
# Processing: ../Data/raw/test_data\0475.txt and ../Data/raw/reference_standard_for_test_data/concepts/0475.con -> ../Data/raw/reference_standard_for_test_data/llm/0475-llm.txt
# Processing: ../Data/raw/test_data\0062.txt and ../Data/raw/reference_standard_for_test_data/concepts/0062.con -> ../Data/raw/reference_standard_for_test_data/llm/0062-llm.txt
# Processing: ../Data/raw/test_data\0322.txt and ../Data/raw/reference_standard_for_test_data/concepts/0322.con -> ../Data/raw/reference_standard_for_test_data/llm/0322-llm.txt
# Processing: ../Data/raw/test_data\0446.txt and ../Data/raw/reference_standard_for_test_data/concepts/0446.con -> ../Data/raw/reference_standard_for_test_data/llm/0446-llm.txt
# Processing: ../Data/raw/test_data\0254.txt and ../Data/raw/reference_standard_for_test_data/concepts/0254.con -> ../Data/raw/reference_standard_for_test_data/llm/0254-llm.txt
# Processing: ../Data/raw/test_data\0342.txt and ../Data/raw/reference_standard_for_test_data/concepts/0342.con -> ../Data/raw/reference_standard_for_test_data/llm/0342-llm.txt
# Processing: ../Data/raw/test_data\0153.txt and ../Data/raw/reference_standard_for_test_data/concepts/0153.con -> ../Data/raw/reference_standard_for_test_data/llm/0153-llm.txt
# Processing: ../Data/raw/test_data\0262.txt and ../Data/raw/reference_standard_for_test_data/concepts/0262.con -> ../Data/raw/reference_standard_for_test_data/llm/0262-llm.txt
# Processing: ../Data/raw/test_data\0170.txt and ../Data/raw/reference_standard_for_test_data/concepts/0170.con -> ../Data/raw/reference_standard_for_test_data/llm/0170-llm.txt
# Processing: ../Data/raw/test_data\0265.txt and ../Data/raw/reference_standard_for_test_data/concepts/0265.con -> ../Data/raw/reference_standard_for_test_data/llm/0265-llm.txt
# Processing: ../Data/raw/test_data\0317.txt and ../Data/raw/reference_standard_for_test_data/concepts/0317.con -> ../Data/raw/reference_standard_for_test_data/llm/0317-llm.txt
# Processing: ../Data/raw/test_data\0181.txt and ../Data/raw/reference_standard_for_test_data/concepts/0181.con -> ../Data/raw/reference_standard_for_test_data/llm/0181-llm.txt
# Processing: ../Data/raw/test_data\0353.txt and ../Data/raw/reference_standard_for_test_data/concepts/0353.con -> ../Data/raw/reference_standard_for_test_data/llm/0353-llm.txt
# Processing: ../Data/raw/test_data\0349.txt and ../Data/raw/reference_standard_for_test_data/concepts/0349.con -> ../Data/raw/reference_standard_for_test_data/llm/0349-llm.txt
# Processing: ../Data/raw/test_data\0217.txt and ../Data/raw/reference_standard_for_test_data/concepts/0217.con -> ../Data/raw/reference_standard_for_test_data/llm/0217-llm.txt
# Processing: ../Data/raw/test_data\0290.txt and ../Data/raw/reference_standard_for_test_data/concepts/0290.con -> ../Data/raw/reference_standard_for_test_data/llm/0290-llm.txt
# Processing: ../Data/raw/test_data\0382.txt and ../Data/raw/reference_standard_for_test_data/concepts/0382.con -> ../Data/raw/reference_standard_for_test_data/llm/0382-llm.txt
# Processing: ../Data/raw/test_data\0021.txt and ../Data/raw/reference_standard_for_test_data/concepts/0021.con -> ../Data/raw/reference_standard_for_test_data/llm/0021-llm.txt
# Processing: ../Data/raw/test_data\0477.txt and ../Data/raw/reference_standard_for_test_data/concepts/0477.con -> ../Data/raw/reference_standard_for_test_data/llm/0477-llm.txt
# Processing: ../Data/raw/test_data\0298.txt and ../Data/raw/reference_standard_for_test_data/concepts/0298.con -> ../Data/raw/reference_standard_for_test_data/llm/0298-llm.txt
# Processing: ../Data/raw/test_data\0014.txt and ../Data/raw/reference_standard_for_test_data/concepts/0014.con -> ../Data/raw/reference_standard_for_test_data/llm/0014-llm.txt
# Processing: ../Data/raw/test_data\0193.txt and ../Data/raw/reference_standard_for_test_data/concepts/0193.con -> ../Data/raw/reference_standard_for_test_data/llm/0193-llm.txt
# Processing: ../Data/raw/test_data\0469.txt and ../Data/raw/reference_standard_for_test_data/concepts/0469.con -> ../Data/raw/reference_standard_for_test_data/llm/0469-llm.txt
# Processing: ../Data/raw/test_data\0138.txt and ../Data/raw/reference_standard_for_test_data/concepts/0138.con -> ../Data/raw/reference_standard_for_test_data/llm/0138-llm.txt
# Processing: ../Data/raw/test_data\0157.txt and ../Data/raw/reference_standard_for_test_data/concepts/0157.con -> ../Data/raw/reference_standard_for_test_data/llm/0157-llm.txt
# Processing: ../Data/raw/test_data\0468.txt and ../Data/raw/reference_standard_for_test_data/concepts/0468.con -> ../Data/raw/reference_standard_for_test_data/llm/0468-llm.txt
# Processing: ../Data/raw/test_data\0282.txt and ../Data/raw/reference_standard_for_test_data/concepts/0282.con -> ../Data/raw/reference_standard_for_test_data/llm/0282-llm.txt
# Processing: ../Data/raw/test_data\0029.txt and ../Data/raw/reference_standard_for_test_data/concepts/0029.con -> ../Data/raw/reference_standard_for_test_data/llm/0029-llm.txt
# Processing: ../Data/raw/test_data\0333.txt and ../Data/raw/reference_standard_for_test_data/concepts/0333.con -> ../Data/raw/reference_standard_for_test_data/llm/0333-llm.txt
# Processing: ../Data/raw/test_data\0445.txt and ../Data/raw/reference_standard_for_test_data/concepts/0445.con -> ../Data/raw/reference_standard_for_test_data/llm/0445-llm.txt
# Processing: ../Data/raw/test_data\0440.txt and ../Data/raw/reference_standard_for_test_data/concepts/0440.con -> ../Data/raw/reference_standard_for_test_data/llm/0440-llm.txt
# Processing: ../Data/raw/test_data\0430.txt and ../Data/raw/reference_standard_for_test_data/concepts/0430.con -> ../Data/raw/reference_standard_for_test_data/llm/0430-llm.txt
# Processing: ../Data/raw/test_data\0427.txt and ../Data/raw/reference_standard_for_test_data/concepts/0427.con -> ../Data/raw/reference_standard_for_test_data/llm/0427-llm.txt
# Processing: ../Data/raw/test_data\0237.txt and ../Data/raw/reference_standard_for_test_data/concepts/0237.con -> ../Data/raw/reference_standard_for_test_data/llm/0237-llm.txt
# Processing: ../Data/raw/test_data\0458.txt and ../Data/raw/reference_standard_for_test_data/concepts/0458.con -> ../Data/raw/reference_standard_for_test_data/llm/0458-llm.txt
# Processing: ../Data/raw/test_data\0186.txt and ../Data/raw/reference_standard_for_test_data/concepts/0186.con -> ../Data/raw/reference_standard_for_test_data/llm/0186-llm.txt
# Processing: ../Data/raw/test_data\0398.txt and ../Data/raw/reference_standard_for_test_data/concepts/0398.con -> ../Data/raw/reference_standard_for_test_data/llm/0398-llm.txt
# Processing: ../Data/raw/test_data\0273.txt and ../Data/raw/reference_standard_for_test_data/concepts/0273.con -> ../Data/raw/reference_standard_for_test_data/llm/0273-llm.txt
# Processing: ../Data/raw/test_data\0305.txt and ../Data/raw/reference_standard_for_test_data/concepts/0305.con -> ../Data/raw/reference_standard_for_test_data/llm/0305-llm.txt
# Processing: ../Data/raw/test_data\0042.txt and ../Data/raw/reference_standard_for_test_data/concepts/0042.con -> ../Data/raw/reference_standard_for_test_data/llm/0042-llm.txt
# Processing: ../Data/raw/test_data\0205.txt and ../Data/raw/reference_standard_for_test_data/concepts/0205.con -> ../Data/raw/reference_standard_for_test_data/llm/0205-llm.txt
# Processing: ../Data/raw/test_data\0474.txt and ../Data/raw/reference_standard_for_test_data/concepts/0474.con -> ../Data/raw/reference_standard_for_test_data/llm/0474-llm.txt
# Processing: ../Data/raw/test_data\0141.txt and ../Data/raw/reference_standard_for_test_data/concepts/0141.con -> ../Data/raw/reference_standard_for_test_data/llm/0141-llm.txt
# Processing: ../Data/raw/test_data\0137.txt and ../Data/raw/reference_standard_for_test_data/concepts/0137.con -> ../Data/raw/reference_standard_for_test_data/llm/0137-llm.txt
# Processing: ../Data/raw/test_data\0261.txt and ../Data/raw/reference_standard_for_test_data/concepts/0261.con -> ../Data/raw/reference_standard_for_test_data/llm/0261-llm.txt
# Processing: ../Data/raw/test_data\0194.txt and ../Data/raw/reference_standard_for_test_data/concepts/0194.con -> ../Data/raw/reference_standard_for_test_data/llm/0194-llm.txt
# Processing: ../Data/raw/test_data\0101.txt and ../Data/raw/reference_standard_for_test_data/concepts/0101.con -> ../Data/raw/reference_standard_for_test_data/llm/0101-llm.txt
# Processing: ../Data/raw/test_data\0366.txt and ../Data/raw/reference_standard_for_test_data/concepts/0366.con -> ../Data/raw/reference_standard_for_test_data/llm/0366-llm.txt
# Processing: ../Data/raw/test_data\0230.txt and ../Data/raw/reference_standard_for_test_data/concepts/0230.con -> ../Data/raw/reference_standard_for_test_data/llm/0230-llm.txt
# Processing: ../Data/raw/test_data\0114.txt and ../Data/raw/reference_standard_for_test_data/concepts/0114.con -> ../Data/raw/reference_standard_for_test_data/llm/0114-llm.txt
# Processing: ../Data/raw/test_data\0098.txt and ../Data/raw/reference_standard_for_test_data/concepts/0098.con -> ../Data/raw/reference_standard_for_test_data/llm/0098-llm.txt
# Processing: ../Data/raw/test_data\0069.txt and ../Data/raw/reference_standard_for_test_data/concepts/0069.con -> ../Data/raw/reference_standard_for_test_data/llm/0069-llm.txt
# Processing: ../Data/raw/test_data\0289.txt and ../Data/raw/reference_standard_for_test_data/concepts/0289.con -> ../Data/raw/reference_standard_for_test_data/llm/0289-llm.txt
# Processing: ../Data/raw/test_data\0419.txt and ../Data/raw/reference_standard_for_test_data/concepts/0419.con -> ../Data/raw/reference_standard_for_test_data/llm/0419-llm.txt
# Processing: ../Data/raw/test_data\0425.txt and ../Data/raw/reference_standard_for_test_data/concepts/0425.con -> ../Data/raw/reference_standard_for_test_data/llm/0425-llm.txt
# Processing: ../Data/raw/test_data\0422.txt and ../Data/raw/reference_standard_for_test_data/concepts/0422.con -> ../Data/raw/reference_standard_for_test_data/llm/0422-llm.txt
# Processing: ../Data/raw/test_data\0285.txt and ../Data/raw/reference_standard_for_test_data/concepts/0285.con -> ../Data/raw/reference_standard_for_test_data/llm/0285-llm.txt
# Processing: ../Data/raw/test_data\0145.txt and ../Data/raw/reference_standard_for_test_data/concepts/0145.con -> ../Data/raw/reference_standard_for_test_data/llm/0145-llm.txt
# Processing: ../Data/raw/test_data\0357.txt and ../Data/raw/reference_standard_for_test_data/concepts/0357.con -> ../Data/raw/reference_standard_for_test_data/llm/0357-llm.txt
# Processing: ../Data/raw/test_data\0369.txt and ../Data/raw/reference_standard_for_test_data/concepts/0369.con -> ../Data/raw/reference_standard_for_test_data/llm/0369-llm.txt

# %% [markdown]
# Process a single file for testing

# %%
import os
import re

def generate_llm_file_with_sentence_matching(text_file, concept_file, output_file):
    # Read the text file
    with open(text_file, 'r') as txt_f:
        lines = txt_f.readlines()

    # Read the concept file
    with open(concept_file, 'r') as con_f:
        concepts = con_f.readlines()

    # Parse the concepts
    tag_map = {}
    for concept in concepts:
        if concept.strip():
            match = re.match(r'c="(.+?)" (\d+):(\d+) (\d+):(\d+)\|\|t="(.+?)"', concept.strip())
            if match:
                phrase, start_line, start_word, end_line, end_word, tag = match.groups()
                start_line, start_word, end_line, end_word = map(int, (start_line, start_word, end_line, end_word))
                start_line -= 1  # Convert to zero-based index
                end_line -= 1  # Convert to zero-based index

                if start_line == end_line:  # Ensure the concept is within one sentence
                    if start_line not in tag_map:
                        tag_map[start_line] = []
                    tag_map[start_line].append((start_word, end_word, phrase, tag))

    # Process the text file
    updated_lines = []
    for i, line in enumerate(lines):
        updated_line = line.strip().split()  # Tokenize the line into words
        if i in tag_map:
            # Sort concepts by start and end indices to avoid overlap issues
            concepts = sorted(tag_map[i], key=lambda x: (x[0], x[1]))
            for start_word, end_word, phrase, tag in reversed(concepts):  # Process from end to start
                # Wrap the specific phrase in its tag
                updated_line[start_word:end_word + 1] = [f"<{tag}>"] + updated_line[start_word:end_word + 1] + [f"</{tag}>"]

        # Reconstruct the updated line
        updated_lines.append(" ".join(updated_line) + "\n")

    # Write the updated text to the output file
    with open(output_file, 'w') as out_f:
        out_f.writelines(updated_lines)


def process_specific_file(txt_dir, concept_dir, output_dir, file_id):
    # Ensure the output directory exists
    os.makedirs(output_dir, exist_ok=True)

    text_file = os.path.join(txt_dir, f"{file_id}.txt")
    concept_file = os.path.join(concept_dir, f"{file_id}.con")
    output_file = os.path.join(output_dir, f"{file_id}-llm.txt")

    # Check if files exist
    if os.path.exists(text_file) and os.path.exists(concept_file):
        print(f"Processing: {text_file} and {concept_file} -> {output_file}")
        generate_llm_file_with_sentence_matching(text_file, concept_file, output_file)
    else:
        print(f"Error: {file_id}.txt or {file_id}.con does not exist in the specified directories.")


# Directory paths
txt_dir = "../Data/raw/concept_assertion_relation_training_data/beth/txt/"
concept_dir = "../Data/raw/concept_assertion_relation_training_data/beth/concept/"
output_dir = "../Data/raw/concept_assertion_relation_training_data/beth/llm/"

# Specify the file ID to process
file_id = "record-13"

# Process the specific file
process_specific_file(txt_dir, concept_dir, output_dir, file_id)
