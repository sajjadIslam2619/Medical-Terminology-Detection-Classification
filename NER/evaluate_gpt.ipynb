# %%
from pathlib import Path

# Define paths
input_dir = Path("../Data/raw/test_data/")
input_file_name = "0001.txt"
input_file = input_dir / input_file_name

print(input_file)

# Read input
with open(input_file, "r", encoding="utf-8") as f:
    clinical_text_content  = f.read().strip()

print(clinical_text_content )
# Out:
# ..\Data\raw\test_data\0001.txt
# ﻿Admission Date :
# 2012-10-31
# Discharge Date :
# 2012-11-07
# Date of Birth :
# 1941-03-23
# Sex :
# M
# Service :
# MEDICINE
# Allergies :
# Nsaids/Anti-Inflammatory Classifier / Vancomycin
# Attending :
# Kristie R. Hamby , M.D.
# Chief Complaint :
# CC : Antonio M. Z. Eddings , M.D.
# Major Surgical or Invasive Procedure :
# Mesenteric angiograpm w/ coil embolization of bleeding vessel .
# Sigmoidoscopy .
# Colonoscopy .
# History of Present Illness :
# HPI: Pt is a 71 y/o male with h/o dm2 , cad s/p cabg , DVT/PE on long term anti-coagulation , ulcerative colitis on Asacol presents with brbpr starting at 9am of the morning of admission .
# He 'd been having lower abdominal pain for approximately the past week , a symptom for which he 's been admitted in the past .
# His PCP had recently started ciprofloxacin for a UTI .
# At 9am the morning of admission he passed a large , bloody bowel movement and came to the Michael . There , his vitals were intially stable with a hct of 36.7 , though he was felt to be hypovolemic and this hemoconcentrated ; his previous hct was 39 about five months ago .
# He refused an NG lavage .
# Although an initial DRE showed only clot , he later passed a large , bloody bowel movement , and his bp nadired to the low 90's but rested there only transiently and easily rebounded to the 130's-140's with fluid ; he then went to angiography for a tagged RBC scan where they found and embolized two vessels to the sigmoid colon .
# His HCT had dropped from 36.7 to 30.8 despite 2U PRBC and 3 U FFP .
# Is called out of the FICU as has been been HD and stable HCT .
# Currently denies CP , SOB , abd pain or continued BRBPR .
# Past Medical History :
# PMH :
# 1.) DM-2
# 2.) CAD s/p 3v-CABG 2003 and subsequent stenting of SVG and LIMA
# 3.) CHF with EF 30-35% on 07-10 echo
# 4.) Right parietal intracranial bleeding following 1996 cardiac cath
# 5.) LBBB
# 6.) Sinus node dysfunction s/p pacemaker
# 7.) H/O DVT ( right sided ) and subsequent PE , put onto lifetime warfarin
# 8.) Ulcerative colitis
# PSH :
# 1.) C4-7 anterior discectomies
# 2.) CABG 2003
# 3.) R intracerebral hemorrhage drainage
# Social History :
# SocHx : Mr Peres generally lives with his wife but has spent a great deal of time recently at rehab .
# He has no h/o ETOH/IVDA but quit tob 15 years ago .
# Family History :
# Noncontributory .
# Physical Exam :
# VS 98.4 , 62 , 103/37 , 15 97%2L
# gen - lying in bed , NAD
# heent - anicteric sclera , op clear with mmm
# neck - jvd flat
# cv - rrr , s1s2 , no m/r/g
# pul - CTAB without rales
# abd - soft , minimally distended , nt , no rebound/guarding , nabs
# extrm - trace edema at ankles , no cyanosis , warm/dry
# Pertinent Results :
# 2012-10-31 05:47PM URINE
# COLOR - Straw APPEAR - Clear SP Marquez - 1.021
# 2012-10-31 05:47PM URINE
# BLOOD - LG NITRITE - NEG PROTEIN - NEG
# GLUCOSE - NEG KETONE - NEG BILIRUBIN - NEG UROBILNGN - NEG PH - 7.0 LEUK - NEG
# 2012-10-31 05:47PM URINE
# RBC-21-50* WBC-0-2 BACTERIA - FEW
# YEAST - NONE EPI - <1
# 2012-10-31 02:32PM
# LACTATE - 1.8
# 2012-10-31 12:20PM
# GLUCOSE - 197* UREA N-25* CREAT - 0.8 SODIUM - 141
# POTASSIUM - 3.7 CHLORIDE - 105 TOTAL CO2 - 22 ANION GAP - 18
# 2012-10-31 12:20PM
# WBC - 5.6 RBC - 4.35* HGB - 12.6* HCT - 36.7* MCV - 84
# MCH - 28.9 MCHC - 34.3 RDW - 15.7*
# 2012-10-31 12:20PM
# NEUTS - 80.5* LYMPHS - 13.1* MONOS - 3.5 EOS - 2.5
# BASOS - 0.4
# 2012-10-31 12:20PM
# POIKILOCY - 1+ MICROCYT - 1+
# 2012-10-31 12:20PM
# PLT COUNT - 102*
# 2012-10-31 12:20PM
# PT - 20.5* PTT - 29.4 INR(PT) - 3.0
# GI BLEEDING STUDY
# 2012-10-31
# IMPRESSION : Increased tracer activity demonstrated within the left lower quadrant , most likely sigmoid colonic loops of bowel , consistent with active bleeding .
# CT ABDOMEN W/CONTRAST
# 2012-10-31 3:27 PM
# IMPRESSION :
# 1. No evidence of colitis or other bowel pathology present to explain the patient 's bright red blood per rectum .
# 2. Stable appearance of left adrenal fat-containing lesion consistent with a myelolipoma .
# 3. Stable appearance of hypodense lesion within the caudate lobe of the liver , too small to fully characterize .
# 4. Subcentimeter attenuation lesion within the lower pole of the right kidney , too small to characterize .
# 5. 3-mm noncalcified pulmonary nodule within the right lower lobe .
# If the patient does not have a history of a primary malignancy , followup CT of the chest in 1 year is recommended to evaluate for stability of this finding .
# Brief Hospital Course :
# Initial A/P :
# 71 y/o male with dm2 , cad , chf , uc presents with one week of lower abdominal pain and 2 episodes of brpbr on the day of admission .
# # BRBPR -- The patient was in the intensive care unit given his lower GI bleed .
# An angiography showed bleeding in two vessels off of the Minnie supplying the sigmoid that were succesfully embolized .
# The patient was transfused from a Hct 29 to 34 on the day of discharge .
# His coumadin was held during his stay given his acute bleed but restarted per his PCP with the guidance of GI on the day of discharge .
# - The patient underwent a flex sigmoidoscopy on Friday , 11-02 , which showed old blood in the rectal vault but no active source of bleeding .
# Given this , it was advised that the patient have a colonoscopy to rule out further bleeding .
# - The patient had a colonoscopy on Monday 11-05 but unfortunately , was unable to complete the study as his bowel
# prep was inadequate .
# Therefore , he had a repeat colonoscopy on 11-06 which showed expected mucosal signs of moderate ulcerative colitis , no polyps , w/ 8 mm ulcer at junction of distal descending colon and sigmoid colon .
# - Biopsies were obtained during his colonoscopy and he should follow up with gastroenterology for the results .
# # Ulcerative colitis -- The patient 's Asacol was originally held but restarted the day prior to discharge per GI .
# # CAD/CHF - The patient was restarted on his home regimen prior to discharge as it was held temporarily given his acute GI bleed .
# The exception is that per his PCP , Jason aspirin will be held for 2 weeks given that he was restarted on coumadin with
# his risk of bleeding .
# # DM-2 -- The patient was maintained on his home insulin regimen .
# # h/o DVT/PE :
# Coumadin was initially held .
# It was unclear at first as to why the patient required life-long anticoagulation .
# After discussing this with his PCP , Leon was clear that the patient had had recurrent DVTs and ultimately a PE and his PCP felt strongly that he required long-term anticoagulation .
# His goal INR should be 1.6-2.0 . If bleeding continues to occur , consider V. Winchester filter .
# # Access -- 2 large bore PIV's
# # Code -- full
# Medications on Admission :
# Meds on Admission :
# 1.) Spironolactone/hctz 25/25 daily
# 2.) Atenolol 12.5mg daily
# 3.) Insulin 45N/8R qAM and 33N qPM
# 4.) Furosemide 10 mg every other day
# 5.) Aspirin 81 mg daily
# 6.) Zoloft 40 mg qAM
# 7.) Flomax
# 8.) Atorvastatin 40 mg daily
# 9.) Ritalin 20 mg daily
# 10.) Ramipril 2.5 mg daily
# 11.) Asacol 400 mg 3 , TID
# 12.) Carafate 1 gm bid
# 13.) Actos 15 mg daily
# 14.) Folate 1 mg daily
# 15.) Warfarin 2 mg daily
# Discharge Medications :
# 1. Tamsulosin 0.4 mg Capsule , Sust . Release 24HR Sig : One ( 1 ) Capsule , Sust . Release 24HR PO HS ( at bedtime ) .
# 2. Atorvastatin 40 mg Tablet Sig : One ( 1 ) Tablet PO DAILY ( Daily ) .
# 3. Methylphenidate 10 mg Tablet Sig : Two ( 2 ) Tablet PO DAILY ( Daily ) .
# 4. Acetaminophen 325 mg Tablet Sig : One ( 1 ) Tablet PO Q4-6H ( every 4 to 6 hours ) as needed .
# 5. Folic Acid 1 mg Tablet Sig : One ( 1 ) Tablet PO DAILY ( Daily ) .
# 6. Atenolol 25 mg Tablet Sig : 0.5 Tablet PO DAILY ( Daily ) .
# 7. Spironolactone 25 mg Tablet Sig : One ( 1 ) Tablet PO DAILY ( Daily ) .
# 8. Ramipril 1.25 mg Capsule Sig : Two ( 2 ) Capsule PO DAILY ( Daily ) .
# 9. Hydrochlorothiazide 25 mg Tablet Sig : One ( 1 ) Tablet PO DAILY ( Daily ) .
# 10. Pioglitazone 15 mg Tablet Sig : One ( 1 ) Tablet PO DAILY ( Daily ) as needed for DM .
# 11. Mesalamine 400 mg Tablet , Delayed Release ( E.C. ) Sig : Three ( 3 ) Tablet , Delayed Release ( E.C. ) PO TID ( 3 times a day ) as needed for ulcerative colitis w/o recent severe flares .
# 12. Insulin 45 NPH in am with 33 NPH at bedtime
# Continue Sliding scale insulin as needed .
# 13. Sertraline 20 mg/mL Concentrate Sig : Two ( 2 )  PO at bedtime .
# 14. Coumadin 2 mg Tablet Sig : One ( 1 ) Tablet PO once a day .
# Discharge Disposition :
# Extended Care
# Facility :
# Oak Bluffs Of Greenfield
# Discharge Diagnosis :
# Rectal bleeding from inferior mesenteric artery tributaries supplying sigmoid colon .
# Discharge Condition : Good .
# Discharge Instructions :
# Please call physician if you develop shortness of breath , weakness in your legs or arms , sudden blurry vision or slurred speech , chest pain , faintness , or significant unexplained weight loss .
# Followup Instructions :
# Provider : Lucio Y. Matthews , M.D. Phone : ( 967 ) 675 1641 Date/Time : 2012-12-28 2:30
# Provider :  Greg CLINIC Phone : ( 212 ) 442 0438 Date/Time : 2013-01-11 1:30
# Provider : Lucio F. R. Matthews , M.D. Phone : ( 967 ) 675 1641 Date/Time : 2013-01-11 2:00
# Please call White , Leslie L. at ( 602 ) 743 8709 to schedule an appointment with him in 1 week .
# Please call your gastroenterologist to schedule a follow up appointment in 2 weeks .
# Alan John MD 54-745
# Completed by : Bertha Janice Motta MD 52-860 2012-11-07 @ 1207
# Signed electronically by : DR. Melody PARKS on: WED 2012-11-21 6:22 PM
# ( End of Report )

# %% [markdown]
# Entity-Only Zero Shot Prompt

# %%
# Define meaningful prompt parts
instruction = (
    "Your task is to extract entities from clinical text and categorize them into predefined labels "
    "based on their role in medical documentation."
)

source_info = (
    "The source text comes from Electronic Health Records (EHRs), which are digital versions of patients' medical histories, "
    "including diagnoses, medications, procedures, lab results, and physician notes."
)

category_definition = (
    "Entity Categories\n"
    "Each extracted entity should be classified into one of the following categories:\n"
    "Test: A diagnostic procedure, lab test, or medical examination performed to investigate or reveal a medical condition.\n"
    "Examples:\n"
    "entity=\"colonoscopy\" label=\"test\"\n"
    "entity=\"MRI scan\" label=\"test\"\n"
    "entity=\"blood glucose test\" label=\"test\"\n\n"
    "Treatment: A medication, procedure, or intervention administered to manage, improve, or prevent a medical problem.\n"
    "Examples:\n"
    "entity=\"ramipril\" label=\"treatment\"\n"
    "entity=\"chemotherapy\" label=\"treatment\"\n"
    "entity=\"insulin therapy\" label=\"treatment\"\n\n"
    "Problem: A medical condition, symptom, or diagnosis affecting a patient, which may require testing or treatment.\n"
    "Examples:\n"
    "entity=\"diabetes mellitus\" label=\"problem\"\n"
    "entity=\"chest pain\" label=\"problem\"\n"
    "entity=\"hypertension\" label=\"problem\""
)

output_format = (
    "Expected Output Format\n"
    "Entities should be extracted and presented in the following format:\n"
    "entity=\"<extracted medical entity>\" label=\"<assigned category>\""
)

uncertain_handling = (
    "Handling Uncertain Cases\n"
    "If an entity cannot be clearly classified as test, treatment, or problem based on the information provided, "
    "label it as:\n"
    "entity=\"<extracted medical entity>\" label=\"unknown\""
)

triple_quote_note = (
    "Clinical Text Input\n"
    "Below, you will be given a clinical text document enclosed within triple quotes (\"\"\" \"\"\"). "
    "Your task is to extract relevant medical entities and assign them the appropriate labels based on the definitions provided above."
)

# Format with triple quotes
clinical_text = f'""" \n{clinical_text_content}\n"""'

# Combine all into one prompt
full_prompt = "\n\n".join([
    instruction,
    source_info,
    category_definition,
    output_format,
    uncertain_handling,  
    triple_quote_note,
    f"Clinical Text Input\n{clinical_text}"
])


print(full_prompt)
# Out:
# Your task is to extract entities from clinical text and categorize them into predefined labels based on their role in medical documentation.
#
# The source text comes from Electronic Health Records (EHRs), which are digital versions of patients' medical histories, including diagnoses, medications, procedures, lab results, and physician notes.
#
# Entity Categories
# Each extracted entity should be classified into one of the following categories:
# Test: A diagnostic procedure, lab test, or medical examination performed to investigate or reveal a medical condition.
# Examples:
# entity="colonoscopy" label="test"
# entity="MRI scan" label="test"
# entity="blood glucose test" label="test"
#
# Treatment: A medication, procedure, or intervention administered to manage, improve, or prevent a medical problem.
# Examples:
# entity="ramipril" label="treatment"
# entity="chemotherapy" label="treatment"
# entity="insulin therapy" label="treatment"
#
# Problem: A medical condition, symptom, or diagnosis affecting a patient, which may require testing or treatment.
# Examples:
# entity="diabetes mellitus" label="problem"
# entity="chest pain" label="problem"
# entity="hypertension" label="problem"
#
# Expected Output Format
# Entities should be extracted and presented in the following format:
# entity="<extracted medical entity>" label="<assigned category>"
#
# Handling Uncertain Cases
# If an entity cannot be clearly classified as test, treatment, or problem based on the information provided, label it as:
# entity="<extracted medical entity>" label="unknown"
#
# Clinical Text Input
# Below, you will be given a clinical text document enclosed within triple quotes (""" """). Your task is to extract relevant medical entities and assign them the appropriate labels based on the definitions provided above.
#
# Clinical Text Input
# """
# ﻿Admission Date :
# 2012-10-31
# Discharge Date :
# 2012-11-07
# Date of Birth :
# 1941-03-23
# Sex :
# M
# Service :
# MEDICINE
# Allergies :
# Nsaids/Anti-Inflammatory Classifier / Vancomycin
# Attending :
# Kristie R. Hamby , M.D.
# Chief Complaint :
# CC : Antonio M. Z. Eddings , M.D.
# Major Surgical or Invasive Procedure :
# Mesenteric angiograpm w/ coil embolization of bleeding vessel .
# Sigmoidoscopy .
# Colonoscopy .
# History of Present Illness :
# HPI: Pt is a 71 y/o male with h/o dm2 , cad s/p cabg , DVT/PE on long term anti-coagulation , ulcerative colitis on Asacol presents with brbpr starting at 9am of the morning of admission .
# He 'd been having lower abdominal pain for approximately the past week , a symptom for which he 's been admitted in the past .
# His PCP had recently started ciprofloxacin for a UTI .
# At 9am the morning of admission he passed a large , bloody bowel movement and came to the Michael . There , his vitals were intially stable with a hct of 36.7 , though he was felt to be hypovolemic and this hemoconcentrated ; his previous hct was 39 about five months ago .
# He refused an NG lavage .
# Although an initial DRE showed only clot , he later passed a large , bloody bowel movement , and his bp nadired to the low 90's but rested there only transiently and easily rebounded to the 130's-140's with fluid ; he then went to angiography for a tagged RBC scan where they found and embolized two vessels to the sigmoid colon .
# His HCT had dropped from 36.7 to 30.8 despite 2U PRBC and 3 U FFP .
# Is called out of the FICU as has been been HD and stable HCT .
# Currently denies CP , SOB , abd pain or continued BRBPR .
# Past Medical History :
# PMH :
# 1.) DM-2
# 2.) CAD s/p 3v-CABG 2003 and subsequent stenting of SVG and LIMA
# 3.) CHF with EF 30-35% on 07-10 echo
# 4.) Right parietal intracranial bleeding following 1996 cardiac cath
# 5.) LBBB
# 6.) Sinus node dysfunction s/p pacemaker
# 7.) H/O DVT ( right sided ) and subsequent PE , put onto lifetime warfarin
# 8.) Ulcerative colitis
# PSH :
# 1.) C4-7 anterior discectomies
# 2.) CABG 2003
# 3.) R intracerebral hemorrhage drainage
# Social History :
# SocHx : Mr Peres generally lives with his wife but has spent a great deal of time recently at rehab .
# He has no h/o ETOH/IVDA but quit tob 15 years ago .
# Family History :
# Noncontributory .
# Physical Exam :
# VS 98.4 , 62 , 103/37 , 15 97%2L
# gen - lying in bed , NAD
# heent - anicteric sclera , op clear with mmm
# neck - jvd flat
# cv - rrr , s1s2 , no m/r/g
# pul - CTAB without rales
# abd - soft , minimally distended , nt , no rebound/guarding , nabs
# extrm - trace edema at ankles , no cyanosis , warm/dry
# Pertinent Results :
# 2012-10-31 05:47PM URINE
# COLOR - Straw APPEAR - Clear SP Marquez - 1.021
# 2012-10-31 05:47PM URINE
# BLOOD - LG NITRITE - NEG PROTEIN - NEG
# GLUCOSE - NEG KETONE - NEG BILIRUBIN - NEG UROBILNGN - NEG PH - 7.0 LEUK - NEG
# 2012-10-31 05:47PM URINE
# RBC-21-50* WBC-0-2 BACTERIA - FEW
# YEAST - NONE EPI - <1
# 2012-10-31 02:32PM
# LACTATE - 1.8
# 2012-10-31 12:20PM
# GLUCOSE - 197* UREA N-25* CREAT - 0.8 SODIUM - 141
# POTASSIUM - 3.7 CHLORIDE - 105 TOTAL CO2 - 22 ANION GAP - 18
# 2012-10-31 12:20PM
# WBC - 5.6 RBC - 4.35* HGB - 12.6* HCT - 36.7* MCV - 84
# MCH - 28.9 MCHC - 34.3 RDW - 15.7*
# 2012-10-31 12:20PM
# NEUTS - 80.5* LYMPHS - 13.1* MONOS - 3.5 EOS - 2.5
# BASOS - 0.4
# 2012-10-31 12:20PM
# POIKILOCY - 1+ MICROCYT - 1+
# 2012-10-31 12:20PM
# PLT COUNT - 102*
# 2012-10-31 12:20PM
# PT - 20.5* PTT - 29.4 INR(PT) - 3.0
# GI BLEEDING STUDY
# 2012-10-31
# IMPRESSION : Increased tracer activity demonstrated within the left lower quadrant , most likely sigmoid colonic loops of bowel , consistent with active bleeding .
# CT ABDOMEN W/CONTRAST
# 2012-10-31 3:27 PM
# IMPRESSION :
# 1. No evidence of colitis or other bowel pathology present to explain the patient 's bright red blood per rectum .
# 2. Stable appearance of left adrenal fat-containing lesion consistent with a myelolipoma .
# 3. Stable appearance of hypodense lesion within the caudate lobe of the liver , too small to fully characterize .
# 4. Subcentimeter attenuation lesion within the lower pole of the right kidney , too small to characterize .
# 5. 3-mm noncalcified pulmonary nodule within the right lower lobe .
# If the patient does not have a history of a primary malignancy , followup CT of the chest in 1 year is recommended to evaluate for stability of this finding .
# Brief Hospital Course :
# Initial A/P :
# 71 y/o male with dm2 , cad , chf , uc presents with one week of lower abdominal pain and 2 episodes of brpbr on the day of admission .
# # BRBPR -- The patient was in the intensive care unit given his lower GI bleed .
# An angiography showed bleeding in two vessels off of the Minnie supplying the sigmoid that were succesfully embolized .
# The patient was transfused from a Hct 29 to 34 on the day of discharge .
# His coumadin was held during his stay given his acute bleed but restarted per his PCP with the guidance of GI on the day of discharge .
# - The patient underwent a flex sigmoidoscopy on Friday , 11-02 , which showed old blood in the rectal vault but no active source of bleeding .
# Given this , it was advised that the patient have a colonoscopy to rule out further bleeding .
# - The patient had a colonoscopy on Monday 11-05 but unfortunately , was unable to complete the study as his bowel
# prep was inadequate .
# Therefore , he had a repeat colonoscopy on 11-06 which showed expected mucosal signs of moderate ulcerative colitis , no polyps , w/ 8 mm ulcer at junction of distal descending colon and sigmoid colon .
# - Biopsies were obtained during his colonoscopy and he should follow up with gastroenterology for the results .
# # Ulcerative colitis -- The patient 's Asacol was originally held but restarted the day prior to discharge per GI .
# # CAD/CHF - The patient was restarted on his home regimen prior to discharge as it was held temporarily given his acute GI bleed .
# The exception is that per his PCP , Jason aspirin will be held for 2 weeks given that he was restarted on coumadin with
# his risk of bleeding .
# # DM-2 -- The patient was maintained on his home insulin regimen .
# # h/o DVT/PE :
# Coumadin was initially held .
# It was unclear at first as to why the patient required life-long anticoagulation .
# After discussing this with his PCP , Leon was clear that the patient had had recurrent DVTs and ultimately a PE and his PCP felt strongly that he required long-term anticoagulation .
# His goal INR should be 1.6-2.0 . If bleeding continues to occur , consider V. Winchester filter .
# # Access -- 2 large bore PIV's
# # Code -- full
# Medications on Admission :
# Meds on Admission :
# 1.) Spironolactone/hctz 25/25 daily
# 2.) Atenolol 12.5mg daily
# 3.) Insulin 45N/8R qAM and 33N qPM
# 4.) Furosemide 10 mg every other day
# 5.) Aspirin 81 mg daily
# 6.) Zoloft 40 mg qAM
# 7.) Flomax
# 8.) Atorvastatin 40 mg daily
# 9.) Ritalin 20 mg daily
# 10.) Ramipril 2.5 mg daily
# 11.) Asacol 400 mg 3 , TID
# 12.) Carafate 1 gm bid
# 13.) Actos 15 mg daily
# 14.) Folate 1 mg daily
# 15.) Warfarin 2 mg daily
# Discharge Medications :
# 1. Tamsulosin 0.4 mg Capsule , Sust . Release 24HR Sig : One ( 1 ) Capsule , Sust . Release 24HR PO HS ( at bedtime ) .
# 2. Atorvastatin 40 mg Tablet Sig : One ( 1 ) Tablet PO DAILY ( Daily ) .
# 3. Methylphenidate 10 mg Tablet Sig : Two ( 2 ) Tablet PO DAILY ( Daily ) .
# 4. Acetaminophen 325 mg Tablet Sig : One ( 1 ) Tablet PO Q4-6H ( every 4 to 6 hours ) as needed .
# 5. Folic Acid 1 mg Tablet Sig : One ( 1 ) Tablet PO DAILY ( Daily ) .
# 6. Atenolol 25 mg Tablet Sig : 0.5 Tablet PO DAILY ( Daily ) .
# 7. Spironolactone 25 mg Tablet Sig : One ( 1 ) Tablet PO DAILY ( Daily ) .
# 8. Ramipril 1.25 mg Capsule Sig : Two ( 2 ) Capsule PO DAILY ( Daily ) .
# 9. Hydrochlorothiazide 25 mg Tablet Sig : One ( 1 ) Tablet PO DAILY ( Daily ) .
# 10. Pioglitazone 15 mg Tablet Sig : One ( 1 ) Tablet PO DAILY ( Daily ) as needed for DM .
# 11. Mesalamine 400 mg Tablet , Delayed Release ( E.C. ) Sig : Three ( 3 ) Tablet , Delayed Release ( E.C. ) PO TID ( 3 times a day ) as needed for ulcerative colitis w/o recent severe flares .
# 12. Insulin 45 NPH in am with 33 NPH at bedtime
# Continue Sliding scale insulin as needed .
# 13. Sertraline 20 mg/mL Concentrate Sig : Two ( 2 )  PO at bedtime .
# 14. Coumadin 2 mg Tablet Sig : One ( 1 ) Tablet PO once a day .
# Discharge Disposition :
# Extended Care
# Facility :
# Oak Bluffs Of Greenfield
# Discharge Diagnosis :
# Rectal bleeding from inferior mesenteric artery tributaries supplying sigmoid colon .
# Discharge Condition : Good .
# Discharge Instructions :
# Please call physician if you develop shortness of breath , weakness in your legs or arms , sudden blurry vision or slurred speech , chest pain , faintness , or significant unexplained weight loss .
# Followup Instructions :
# Provider : Lucio Y. Matthews , M.D. Phone : ( 967 ) 675 1641 Date/Time : 2012-12-28 2:30
# Provider :  Greg CLINIC Phone : ( 212 ) 442 0438 Date/Time : 2013-01-11 1:30
# Provider : Lucio F. R. Matthews , M.D. Phone : ( 967 ) 675 1641 Date/Time : 2013-01-11 2:00
# Please call White , Leslie L. at ( 602 ) 743 8709 to schedule an appointment with him in 1 week .
# Please call your gastroenterologist to schedule a follow up appointment in 2 weeks .
# Alan John MD 54-745
# Completed by : Bertha Janice Motta MD 52-860 2012-11-07 @ 1207
# Signed electronically by : DR. Melody PARKS on: WED 2012-11-21 6:22 PM
# ( End of Report )
# """

# %% [markdown]
# Prompt: Sentence level

# %%
from pathlib import Path

# Path to the sample training file
sample_file_path = Path("../Data/processed/llm/tag_sentences/train/random_100_sentences.txt")

# Read and wrap with triple quotes
with open(sample_file_path, "r", encoding="utf-8") as f:
    sample_sentences = f.read().strip()

# print(sample_sentences)

# Define meaningful prompt parts
instruction = (
    "Your task is to extract entities from clinical text and categorize them into predefined labels "
    "based on their role in medical documentation."
)

source_info = (
    "The source text comes from Electronic Health Records (EHRs), which are digital versions of patients' medical histories, "
    "including diagnoses, medications, procedures, lab results, and physician notes."
)

category_definition = (
    "Entity Categories\n"
    "Each extracted entity should be classified into one of the following categories:\n"
    "Test: A diagnostic procedure, lab test, or medical examination performed to investigate or reveal a medical condition.\n"
    "Examples:\n"
    "entity=\"colonoscopy\" label=\"test\"\n"
    "entity=\"MRI scan\" label=\"test\"\n"
    "entity=\"blood glucose test\" label=\"test\"\n\n"
    "Treatment: A medication, procedure, or intervention administered to manage, improve, or prevent a medical problem.\n"
    "Examples:\n"
    "entity=\"ramipril\" label=\"treatment\"\n"
    "entity=\"chemotherapy\" label=\"treatment\"\n"
    "entity=\"insulin therapy\" label=\"treatment\"\n\n"
    "Problem: A medical condition, symptom, or diagnosis affecting a patient, which may require testing or treatment.\n"
    "Examples:\n"
    "entity=\"diabetes mellitus\" label=\"problem\"\n"
    "entity=\"chest pain\" label=\"problem\"\n"
    "entity=\"hypertension\" label=\"problem\""
)

output_format = (
    "Expected Output Format\n"
    "Entities should be extracted and presented in the following format:\n"
    "entity=\"<extracted medical entity>\" label=\"<assigned category>\""
)

uncertain_handling = (
    "Handling Uncertain Cases\n"
    "If an entity cannot be clearly classified as test, treatment, or problem based on the information provided, "
    "label it as:\n"
    "entity=\"<extracted medical entity>\" label=\"unknown\""
)


sample_training_sentences = (
    "Sample Training Clinical Text\n"
    "You will be given a set of clinical sentences enclosed within triple quotes (\"\"\" \"\"\"). "
    "Each sentence will contain multiple tagged medical entities. Each entity is surrounded by angle brackets indicating its category: <test>, <treatment>, or <problem>."
    "For example, a blood test would be written as <test> blood test </test>, and a condition like chest pain would appear as <problem> chest pain </problem>."
    "These examples should help clarify how entities should be identified and classified. The system should learn from these examples and apply similar logic when "
    "extracting entities from new clinical text.\n\n"

    "Below is the annotated clinical sentences for training:\n"
    f"\"\"\"\n{sample_sentences}\n\"\"\""
)

triple_quote_note = (
    "Clinical Text Input\n"
    "Below, you will be given a clinical text document enclosed within triple quotes (\"\"\" \"\"\"). "
    "Your task is to extract relevant medical entities and assign them the appropriate labels based on the definitions provided above."
)

# Format with triple quotes
clinical_text = f'""" \n{clinical_text_content}\n"""'

# Combine all into one prompt
full_prompt = "\n\n".join([
    instruction,
    source_info,
    category_definition,
    output_format,
    uncertain_handling,
    triple_quote_note,
    sample_training_sentences, 
    f"Clinical Text Input\n{clinical_text}"  # ← actual test input
])


print(full_prompt)
# Out:
# Your task is to extract entities from clinical text and categorize them into predefined labels based on their role in medical documentation.
#
# The source text comes from Electronic Health Records (EHRs), which are digital versions of patients' medical histories, including diagnoses, medications, procedures, lab results, and physician notes.
#
# Entity Categories
# Each extracted entity should be classified into one of the following categories:
# Test: A diagnostic procedure, lab test, or medical examination performed to investigate or reveal a medical condition.
# Examples:
# entity="colonoscopy" label="test"
# entity="MRI scan" label="test"
# entity="blood glucose test" label="test"
#
# Treatment: A medication, procedure, or intervention administered to manage, improve, or prevent a medical problem.
# Examples:
# entity="ramipril" label="treatment"
# entity="chemotherapy" label="treatment"
# entity="insulin therapy" label="treatment"
#
# Problem: A medical condition, symptom, or diagnosis affecting a patient, which may require testing or treatment.
# Examples:
# entity="diabetes mellitus" label="problem"
# entity="chest pain" label="problem"
# entity="hypertension" label="problem"
#
# Expected Output Format
# Entities should be extracted and presented in the following format:
# entity="<extracted medical entity>" label="<assigned category>"
#
# Handling Uncertain Cases
# If an entity cannot be clearly classified as test, treatment, or problem based on the information provided, label it as:
# entity="<extracted medical entity>" label="unknown"
#
# Clinical Text Input
# Below, you will be given a clinical text document enclosed within triple quotes (""" """). Your task is to extract relevant medical entities and assign them the appropriate labels based on the definitions provided above.
#
# Sample Training Clinical Text
# You will be given a set of clinical sentences enclosed within triple quotes (""" """). Each sentence will contain multiple tagged medical entities. Each entity is surrounded by angle brackets indicating its category: <test>, <treatment>, or <problem>.For example, a blood test would be written as <test> blood test </test>, and a condition like chest pain would appear as <problem> chest pain </problem>.These examples should help clarify how entities should be identified and classified. The system should learn from these examples and apply similar logic when extracting entities from new clinical text.
#
# Below is the annotated clinical sentences for training:
# """
# <test> Her O2 sat </test> was stable at 94-97% on 2.5L of <treatment> supplemental O2 </treatment> .
# There is no <problem> pericardial effusion </problem> .
# With <problem> chronic lung disease </problem> .
# He underwent <treatment> a joint procedure </treatment> by Otolaryngology and Plastic Surgery .
# <treatment> Gentle diuresis </treatment> and <treatment> beta blockade </treatment> started , and he was transferred to the floor to begin increasing his activity level .
# You may remove <treatment> your dressings </treatment> 2 days after <treatment> your surgery </treatment> if they were not removed in the hospital .
# <treatment> Oxycodone-Acetaminophen </treatment> 5-325 mg Tablet Sig : 1-2 Tablets PO every 4-6 hours as needed for <problem> pain </problem> .
# <test> Apgar scores </test> were 6 at one minute and 8 at five minutes .
# After returning to her room she w noted <problem> SSCP </problem> without radiation .
# Will also need <test> LFT 's </test> checked in 3-6 months .
# <treatment> Staples </treatment> and <treatment> stitches </treatment> will remain until your follow-up appointment .
# <treatment> Docusate Sodium </treatment> 100 mg Capsule Sig : One ( 1 ) Capsule PO BID ( 2 times a day ) .
# <problem> Right basilar atelectasis </problem> has slightly worsened .
# CMED CSRU and Plastic Surgery <test> flap checks </test> , <treatment> tracheostomy care </treatment> , and <treatment> Westwood-Pocasset management </treatment>.
# <test> Troponin </test> was 0.07 .
# There is <problem> mild symmetric left ventricular hypertrophy </problem> with normal cavity size .
# <treatment> Furosemide </treatment> 20 mg Tablet Sig : One ( 1 ) Tablet PO BID ( 2 times a day ) for 7 days .
# History of <problem> orthostasis </problem> with <test> tilt table testing </test> done in the past .
# Before this age , the family and other caregivers should be considered for <treatment> immunization </treatment> against <problem> influenza </problem> to protect the infant .
# <test> Flap checks </test> carried out q.2h.
# <treatment> Aspirin </treatment> 325 mg Tablet Sig : One ( 1 ) Tablet PO DAILY ( Daily ) .
# <problem> TWI </problem> 's in III , V1 .
# <treatment> Tracheostomy </treatment> .
# He was weaned from <treatment> ventilation </treatment> on postoperative day one to <treatment> pressure support ventilation </treatment> and then to spontaneous breathing on postoperative day two .
# The right ventricular cavity is <problem> mildly dilated </problem> .
# There is <problem> mild regional left ventricular systolic dysfunction </problem> .
# Transferred in urgently for <treatment> cabg </treatment> with Dr. Howard .
# <test> Hematocrit </test> stable .
# <treatment> Total intravenous fluids </treatment> of 7300 cc .
# The pregnancy was unremarkable until 2015-06-01 when the mother presented to Shriner 's Hospital for Crippled Children for <problem> increased blood pressure </problem> and <problem> proteinuria </problem> .
# <treatment> Aluminum-Magnesium Hydroxide </treatment> 225-200 mg/5 mL Suspension Sig : 15-30 MLs PO QID ( 4 times a day ) as needed for <problem> indigestion </problem> .
# <treatment> Synagis RSV prophylaxis </treatment> should be considered from October through April for infants who meet any of the following criteria :
# <test> Her CXR </test> prior to discharge showed <problem> mild pulm edema </problem> and thus was given 40 of <treatment> lasix </treatment> prior to going to rehab .
# <treatment> Atorvastatin </treatment> 80 mg Tablet Sig : One ( 1 ) Tablet PO DAILY ( Daily ) .
# There are <problem> simple atheroma </problem> in the descending thoracic aorta .
# <test> Hematocrit </test> was 45 , <test> platelet count </test> 270 .
# <test> Her SBP </test> remained in the 160s-170s on hospital day 1 and she was gently diuresed .
# With the initiation of <treatment> caffeine therapy </treatment> the patient has had no more <problem> apnea </problem> or <problem> bradycardic events </problem> .
# <treatment> bisoprolol </treatment> 5 mg daily <treatment> crestor </treatment> 20 mg daily
# <treatment> HCTZ </treatment> 25 mg daily <treatment> lisinopril </treatment> 40 mg daily
# <problem> Afebrile </problem> the next day and <treatment> pacing wires </treatment> removed without incident .
# <problem> Hyperbilirubinemia </problem> .
# <treatment> His tracheostomy </treatment> was changed to <treatment> a 6 cuffless Shiley </treatment> on 2016-11-26 and <treatment> sutures </treatment> in place with <treatment> a 3-0 silk </treatment> .
# Extubated early the next morning and <treatment> chest tubes </treatment> removed .
# <problem> Small right pleural effusion </problem> is stable .
# <problem> Bibasilar minor atelectasis </problem> , worse on the right and improved on the left .
# He is due to have <test> his state screen </test> sent today .
# She was transferred to Charles River Hospital and was treated with <treatment> magnesium sulfate </treatment> and <treatment> betamethasone </treatment> .
# The patient was given <treatment> ASA </treatment> , <treatment> Plavix </treatment> , <treatment> heparin drip </treatment> x 24 hours , <treatment> nitro drip </treatment> , <treatment> atorvastatin </treatment> , <treatment> metoprolol </treatment> , and <treatment> lisinopril </treatment> .
# No <problem> atrial septal defect </problem> is seen by <test> 2D </test> or <test> color Doppler </test> .
# <test> His most recent bilirubin </test> was 6.6 on day of life six , the day of discharge , and <treatment> his phototherapy </treatment> was discontinued.
# The mitral valve leaflets are <problem> mildly thickened </problem> .
# He has not had his 06-10 dose .
# <problem> HTN </problem>
# <problem> Hearing difficulty </problem>
# <problem> Blindness </problem> 02-26 <problem> macular degeneration </problem>
# <problem> R ankle fx </problem> 2002
# S/p <treatment> hysterectomy </treatment>
# <test> T </test> 97.8 , <test> HR </test> 53 , <test> BP </test> 156/58 , <test> RR </test> 16 , <test> O2 sat </test> 94% on 2.5 L
# <problem> NAD </problem> , awake , alert , <problem> blind </problem> , able to hear loud voices at L ear
# <test> JVP </test> 11 cm
# Reg rate , nl S1 & S2 , no <problem> m/r/g </problem>
# <problem> Crackles at base and mid-lungs bilaterally </problem>
# Soft , <problem> NT </problem> , <problem> ND </problem> , BS present , no <problem> masses </problem>
# <problem> Trace ankle edema bilaterally </problem>
# <test> WBC </test> - 11.4* <test> RBC </test> - 3.61* <test> Hgb </test> - 11.4* <test> Hct </test> - 32.6* <test> MCV </test> - 90 <test> MCH </test> - 31.7
# <test> MCHC </test> - 35.1* <test> RDW </test> - 14.7 <test> Plt Ct </test> - 281
# <test> Glucose </test> - 124* <test> UreaN </test> - 30* <test> Creat </test> - 1.3* <test> Na </test> - 137 <test> K </test> - 4.2 <test> Cl </test> - 102 <test> HCO3 </test> - 27
# <test> AnGap </test> - 12
# <test> CK </test> ( <test> CPK </test> ) - 42 <test> cTropnT </test> - 0.07*
# <test> EKG </test> :
# <problem> sinus brady </problem> @ 48 bpm , LAD , <problem> LVH </problem> , <problem> RBBB </problem> , <problem> Q wave in I </problem> , <problem> ST depressions in V1-V4 </problem> , <problem> ST elevation in III </problem> , <problem> aVF </problem> , <problem> TWI in III </problem> , V5 .
# <test> Blood culture </test> was sent but he was never started on <treatment> antibiotics </treatment> .
# <treatment> The flap </treatment> was pink with <test> a strong Doppler signal </test> .
# <problem> Chest pain </problem>
# The patient is a 91 yo woman with h/o <problem> HTN </problem> who came from Bridgewater State Hospital Rehab with <problem> substernal chest pain </problem> after exercise .
# <test> Calcium </test> was 7.6 .
# <problem> Bilateral pleural effusions </problem> are unchanged .
# <test> Echo </test> :
# <test> LVEF </test> >70% , <test> LA </test> 6.1 cm , no <problem> regional wall motion abnormality </problem> .
# <treatment> Catheter </treatment> was removed .
# <test> Cardiac Enzymes </test>
# 2015-10-05 09:00PM <test> BLOOD </test>
# <test> CK </test> ( <test> CPK </test> ) - 1471* <test> CK-MB </test> - 207* <test> MB Indx </test> - 14.1* <test> cTropnT </test> - 6.00*
# 2015-10-06 04:47PM <test> BLOOD </test>
# <test> CK </test> ( <test> CPK </test> ) - 1288* <test> CK-MB </test> - 158* <test> MB Indx </test> - 12.3* <test> cTropnT </test> - 6.88*
# 2015-10-07 07:30AM <test> BLOOD </test>
# <test> CK </test> ( <test> CPK </test> ) - 627* <test> CK-MB </test> - 55* <test> MB Indx </test> - 8.8* <test> cTropnT </test> - 4.46*
# <test> Labs </test> on Discharge 2015-10-08 08:35AM
# <test> WBC </test> - 13.8* <test> RBC </test> - 3.39* <test> Hgb </test> - 10.7* <test> Hct </test> - 30.2* <test> MCV </test> - 89 <test> MCH </test> - 31.5
# <test> MCHC </test> - 35.3* <test> RDW </test> - 14.8 <test> Plt Ct </test> - 214
# <test> Glucose </test> - 120* <test> UreaN </test> - 30* <test> Creat </test> - 1.2* <test> Na </test> - 134 <test> K </test> - 4.2 <test> Cl </test> - 100 <test> HCO3 </test> - 25
# <test> AnGap </test> - 13
# <test> Calcium </test> - 8.7 <test> Phos </test> - 2.5* <test> Mg </test> - 2.1
# 90 year-old woman with h/o of <problem> HTN </problem> p/w <problem> substernal chest pain </problem> shortly after exercise at nursing home , with <test> EKG </test> showing <problem> ST depressions in V1-V4 </problem> and <test> troponin </test> 0.07.
# <treatment> Lasix </treatment> 40 mg Tablet Sig : One ( 1 ) Tablet PO once a day as needed for <problem> shortness of breath </problem> or <problem> wheezing </problem> :
# Can give 40 <treatment> lasix </treatment> PO if having any <problem> weight gain </problem> or <problem> shortness of breath </problem> .
# There is <problem> mild symmetric left ventricular hypertrophy </problem> .
# <problem> Resting regional wall motion abnormalities </problem> include <problem> mild inferior hypokinesis </problem> .
# """
#
# Clinical Text Input
# """
# ﻿Admission Date :
# 2012-10-31
# Discharge Date :
# 2012-11-07
# Date of Birth :
# 1941-03-23
# Sex :
# M
# Service :
# MEDICINE
# Allergies :
# Nsaids/Anti-Inflammatory Classifier / Vancomycin
# Attending :
# Kristie R. Hamby , M.D.
# Chief Complaint :
# CC : Antonio M. Z. Eddings , M.D.
# Major Surgical or Invasive Procedure :
# Mesenteric angiograpm w/ coil embolization of bleeding vessel .
# Sigmoidoscopy .
# Colonoscopy .
# History of Present Illness :
# HPI: Pt is a 71 y/o male with h/o dm2 , cad s/p cabg , DVT/PE on long term anti-coagulation , ulcerative colitis on Asacol presents with brbpr starting at 9am of the morning of admission .
# He 'd been having lower abdominal pain for approximately the past week , a symptom for which he 's been admitted in the past .
# His PCP had recently started ciprofloxacin for a UTI .
# At 9am the morning of admission he passed a large , bloody bowel movement and came to the Michael . There , his vitals were intially stable with a hct of 36.7 , though he was felt to be hypovolemic and this hemoconcentrated ; his previous hct was 39 about five months ago .
# He refused an NG lavage .
# Although an initial DRE showed only clot , he later passed a large , bloody bowel movement , and his bp nadired to the low 90's but rested there only transiently and easily rebounded to the 130's-140's with fluid ; he then went to angiography for a tagged RBC scan where they found and embolized two vessels to the sigmoid colon .
# His HCT had dropped from 36.7 to 30.8 despite 2U PRBC and 3 U FFP .
# Is called out of the FICU as has been been HD and stable HCT .
# Currently denies CP , SOB , abd pain or continued BRBPR .
# Past Medical History :
# PMH :
# 1.) DM-2
# 2.) CAD s/p 3v-CABG 2003 and subsequent stenting of SVG and LIMA
# 3.) CHF with EF 30-35% on 07-10 echo
# 4.) Right parietal intracranial bleeding following 1996 cardiac cath
# 5.) LBBB
# 6.) Sinus node dysfunction s/p pacemaker
# 7.) H/O DVT ( right sided ) and subsequent PE , put onto lifetime warfarin
# 8.) Ulcerative colitis
# PSH :
# 1.) C4-7 anterior discectomies
# 2.) CABG 2003
# 3.) R intracerebral hemorrhage drainage
# Social History :
# SocHx : Mr Peres generally lives with his wife but has spent a great deal of time recently at rehab .
# He has no h/o ETOH/IVDA but quit tob 15 years ago .
# Family History :
# Noncontributory .
# Physical Exam :
# VS 98.4 , 62 , 103/37 , 15 97%2L
# gen - lying in bed , NAD
# heent - anicteric sclera , op clear with mmm
# neck - jvd flat
# cv - rrr , s1s2 , no m/r/g
# pul - CTAB without rales
# abd - soft , minimally distended , nt , no rebound/guarding , nabs
# extrm - trace edema at ankles , no cyanosis , warm/dry
# Pertinent Results :
# 2012-10-31 05:47PM URINE
# COLOR - Straw APPEAR - Clear SP Marquez - 1.021
# 2012-10-31 05:47PM URINE
# BLOOD - LG NITRITE - NEG PROTEIN - NEG
# GLUCOSE - NEG KETONE - NEG BILIRUBIN - NEG UROBILNGN - NEG PH - 7.0 LEUK - NEG
# 2012-10-31 05:47PM URINE
# RBC-21-50* WBC-0-2 BACTERIA - FEW
# YEAST - NONE EPI - <1
# 2012-10-31 02:32PM
# LACTATE - 1.8
# 2012-10-31 12:20PM
# GLUCOSE - 197* UREA N-25* CREAT - 0.8 SODIUM - 141
# POTASSIUM - 3.7 CHLORIDE - 105 TOTAL CO2 - 22 ANION GAP - 18
# 2012-10-31 12:20PM
# WBC - 5.6 RBC - 4.35* HGB - 12.6* HCT - 36.7* MCV - 84
# MCH - 28.9 MCHC - 34.3 RDW - 15.7*
# 2012-10-31 12:20PM
# NEUTS - 80.5* LYMPHS - 13.1* MONOS - 3.5 EOS - 2.5
# BASOS - 0.4
# 2012-10-31 12:20PM
# POIKILOCY - 1+ MICROCYT - 1+
# 2012-10-31 12:20PM
# PLT COUNT - 102*
# 2012-10-31 12:20PM
# PT - 20.5* PTT - 29.4 INR(PT) - 3.0
# GI BLEEDING STUDY
# 2012-10-31
# IMPRESSION : Increased tracer activity demonstrated within the left lower quadrant , most likely sigmoid colonic loops of bowel , consistent with active bleeding .
# CT ABDOMEN W/CONTRAST
# 2012-10-31 3:27 PM
# IMPRESSION :
# 1. No evidence of colitis or other bowel pathology present to explain the patient 's bright red blood per rectum .
# 2. Stable appearance of left adrenal fat-containing lesion consistent with a myelolipoma .
# 3. Stable appearance of hypodense lesion within the caudate lobe of the liver , too small to fully characterize .
# 4. Subcentimeter attenuation lesion within the lower pole of the right kidney , too small to characterize .
# 5. 3-mm noncalcified pulmonary nodule within the right lower lobe .
# If the patient does not have a history of a primary malignancy , followup CT of the chest in 1 year is recommended to evaluate for stability of this finding .
# Brief Hospital Course :
# Initial A/P :
# 71 y/o male with dm2 , cad , chf , uc presents with one week of lower abdominal pain and 2 episodes of brpbr on the day of admission .
# # BRBPR -- The patient was in the intensive care unit given his lower GI bleed .
# An angiography showed bleeding in two vessels off of the Minnie supplying the sigmoid that were succesfully embolized .
# The patient was transfused from a Hct 29 to 34 on the day of discharge .
# His coumadin was held during his stay given his acute bleed but restarted per his PCP with the guidance of GI on the day of discharge .
# - The patient underwent a flex sigmoidoscopy on Friday , 11-02 , which showed old blood in the rectal vault but no active source of bleeding .
# Given this , it was advised that the patient have a colonoscopy to rule out further bleeding .
# - The patient had a colonoscopy on Monday 11-05 but unfortunately , was unable to complete the study as his bowel
# prep was inadequate .
# Therefore , he had a repeat colonoscopy on 11-06 which showed expected mucosal signs of moderate ulcerative colitis , no polyps , w/ 8 mm ulcer at junction of distal descending colon and sigmoid colon .
# - Biopsies were obtained during his colonoscopy and he should follow up with gastroenterology for the results .
# # Ulcerative colitis -- The patient 's Asacol was originally held but restarted the day prior to discharge per GI .
# # CAD/CHF - The patient was restarted on his home regimen prior to discharge as it was held temporarily given his acute GI bleed .
# The exception is that per his PCP , Jason aspirin will be held for 2 weeks given that he was restarted on coumadin with
# his risk of bleeding .
# # DM-2 -- The patient was maintained on his home insulin regimen .
# # h/o DVT/PE :
# Coumadin was initially held .
# It was unclear at first as to why the patient required life-long anticoagulation .
# After discussing this with his PCP , Leon was clear that the patient had had recurrent DVTs and ultimately a PE and his PCP felt strongly that he required long-term anticoagulation .
# His goal INR should be 1.6-2.0 . If bleeding continues to occur , consider V. Winchester filter .
# # Access -- 2 large bore PIV's
# # Code -- full
# Medications on Admission :
# Meds on Admission :
# 1.) Spironolactone/hctz 25/25 daily
# 2.) Atenolol 12.5mg daily
# 3.) Insulin 45N/8R qAM and 33N qPM
# 4.) Furosemide 10 mg every other day
# 5.) Aspirin 81 mg daily
# 6.) Zoloft 40 mg qAM
# 7.) Flomax
# 8.) Atorvastatin 40 mg daily
# 9.) Ritalin 20 mg daily
# 10.) Ramipril 2.5 mg daily
# 11.) Asacol 400 mg 3 , TID
# 12.) Carafate 1 gm bid
# 13.) Actos 15 mg daily
# 14.) Folate 1 mg daily
# 15.) Warfarin 2 mg daily
# Discharge Medications :
# 1. Tamsulosin 0.4 mg Capsule , Sust . Release 24HR Sig : One ( 1 ) Capsule , Sust . Release 24HR PO HS ( at bedtime ) .
# 2. Atorvastatin 40 mg Tablet Sig : One ( 1 ) Tablet PO DAILY ( Daily ) .
# 3. Methylphenidate 10 mg Tablet Sig : Two ( 2 ) Tablet PO DAILY ( Daily ) .
# 4. Acetaminophen 325 mg Tablet Sig : One ( 1 ) Tablet PO Q4-6H ( every 4 to 6 hours ) as needed .
# 5. Folic Acid 1 mg Tablet Sig : One ( 1 ) Tablet PO DAILY ( Daily ) .
# 6. Atenolol 25 mg Tablet Sig : 0.5 Tablet PO DAILY ( Daily ) .
# 7. Spironolactone 25 mg Tablet Sig : One ( 1 ) Tablet PO DAILY ( Daily ) .
# 8. Ramipril 1.25 mg Capsule Sig : Two ( 2 ) Capsule PO DAILY ( Daily ) .
# 9. Hydrochlorothiazide 25 mg Tablet Sig : One ( 1 ) Tablet PO DAILY ( Daily ) .
# 10. Pioglitazone 15 mg Tablet Sig : One ( 1 ) Tablet PO DAILY ( Daily ) as needed for DM .
# 11. Mesalamine 400 mg Tablet , Delayed Release ( E.C. ) Sig : Three ( 3 ) Tablet , Delayed Release ( E.C. ) PO TID ( 3 times a day ) as needed for ulcerative colitis w/o recent severe flares .
# 12. Insulin 45 NPH in am with 33 NPH at bedtime
# Continue Sliding scale insulin as needed .
# 13. Sertraline 20 mg/mL Concentrate Sig : Two ( 2 )  PO at bedtime .
# 14. Coumadin 2 mg Tablet Sig : One ( 1 ) Tablet PO once a day .
# Discharge Disposition :
# Extended Care
# Facility :
# Oak Bluffs Of Greenfield
# Discharge Diagnosis :
# Rectal bleeding from inferior mesenteric artery tributaries supplying sigmoid colon .
# Discharge Condition : Good .
# Discharge Instructions :
# Please call physician if you develop shortness of breath , weakness in your legs or arms , sudden blurry vision or slurred speech , chest pain , faintness , or significant unexplained weight loss .
# Followup Instructions :
# Provider : Lucio Y. Matthews , M.D. Phone : ( 967 ) 675 1641 Date/Time : 2012-12-28 2:30
# Provider :  Greg CLINIC Phone : ( 212 ) 442 0438 Date/Time : 2013-01-11 1:30
# Provider : Lucio F. R. Matthews , M.D. Phone : ( 967 ) 675 1641 Date/Time : 2013-01-11 2:00
# Please call White , Leslie L. at ( 602 ) 743 8709 to schedule an appointment with him in 1 week .
# Please call your gastroenterologist to schedule a follow up appointment in 2 weeks .
# Alan John MD 54-745
# Completed by : Bertha Janice Motta MD 52-860 2012-11-07 @ 1207
# Signed electronically by : DR. Melody PARKS on: WED 2012-11-21 6:22 PM
# ( End of Report )
# """

# %% [markdown]
# Prompt: Document Level

# %%
from pathlib import Path

# Path to the sample training file
sample_file_path = Path("../Data/processed/llm/all_sentences/train/record-13-llm.txt")

# Read and wrap with triple quotes
with open(sample_file_path, "r", encoding="utf-8") as f:
    sample_document = f.read().strip()

# print(sample_document)

# Define meaningful prompt parts
instruction = (
    "Your task is to extract entities from clinical text and categorize them into predefined labels "
    "based on their role in medical documentation."
)

source_info = (
    "The source text comes from Electronic Health Records (EHRs), which are digital versions of patients' medical histories, "
    "including diagnoses, medications, procedures, lab results, and physician notes."
)

category_definition = (
    "Entity Categories\n"
    "Each extracted entity should be classified into one of the following categories:\n"
    "Test: A diagnostic procedure, lab test, or medical examination performed to investigate or reveal a medical condition.\n"
    "Examples:\n"
    "entity=\"colonoscopy\" label=\"test\"\n"
    "entity=\"MRI scan\" label=\"test\"\n"
    "entity=\"blood glucose test\" label=\"test\"\n\n"
    "Treatment: A medication, procedure, or intervention administered to manage, improve, or prevent a medical problem.\n"
    "Examples:\n"
    "entity=\"ramipril\" label=\"treatment\"\n"
    "entity=\"chemotherapy\" label=\"treatment\"\n"
    "entity=\"insulin therapy\" label=\"treatment\"\n\n"
    "Problem: A medical condition, symptom, or diagnosis affecting a patient, which may require testing or treatment.\n"
    "Examples:\n"
    "entity=\"diabetes mellitus\" label=\"problem\"\n"
    "entity=\"chest pain\" label=\"problem\"\n"
    "entity=\"hypertension\" label=\"problem\""
)

output_format = (
    "Expected Output Format\n"
    "Entities should be extracted and presented in the following format:\n"
    "entity=\"<extracted medical entity>\" label=\"<assigned category>\""
)

uncertain_handling = (
    "Handling Uncertain Cases\n"
    "If an entity cannot be clearly classified as test, treatment, or problem based on the information provided, "
    "label it as:\n"
    "entity=\"<extracted medical entity>\" label=\"unknown\""
)

sample_training_document = (
    "Sample Training Clinical Document\n"
    "You will be given a cinical document that contains a set of clinical sentences enclosed within triple quotes (\"\"\" \"\"\"). "
    "Each sentence will contain medical entities, if present, tagged using angle brackets indicating their category: "
    "<test>, <treatment>, or <problem>. For example, a blood test would be written as <test> blood test </test>, and a condition like chest pain would appear as "
    "<problem> chest pain </problem>.\n\n"
    "Please note that:\n"
    "- Some sentences may not contain any identifiable medical entities.\n"
    "- Some sentences may contain multiple entities from different categories.\n\n"
    "These examples are provided to help the system understand how to identify and categorize entities. "
    "You should learn from these patterns and apply similar logic when extracting entities from new clinical text.\n\n"
    "Below is the content of clinical training document:\n"
    f"\"\"\"\n{sample_document}\n\"\"\""
)

triple_quote_note = (
    "Clinical Text Input\n"
    "Below, you will be given a clinical text document enclosed within triple quotes (\"\"\" \"\"\"). "
    "Your task is to extract relevant medical entities and assign them the appropriate labels based on the definitions provided above."
)

# Format with triple quotes
clinical_text = f'""" \n{clinical_text_content}\n"""'

# Combine all into one prompt
full_prompt = "\n\n".join([
    instruction,
    source_info,
    category_definition,
    output_format,
    uncertain_handling,
    triple_quote_note,
    sample_training_document, 
    f"Clinical Text Input\n{clinical_text}"  # ← actual test input
])



print(full_prompt)
# Out:
# Your task is to extract entities from clinical text and categorize them into predefined labels based on their role in medical documentation.
#
# The source text comes from Electronic Health Records (EHRs), which are digital versions of patients' medical histories, including diagnoses, medications, procedures, lab results, and physician notes.
#
# Entity Categories
# Each extracted entity should be classified into one of the following categories:
# Test: A diagnostic procedure, lab test, or medical examination performed to investigate or reveal a medical condition.
# Examples:
# entity="colonoscopy" label="test"
# entity="MRI scan" label="test"
# entity="blood glucose test" label="test"
#
# Treatment: A medication, procedure, or intervention administered to manage, improve, or prevent a medical problem.
# Examples:
# entity="ramipril" label="treatment"
# entity="chemotherapy" label="treatment"
# entity="insulin therapy" label="treatment"
#
# Problem: A medical condition, symptom, or diagnosis affecting a patient, which may require testing or treatment.
# Examples:
# entity="diabetes mellitus" label="problem"
# entity="chest pain" label="problem"
# entity="hypertension" label="problem"
#
# Expected Output Format
# Entities should be extracted and presented in the following format:
# entity="<extracted medical entity>" label="<assigned category>"
#
# Handling Uncertain Cases
# If an entity cannot be clearly classified as test, treatment, or problem based on the information provided, label it as:
# entity="<extracted medical entity>" label="unknown"
#
# Clinical Text Input
# Below, you will be given a clinical text document enclosed within triple quotes (""" """). Your task is to extract relevant medical entities and assign them the appropriate labels based on the definitions provided above.
#
# Sample Training Clinical Document
# You will be given a cinical document that contains a set of clinical sentences enclosed within triple quotes (""" """). Each sentence will contain medical entities, if present, tagged using angle brackets indicating their category: <test>, <treatment>, or <problem>. For example, a blood test would be written as <test> blood test </test>, and a condition like chest pain would appear as <problem> chest pain </problem>.
#
# Please note that:
# - Some sentences may not contain any identifiable medical entities.
# - Some sentences may contain multiple entities from different categories.
#
# These examples are provided to help the system understand how to identify and categorize entities. You should learn from these patterns and apply similar logic when extracting entities from new clinical text.
#
# Below is the content of clinical training document:
# """
# Admission Date :
# 2018-10-25
# Discharge Date :
# 2018-10-31
# Date of Birth :
# 1951-06-15
# Sex :
# M
# Service :
# CARDIOTHORACIC
# Allergies :
# Patient recorded as having No <problem> Known Allergies </problem> to <treatment> Drugs </treatment>
# Attending : Michael D. Christensen , M.D.
# Chief Complaint :
# <problem> Shortness of Breath </problem>
# Major Surgical or Invasive Procedure :
# <treatment> Coronary Artery Bypass Graft </treatment> x3 ( <treatment> Left internal mammary -> left anterior descending </treatment> , <treatment> saphaneous vein graft -> obtuse marginal </treatment> , <treatment> saphaneous vein graft -> posterior descending artery </treatment> ) 2018-10-25
# History of Present Illness :
# 67 y/o male with <problem> worsening shortness of breath. </problem> Had <problem> abnormal ETT </problem> and referred for <test> cath </test> .
# <test> Cath </test> revealed <problem> severe 3 vessel disease </problem> .
# Then referred for <treatment> surgical intervention </treatment> .
# Past Medical History :
# <problem> Carpal tunnel syndrome </problem> , <problem> Hypertension </problem> , <problem> Hyperlipidemia </problem> , <problem> Arthritis </problem> , h/o <problem> Bell's Palsy </problem> , <problem> HOH </problem> , s/p <treatment> Tonsillectomy </treatment>
# Social History :
# Denies ETOH , rare Tobacco .
# Electrician .
# Family History :
# Father with <problem> MI </problem> in 50 's and underwent <treatment> CABG </treatment> .
# Physical Exam :
# <test> VS </test> : 65 20 160/100 5 ' 7 " 180 #
# General : WD/WN male in <problem> NAD </problem>
# HEENT : EOMI , PERRL , <problem> NC/AT </problem>
# Neck : Supple , FROM , - <problem> JVD </problem> , - <problem> carotid bruits </problem>
# Chest : CTAB - <problem> w/r/r </problem>
# Heart : RRR - <problem> c/r/m/g </problem>
# Abd : Soft , <problem> NT/ND </problem> +BS
# Ext : Warm , well-perfused - <problem> edema </problem> , - <problem> varicosities </problem>
# Neuro : A&Ox3 , MAE , non-focal
# Pertinent Results :
# <test> Echo </test> 10-25 : PRE-BYPASS : <test> Left ventricular wall thicknesses </test> are normal .
# <test> The left ventricular cavity size </test> is normal .
# There is <problem> mild inferior wall hypokinesis </problem> .
# There is <problem> akinesis </problem> / <problem> dyskinesis </problem> and <problem> thinning of the mid to distal inferior septum </problem> and the apex .
# <test> Overall left ventricular systolic function </test> is <problem> mildly depressed </problem> .
# <test> Right ventricular chamber size </test> and <test> free wall motion </test> are normal .
# The descending thoracic aorta is <problem> mildly dilated </problem> .
# There are <problem> simple atheroma in the descending thoracic aorta </problem> .
# There are three aortic valve leaflets .
# There is no <problem> aortic valve stenosis </problem> .
# No <problem> aortic regurgitation </problem> is seen .
# The mitral valve leaflets are <problem> mildly thickened </problem> .
# <problem> Trivial mitral regurgitation </problem> is seen .
# <treatment> POST-BYPASS </treatment> : <test> LV and RV function </test> is unchanged .
# Aorta is unchanged .
# Other findings are unchanged .
# <test> CXR </test> 10-30 : <problem> Left lower lobe atelectasis </problem> has partially cleared .
# Upper lungs are clear .
# <problem> Mild postoperative widening of the cardiomediastinal silhouette </problem> is stable .
# No <problem> pneumothorax </problem> .
# 2018-10-25 11:15 AM <test> BLOOD </test> <test> WBC </test> - 18.3 *# <test> RBC </test> - 3.42 * <test> Hgb </test> - 10.9 * <test> Hct </test> - 31.6 * <test> MCV </test> - 92 <test> MCH </test> - 31.7 <test> MCHC </test> - 34.4 <test> RDW </test> - 13.3 <test> Plt Ct </test> - 134 *
# 2018-10-31 06:25 AM <test> BLOOD </test> <test> WBC </test> - 13.6 * <test> RBC </test> - 2.72 * <test> Hgb </test> - 8.6 * <test> Hct </test> - 24.6 * <test> MCV </test> - 91 <test> MCH </test> - 31.7 <test> MCHC </test> - 35.0 <test> RDW </test> - 14.0 <test> Plt Ct </test> - 314
# 2018-10-25 11:15 AM <test> BLOOD </test> <test> PT </test> - 13.3 * <test> PTT </test> - 30.0 <test> INR(PT) </test> - 1.2 *
# 2018-10-29 06:50 AM <test> BLOOD </test> <test> PT </test> - 11.9 <test> INR(PT) </test> - 1.0
# 2018-10-25 12:36 PM <test> BLOOD </test> <test> UreaN </test> - 17 <test> Creat </test> - 0.7 <test> Cl </test> - 111 * <test> HCO3 </test> - 23
# 2018-10-31 06:25 AM <test> BLOOD </test> <test> Glucose </test> - 91 <test> UreaN </test> - 19 <test> Creat </test> - 0.8 <test> Na </test> - 134 <test> K </test> - 4.0 <test> Cl </test> - 98 <test> HCO3 </test> - 26 <test> AnGap </test> - 14
# Brief Hospital Course :
# Mr. Kammerer was a same day admit and on 10-25 was brought to the operating room where he underwent <treatment> a coronary artery bypass graft </treatment> x 3 .
# Please see operative report for surgical details .
# He tolerated <treatment> the procedure </treatment> well and was transferred to the CSRU for <test> invasive monitoring </test> in stable condition .
# Later on op day he was weaned from <treatment> sedation </treatment> , awoke neurologically intact , and
# extubated .
# <treatment> Beta blockers </treatment> and <treatment> diuretics </treatment> were initiated on post-op day one .
# He was <treatment> diuresed </treatment> towards <test> his pre-op weight </test> .
# He appeared to be doing well and was transferred to the SDU on this day .
# He did have <problem> burst of atrial fibrillation </problem> and was started on <treatment> a Amiodarone gtt </treatment> .
# <treatment> His beta blockers </treatment> were also titrated for <treatment> maximal BP and HR control </treatment> .
# <treatment> Chest tubes </treatment> were removed on post-op day two and <treatment> epicardial pacing wires </treatment> on post-op day three .
# Over the next several days he continued to improve his ambulation and mobility with <treatment> physical therapy </treatment> .
# He had no <problem> further episodes of AFIB </problem> while on <treatment> po Amiodarone </treatment> .
# On post-op day five he appeared to have <problem> left arm phlebitis </problem> and was started on <treatment> antibiotics </treatment> .
# He was discharged home on post-op day six with <treatment> antibiotics </treatment> and <treatment> appropriate meds </treatment> .
# He will have <treatment> VNA services </treatment> and make the appropriate follow-up appointments .
# Medications on Admission :
# <treatment> Aspirin </treatment> 81 mg qd , <treatment> Toprol </treatment> XL 50 mg qd , <treatment> MVI </treatment> , <treatment> Flexeril </treatment> 10 mg qhs , <treatment> Plavix </treatment> 75 mg qd ( last on 10-18 )
# Discharge Medications :
# 1. <treatment> Docusate Sodium </treatment> 100 mg Capsule Sig : One ( 1 ) Capsule PO BID ( 2 times a day ).
# Disp :* 60 Capsule (s)* Refills :* 0 *
# 2. <treatment> Aspirin </treatment> 81 mg Tablet , Delayed Release ( E.C. ) Sig : One ( 1 ) Tablet , Delayed Release ( E.C. ) PO DAILY ( Daily ).
# Disp:* 30 Tablet , Delayed Release ( E.C. )(s)* Refills :* 0 *
# 3. <treatment> Ranitidine HCl </treatment> 150 mg Tablet Sig : One ( 1 ) Tablet PO BID ( 2 times a day ).
# Disp :* 60 Tablet (s)* Refills :* 0 *
# 4. <treatment> Oxycodone - Acetaminophen </treatment> 5-325 mg Tablet Sig : 1-2 Tablets PO Q4H ( every 4 hours ) as needed for <problem> pain </problem> .
# Disp :* 40 Tablet (s)* Refills :* 0 *
# 5. <treatment> Atorvastatin </treatment> 10 mg Tablet Sig : One ( 1 ) Tablet PO DAILY ( Daily ).
# Disp :* 30 Tablet (s)* Refills :* 0 *
# 6. <treatment> Amiodarone </treatment> 200 mg Tablet Sig : Two ( 2 ) Tablet PO BID ( 2 times a day ): please take 400 mg twice a day until 11-02 then decrease to 400 mg once a day for 1 week and then decrease to 200 mg once a day .
# Disp :* 40 Tablet (s)* Refills :* 0 *
# 7. <treatment> Metoprolol Succinate </treatment> 50 mg Tablet Sustained Release 24 HR Sig : One ( 1 ) Tablet Sustained Release 24 HR PO DAILY ( Daily ).
# Disp :* 30 Tablet Sustained Release 24 HR (s)* Refills :* 0 *
# 8. <treatment> Ferrous Gluconate </treatment> 300 mg Tablet Sig : One ( 1 ) Tablet PO DAILY ( Daily ).
# Disp :* 30 Tablet (s)* Refills :* 0 *
# 9. <treatment> Ascorbic Acid </treatment> 500 mg Tablet Sig : One ( 1 ) Tablet PO BID ( 2 times a day ).
# Disp :* 60 Tablet (s)* Refills :* 0 *
# 10. <treatment> Cephalexin </treatment> 500 mg Capsule Sig : One ( 1 ) Capsule PO Q6H ( every 6 hours ) for 6 days : please complete full course .
# Disp :* 24 Capsule (s)* Refills :* 0 *
# 11. <treatment> Furosemide </treatment> 20 mg Tablet Sig : One ( 1 ) Tablet PO once a day for 2 weeks .
# Disp :* 14 Tablet (s)* Refills :* 0 *
# 12. <treatment> Potassium Chloride </treatment> 10 mEq Capsule , Sustained Release Sig : One ( 1 ) Capsule , Sustained Release PO DAILY ( Daily ) for 2 weeks .
# Disp :* 14 Capsule , Sustained Release (s)* Refills :* 0 *
# 13. <treatment> Lisinopril </treatment> 5 mg Tablet Sig : 0.5 Tablet PO DAILY ( Daily ).
# Disp :* 15 Tablet (s)* Refills :* 0 *
# Discharge Disposition :
# Home with Service
# Discharge Diagnosis :
# <problem> Coronary artery disease </problem> s/p <treatment> Coronary Artery Bypass Graft </treatment> x3
# PMH : <problem> Carpal tunnel syndrome </problem> , <problem> Hypertension </problem> , <problem> Hyperlipidemia </problem> , <problem> Arthritis </problem>
# Discharge Condition :
# good
# Discharge Instructions :
# May shower , no baths or swimming
# Monitor <problem> wounds </problem> for <problem> infection </problem> - <problem> redness </problem> , <problem> drainage </problem> , or <problem> increased pain </problem>
# Report <problem> any fever greater than 101 </problem>
# Report <problem> any weight gain </problem> of greater than 2 pounds in 24 hours or 5 pounds in a week
# No <treatment> creams </treatment> , <treatment> lotions </treatment> , <treatment> powders </treatment> , or <treatment> ointments </treatment> to <problem> incisions </problem>
# No driving for approximately one month
# No lifting more than 10 pounds for 10 weeks
# Please call with any questions or concerns
# Left Arm continue with <treatment> elevation </treatment> , <treatment> ice </treatment> , and complete <treatment> all antibiotics </treatment>
# Followup Instructions :
# Dr Day in 4 weeks (( 469 ) 587-0462 ) please call for appointment
# Dr Miller in 1 week ( 262-575-0600 ) please call for appointment
# Dr Scott Raines in 2-3 weeks please call for appointment
# Wound check appointment 4 East as instructed by nurse ( 280-5326 )
# For <problem> surgical incision </problem> and left arm
# Craig Douglas MD 10-898
# Completed by : Reyes Marengo PA 80 - BMD 2018-11-19 @ 1536
# Signed electronically by : DR. Jeffrey Collins on : WED 2018-11-21 9:28 AM
# ( End of Report )
# """
#
# Clinical Text Input
# """
# ﻿Admission Date :
# 2012-10-31
# Discharge Date :
# 2012-11-07
# Date of Birth :
# 1941-03-23
# Sex :
# M
# Service :
# MEDICINE
# Allergies :
# Nsaids/Anti-Inflammatory Classifier / Vancomycin
# Attending :
# Kristie R. Hamby , M.D.
# Chief Complaint :
# CC : Antonio M. Z. Eddings , M.D.
# Major Surgical or Invasive Procedure :
# Mesenteric angiograpm w/ coil embolization of bleeding vessel .
# Sigmoidoscopy .
# Colonoscopy .
# History of Present Illness :
# HPI: Pt is a 71 y/o male with h/o dm2 , cad s/p cabg , DVT/PE on long term anti-coagulation , ulcerative colitis on Asacol presents with brbpr starting at 9am of the morning of admission .
# He 'd been having lower abdominal pain for approximately the past week , a symptom for which he 's been admitted in the past .
# His PCP had recently started ciprofloxacin for a UTI .
# At 9am the morning of admission he passed a large , bloody bowel movement and came to the Michael . There , his vitals were intially stable with a hct of 36.7 , though he was felt to be hypovolemic and this hemoconcentrated ; his previous hct was 39 about five months ago .
# He refused an NG lavage .
# Although an initial DRE showed only clot , he later passed a large , bloody bowel movement , and his bp nadired to the low 90's but rested there only transiently and easily rebounded to the 130's-140's with fluid ; he then went to angiography for a tagged RBC scan where they found and embolized two vessels to the sigmoid colon .
# His HCT had dropped from 36.7 to 30.8 despite 2U PRBC and 3 U FFP .
# Is called out of the FICU as has been been HD and stable HCT .
# Currently denies CP , SOB , abd pain or continued BRBPR .
# Past Medical History :
# PMH :
# 1.) DM-2
# 2.) CAD s/p 3v-CABG 2003 and subsequent stenting of SVG and LIMA
# 3.) CHF with EF 30-35% on 07-10 echo
# 4.) Right parietal intracranial bleeding following 1996 cardiac cath
# 5.) LBBB
# 6.) Sinus node dysfunction s/p pacemaker
# 7.) H/O DVT ( right sided ) and subsequent PE , put onto lifetime warfarin
# 8.) Ulcerative colitis
# PSH :
# 1.) C4-7 anterior discectomies
# 2.) CABG 2003
# 3.) R intracerebral hemorrhage drainage
# Social History :
# SocHx : Mr Peres generally lives with his wife but has spent a great deal of time recently at rehab .
# He has no h/o ETOH/IVDA but quit tob 15 years ago .
# Family History :
# Noncontributory .
# Physical Exam :
# VS 98.4 , 62 , 103/37 , 15 97%2L
# gen - lying in bed , NAD
# heent - anicteric sclera , op clear with mmm
# neck - jvd flat
# cv - rrr , s1s2 , no m/r/g
# pul - CTAB without rales
# abd - soft , minimally distended , nt , no rebound/guarding , nabs
# extrm - trace edema at ankles , no cyanosis , warm/dry
# Pertinent Results :
# 2012-10-31 05:47PM URINE
# COLOR - Straw APPEAR - Clear SP Marquez - 1.021
# 2012-10-31 05:47PM URINE
# BLOOD - LG NITRITE - NEG PROTEIN - NEG
# GLUCOSE - NEG KETONE - NEG BILIRUBIN - NEG UROBILNGN - NEG PH - 7.0 LEUK - NEG
# 2012-10-31 05:47PM URINE
# RBC-21-50* WBC-0-2 BACTERIA - FEW
# YEAST - NONE EPI - <1
# 2012-10-31 02:32PM
# LACTATE - 1.8
# 2012-10-31 12:20PM
# GLUCOSE - 197* UREA N-25* CREAT - 0.8 SODIUM - 141
# POTASSIUM - 3.7 CHLORIDE - 105 TOTAL CO2 - 22 ANION GAP - 18
# 2012-10-31 12:20PM
# WBC - 5.6 RBC - 4.35* HGB - 12.6* HCT - 36.7* MCV - 84
# MCH - 28.9 MCHC - 34.3 RDW - 15.7*
# 2012-10-31 12:20PM
# NEUTS - 80.5* LYMPHS - 13.1* MONOS - 3.5 EOS - 2.5
# BASOS - 0.4
# 2012-10-31 12:20PM
# POIKILOCY - 1+ MICROCYT - 1+
# 2012-10-31 12:20PM
# PLT COUNT - 102*
# 2012-10-31 12:20PM
# PT - 20.5* PTT - 29.4 INR(PT) - 3.0
# GI BLEEDING STUDY
# 2012-10-31
# IMPRESSION : Increased tracer activity demonstrated within the left lower quadrant , most likely sigmoid colonic loops of bowel , consistent with active bleeding .
# CT ABDOMEN W/CONTRAST
# 2012-10-31 3:27 PM
# IMPRESSION :
# 1. No evidence of colitis or other bowel pathology present to explain the patient 's bright red blood per rectum .
# 2. Stable appearance of left adrenal fat-containing lesion consistent with a myelolipoma .
# 3. Stable appearance of hypodense lesion within the caudate lobe of the liver , too small to fully characterize .
# 4. Subcentimeter attenuation lesion within the lower pole of the right kidney , too small to characterize .
# 5. 3-mm noncalcified pulmonary nodule within the right lower lobe .
# If the patient does not have a history of a primary malignancy , followup CT of the chest in 1 year is recommended to evaluate for stability of this finding .
# Brief Hospital Course :
# Initial A/P :
# 71 y/o male with dm2 , cad , chf , uc presents with one week of lower abdominal pain and 2 episodes of brpbr on the day of admission .
# # BRBPR -- The patient was in the intensive care unit given his lower GI bleed .
# An angiography showed bleeding in two vessels off of the Minnie supplying the sigmoid that were succesfully embolized .
# The patient was transfused from a Hct 29 to 34 on the day of discharge .
# His coumadin was held during his stay given his acute bleed but restarted per his PCP with the guidance of GI on the day of discharge .
# - The patient underwent a flex sigmoidoscopy on Friday , 11-02 , which showed old blood in the rectal vault but no active source of bleeding .
# Given this , it was advised that the patient have a colonoscopy to rule out further bleeding .
# - The patient had a colonoscopy on Monday 11-05 but unfortunately , was unable to complete the study as his bowel
# prep was inadequate .
# Therefore , he had a repeat colonoscopy on 11-06 which showed expected mucosal signs of moderate ulcerative colitis , no polyps , w/ 8 mm ulcer at junction of distal descending colon and sigmoid colon .
# - Biopsies were obtained during his colonoscopy and he should follow up with gastroenterology for the results .
# # Ulcerative colitis -- The patient 's Asacol was originally held but restarted the day prior to discharge per GI .
# # CAD/CHF - The patient was restarted on his home regimen prior to discharge as it was held temporarily given his acute GI bleed .
# The exception is that per his PCP , Jason aspirin will be held for 2 weeks given that he was restarted on coumadin with
# his risk of bleeding .
# # DM-2 -- The patient was maintained on his home insulin regimen .
# # h/o DVT/PE :
# Coumadin was initially held .
# It was unclear at first as to why the patient required life-long anticoagulation .
# After discussing this with his PCP , Leon was clear that the patient had had recurrent DVTs and ultimately a PE and his PCP felt strongly that he required long-term anticoagulation .
# His goal INR should be 1.6-2.0 . If bleeding continues to occur , consider V. Winchester filter .
# # Access -- 2 large bore PIV's
# # Code -- full
# Medications on Admission :
# Meds on Admission :
# 1.) Spironolactone/hctz 25/25 daily
# 2.) Atenolol 12.5mg daily
# 3.) Insulin 45N/8R qAM and 33N qPM
# 4.) Furosemide 10 mg every other day
# 5.) Aspirin 81 mg daily
# 6.) Zoloft 40 mg qAM
# 7.) Flomax
# 8.) Atorvastatin 40 mg daily
# 9.) Ritalin 20 mg daily
# 10.) Ramipril 2.5 mg daily
# 11.) Asacol 400 mg 3 , TID
# 12.) Carafate 1 gm bid
# 13.) Actos 15 mg daily
# 14.) Folate 1 mg daily
# 15.) Warfarin 2 mg daily
# Discharge Medications :
# 1. Tamsulosin 0.4 mg Capsule , Sust . Release 24HR Sig : One ( 1 ) Capsule , Sust . Release 24HR PO HS ( at bedtime ) .
# 2. Atorvastatin 40 mg Tablet Sig : One ( 1 ) Tablet PO DAILY ( Daily ) .
# 3. Methylphenidate 10 mg Tablet Sig : Two ( 2 ) Tablet PO DAILY ( Daily ) .
# 4. Acetaminophen 325 mg Tablet Sig : One ( 1 ) Tablet PO Q4-6H ( every 4 to 6 hours ) as needed .
# 5. Folic Acid 1 mg Tablet Sig : One ( 1 ) Tablet PO DAILY ( Daily ) .
# 6. Atenolol 25 mg Tablet Sig : 0.5 Tablet PO DAILY ( Daily ) .
# 7. Spironolactone 25 mg Tablet Sig : One ( 1 ) Tablet PO DAILY ( Daily ) .
# 8. Ramipril 1.25 mg Capsule Sig : Two ( 2 ) Capsule PO DAILY ( Daily ) .
# 9. Hydrochlorothiazide 25 mg Tablet Sig : One ( 1 ) Tablet PO DAILY ( Daily ) .
# 10. Pioglitazone 15 mg Tablet Sig : One ( 1 ) Tablet PO DAILY ( Daily ) as needed for DM .
# 11. Mesalamine 400 mg Tablet , Delayed Release ( E.C. ) Sig : Three ( 3 ) Tablet , Delayed Release ( E.C. ) PO TID ( 3 times a day ) as needed for ulcerative colitis w/o recent severe flares .
# 12. Insulin 45 NPH in am with 33 NPH at bedtime
# Continue Sliding scale insulin as needed .
# 13. Sertraline 20 mg/mL Concentrate Sig : Two ( 2 )  PO at bedtime .
# 14. Coumadin 2 mg Tablet Sig : One ( 1 ) Tablet PO once a day .
# Discharge Disposition :
# Extended Care
# Facility :
# Oak Bluffs Of Greenfield
# Discharge Diagnosis :
# Rectal bleeding from inferior mesenteric artery tributaries supplying sigmoid colon .
# Discharge Condition : Good .
# Discharge Instructions :
# Please call physician if you develop shortness of breath , weakness in your legs or arms , sudden blurry vision or slurred speech , chest pain , faintness , or significant unexplained weight loss .
# Followup Instructions :
# Provider : Lucio Y. Matthews , M.D. Phone : ( 967 ) 675 1641 Date/Time : 2012-12-28 2:30
# Provider :  Greg CLINIC Phone : ( 212 ) 442 0438 Date/Time : 2013-01-11 1:30
# Provider : Lucio F. R. Matthews , M.D. Phone : ( 967 ) 675 1641 Date/Time : 2013-01-11 2:00
# Please call White , Leslie L. at ( 602 ) 743 8709 to schedule an appointment with him in 1 week .
# Please call your gastroenterologist to schedule a follow up appointment in 2 weeks .
# Alan John MD 54-745
# Completed by : Bertha Janice Motta MD 52-860 2012-11-07 @ 1207
# Signed electronically by : DR. Melody PARKS on: WED 2012-11-21 6:22 PM
# ( End of Report )
# """

# %% [markdown]
# Prompt: Entity-Seen

# %%
from pathlib import Path

# Path to the sample training file
sample_file_path = Path("../Data/processed/llm/entity_only/train/all_entities_small.txt")

# Read and wrap with triple quotes
with open(sample_file_path, "r", encoding="utf-8") as f:
    all_entity_list = f.read().strip()

# print(all_entity_list)

# Define meaningful prompt parts
instruction = (
    "Your task is to extract entities from clinical text and categorize them into predefined labels "
    "based on their role in medical documentation."
)

source_info = (
    "The source text comes from Electronic Health Records (EHRs), which are digital versions of patients' medical histories, "
    "including diagnoses, medications, procedures, lab results, and physician notes."
)

category_definition = (
    "Entity Categories\n"
    "Each extracted entity should be classified into one of the following categories:\n"
    "Test: A diagnostic procedure, lab test, or medical examination performed to investigate or reveal a medical condition.\n"
    "Examples:\n"
    "entity=\"colonoscopy\" label=\"test\"\n"
    "entity=\"MRI scan\" label=\"test\"\n"
    "entity=\"blood glucose test\" label=\"test\"\n\n"
    "Treatment: A medication, procedure, or intervention administered to manage, improve, or prevent a medical problem.\n"
    "Examples:\n"
    "entity=\"ramipril\" label=\"treatment\"\n"
    "entity=\"chemotherapy\" label=\"treatment\"\n"
    "entity=\"insulin therapy\" label=\"treatment\"\n\n"
    "Problem: A medical condition, symptom, or diagnosis affecting a patient, which may require testing or treatment.\n"
    "Examples:\n"
    "entity=\"diabetes mellitus\" label=\"problem\"\n"
    "entity=\"chest pain\" label=\"problem\"\n"
    "entity=\"hypertension\" label=\"problem\""
)

output_format = (
    "Expected Output Format\n"
    "Entities should be extracted and presented in the following format:\n"
    "entity=\"<extracted medical entity>\" label=\"<assigned category>\""
)

uncertain_handling = (
    "Handling Uncertain Cases\n"
    "If an entity cannot be clearly classified as test, treatment, or problem based on the information provided, "
    "label it as:\n"
    "entity=\"<extracted medical entity>\" label=\"unknown\""
)



triple_quote_note = (sample_training_entity_all = (
    "Sample Training Entities\n"
    "You will be given a list of sample entities enclosed within triple quotes (\"\"\" \"\"\"). "
    "You will find the list of test, treatment, and problem entities.\n\n"
    "These examples serve as a training guide and should help the system understand how medical terms are categorized based on their role in clinical documentation.\n"
    "You should use these examples to infer how to extract and label entities from the testing clinical text.\n\n"
    "Below is the list of training entities enclosed into square bracket. Each entity is comma separated.:\n"
    f"\"\"\"\n{all_entity_list}\n\"\"\""
)
    "Clinical Text Input\n"
    "Below, you will be given a clinical text document enclosed within triple quotes (\"\"\" \"\"\"). "
    "Your task is to extract relevant medical entities and assign them the appropriate labels based on the definitions provided above."
)

# Format with triple quotes
clinical_text = f'""" \n{clinical_text_content}\n"""'

# Combine all into one prompt
full_prompt = "\n\n".join([
    instruction,
    source_info,
    category_definition,
    output_format,
    uncertain_handling,
    triple_quote_note,
    sample_training_entity_all, 
    f"Clinical Text Input\n{clinical_text}"  # ← actual test input
])



print(full_prompt)
# Out:
# Your task is to extract entities from clinical text and categorize them into predefined labels based on their role in medical documentation.
#
# The source text comes from Electronic Health Records (EHRs), which are digital versions of patients' medical histories, including diagnoses, medications, procedures, lab results, and physician notes.
#
# Entity Categories
# Each extracted entity should be classified into one of the following categories:
# Test: A diagnostic procedure, lab test, or medical examination performed to investigate or reveal a medical condition.
# Examples:
# entity="colonoscopy" label="test"
# entity="MRI scan" label="test"
# entity="blood glucose test" label="test"
#
# Treatment: A medication, procedure, or intervention administered to manage, improve, or prevent a medical problem.
# Examples:
# entity="ramipril" label="treatment"
# entity="chemotherapy" label="treatment"
# entity="insulin therapy" label="treatment"
#
# Problem: A medical condition, symptom, or diagnosis affecting a patient, which may require testing or treatment.
# Examples:
# entity="diabetes mellitus" label="problem"
# entity="chest pain" label="problem"
# entity="hypertension" label="problem"
#
# Expected Output Format
# Entities should be extracted and presented in the following format:
# entity="<extracted medical entity>" label="<assigned category>"
#
# Handling Uncertain Cases
# If an entity cannot be clearly classified as test, treatment, or problem based on the information provided, label it as:
# entity="<extracted medical entity>" label="unknown"
#
# Clinical Text Input
# Below, you will be given a clinical text document enclosed within triple quotes (""" """). Your task is to extract relevant medical entities and assign them the appropriate labels based on the definitions provided above.
#
# Sample Training Entities
# You will be given a list of sample entities enclosed within triple quotes (""" """). You will find the list of test, treatment, and problem entities.
#
# These examples serve as a training guide and should help the system understand how medical terms are categorized based on their role in clinical documentation.
# You should use these examples to infer how to extract and label entities from the testing clinical text.
#
# Below is the list of training entities enclosed into square bracket. Each entity is comma separated.:
# """
# problem = ["+ blood cultures", "+distension", "+loc", "+s3", "02 requirement", "1+ edema bilaterally", "1+ le edema", "1+ lower extremity edema", "1+ mitral regurgitation", "1-vessel disease", "10/10 substernal chest pain", "100% occlusion of the proximal left anterior descending artery", "11% bandemia", "1st deg block", "2 vessel cord", "2+ edema both upper extremities", "2+ pitting edema bilateral le", "2+ pitting edema to knees b/l", "2-pillow orthopnea", "2/6 systolic murmur at lusb", "2/6 systolic murmur radiating to axilla", "3+ tricuspid regurgitation", "3/6 systolic ejection murmur", "4 mm left upper lobe lung nodule", "5 cm circular full thickness defect", "5 cores of varices", "50% stenosis d1", "50% stenosis of first diagonal", "60-69% stenosis of the right internal carotid artery", "70% stenoses of the left circumflex and oblique marginal artery", "80 percent mid lad lesion", "80% lm lesion", "80% stenosis of the mid left anterior descending", "80-99% stenosis of the left internal carotid artery", "90% stenosis of the posterior descending artery", "99% stenosis", "a 1-2/6 holosystolic murmur", "a 1.5 cm diameter hyperdense mass in the pons", "a 1.8 cm exophytic renal cyst", "a 10 pound weight gain", "a 3 cm laceration in the lower leg", "a 5 cm laceration", "a 90% lesion", "a 95% stenosis", "a bacterial pna", "a band-like opacity in the left lower lobe", "a bandemia", "a baseline renal insufficiency", "a bile leak", "a bile leak at the duct of luschka", "a bile leak from the duct of luschka", "a bleed from femoral access site", "a bleeding source in your colon", "a breech presentation", "a change in mental status", "a chf exacerbation", "a chronic problem", "a clot", "a coloboma", "a colovesicular fistula", "a complex plaque", "a complication", "a confirmatory elevation", "a cystic lesion", "a decreased and sluggish flow within the right and left hepatic veins", "a definitive epidural abscess", "a depressed respiratory drive", "a dilated aortic root", "a dilated common bile duct", "a distal stricture of the common bile duct", "a documented alpha streptococcal septicemia", "a dry cough", "a fever", "a fib", "a forming pseudocyst", "a fracture of the proximal right humerus", "a headache", "a hematoma", "a high co", "a hip and arm fracture", "a iii/vi systolic ejection murmur", "a keyhole appearance", "a large omental mass", "a large pericardial effusion", "a large right and small left pleural effusion", "a larger cystic lesion in the tail of the pancreas", "a leak from relaford pouch", "a left clavicular deformity", "a left facial mass", "a left frontal headache", "a left humeral fracuture", "a left occipital scalp contusion", "a left pleural effusion", "a left shoulder fracture", "a linear nondepressed right temporal calvarial fracture", "a linear right temporal calvarial fracture", "a little bit icteric", "a little bit out of it", "a long lad lesion", "a long nipple like papilla", "a low hct", "a mass in the right pelvis", "a mechanical fall", "a meniscal tear", "a mid rca lesion of 80-90%", "a mild cough", "a mild left pronator drift", "a mildly dilated ascending aorta", "a mildly dilated left atrium", "a mildly widened right palpable fissure", "a minor stepoff", "a moderately dilated aortic root", "a more pervasive process", "a multifocal pneumonic process", "a murmur", "a myocardial infarction", "a new fever", "a new humerus fracture distal to the hardware", "a non specific dysfunction in midline structures", "a non-displaced comminuted fracture of the proximal fibular diaphysis", "a non-q wave myocardial infarction", "a non-st elevation mi", "a partial biliary obstruction", "a patchy area of increased opacity", "a pe", "a pea arrest", "a pelvic fracture", "a persistent acidemia", "a persistent cough", "a persistent flow", "a pins and needle feeling in the face , hands and feet bilaterally", "a pna", "a pneumonia", "a positive exercise tolerance test", "a posterior scalp laceration", "a preexisting alkalosis", " ...
#
# test = ["2 echocardiograms", "2+ dp pulses bilaterally", "2+ femoral pulses", "25 polys", "2d", "a b/l creatinine", "a bedside echocardiogram", "a bedside transthoracic echocardiogram", "a blood culture", "a bnp", "a bone biopsy", "a car seat positioning test", "a cardiac cath", "a cardiac catheterization", "a cardiac output index", "a cardiopulmonary monitor", "a cbc", "a cervical mri scan", "a chest x ray", "a chest x-ray", "a chloride", "a ck", "a ck peak", "a co2", "a complete blood count", "a computerized axial tomography scan of his head", "a cosyntropin stimulation test", "a creatinine", "a ct scan", "a ct scan angiogram", "a ct scan of her abdomen", "a ct scan of your abdomen", "a ct scan with po contrast", "a ct-guided aspiration / biopsy at the l3-4 disc space", "a cta", "a culture", "a cxr", "a cystoscopy", "a d-dimer", "a delirium work-up", "a dental consultation", "a duplex evaluation of the right lower extremity", "a endocarditis work-up", "a follow up examination", "a hct", "a head and neck ct scan , non-contrast", "a head ct", "a head ct scan", "a head ultrasound", "a heart rate", "a hematocrit", "a heparin independent antibody", "a hida scan", "a hit panel", "a left kidney size", "a left ventricular ejection fraction", "a lipid panel", "a lumbar puncture", "a map", "a mean", "a mean gradient", "a mean ra pressure", "a mean wedge pressure", "a pa", "a panorex x-ray", "a peak ck mb", "a peak gradient", "a pelvic ultrasound", "a pharmacological stress test", "a platelet count", "a postoperative hematocrit", "a potassium", "a previous study", "a prior ct scan", "a pulse", "a rate", "apgars", "appear", "art", "art po2", "arterial blood gas", "asa", "asculation", "assessment of alignment", "assessment of the intraluminal process", "ast", "ast ( sgot", "ast(sgot)", "atyps", "augmented diastole", "auscultation", "auscultation bilaterally", "avr ,", "axial mdct images of the brain", "axial mdct images of the cervical spine", "axial noncontrast ct scans of the brain", "axis", "axr", "b/l le lenis", "b12", "bacteria", "bands", "bands .", "barbitr", "barbitrt", "base xs", "basic coagulation", "baso", "basos", "bcx", "bicarb", "bicarbonate", "bilateral le doppler", "bilateral leni 's", "bilateral lower extremeties", "bilirubin", "bilirubins", "biopsy", "birth weight", "birthweight", "blasts", "bld cx", "blood", "blood , urine , wound , and pleural fluid cultures", "blood , urine and sputum culutres", "blood alcohol level", "blood culture", "blood cultures", "blood cx", "blood gas", "blood gases", "blood heparin dependent antibodies", "blood levels", "blood pressure", "blood pressure.o.", "blood pressures", "blood pt", "blood type", "blood urea nitrogen", "blood wbc", "bnp", "bnzodzp", "bnzodzpn", "boston coma scale", "bowel sounds", "bp", "bps", "breath sounds", "breathing", "bronchoscopy", "bs", "bun", "c diff", "c. diff b", "c. diff b toxin", "ca", "calchct", "calcium", "calculated osmolality gap", "calhco3", "caltibc", "capillary refill", "car seat position screening", "car seat screening", "cardiac catheterization", "cardiac clearance", "cardiac enzymes", "cardiac exam", "cardiac examination", "cardiac index", "cardiac monitoring", "cardiac output", "cardiac size", "cardiovascular exam", "cardiovascular examination", "carotid ultrasound", "carotids", "cath", "catheterization", "catheterization results", "cbc", "cervical spine imaging", "chem-10", "chem-7", "chemistry", "chest ( pa & lat )", "chest ( portable ap )", "chest ct", "chest ct scan", "chest x ray", "chest x-ray", "chest x-rays", "chloride", "chol/hd", "cholangiogram", "cholangiopancreatography", "cholest", "cholesterol", "ciwa scale", "ck", "ck ( cpk )-", "ck - mb", "ck(cpk)", "ck-mb", "cl", "cl-", "close hemodynamic monitoring", "close monitoring", "closer observation", "cmed examination", "cnis", "co2", "cocaine", "cohgb", "colonoscopy", "colonscopy", "color", "color doppler", "complete blood count", "contiguous axial images", "contrast - enhanced mri of th ...
#
# treatment = ["", "02", "1 mg coumadin", "1 unit of platelets", "1 unit prbcs", "100% nonrebreather", "1l nc", "2 liters nasal cannula", "2 surgs.", "200 mg iv lasix", "2l ns", "2lnc", "2nd surgery", "3 cardiac surgeries", "3 fluid boluses", "3 u packed cells", "3-vessel percutaneous transluminal coronary angioplasty", "3l nc", "3l o2", "4 leather restraints", "4 surgeries", "4l nc", "4u ffp", "60%fm", "a #21 mosaic porcine valve", "a .................... graft", "a 1:1 sitter", "a 3-0 silk", "a 500 cc fluid bolus", "a 6 cuffless shiley", "a 8 week course of antibiotics", "a amiodarone gtt", "a back brace", "a barium swallow", "a beta blocker", "a beta elmore", "a bid protonix regimen", "a bioprosthetic aortic valve prosthesis", "a brat diet", "a cabg", "a calcium and glucagon drip", "a calcium gtt", "a cane", "a cardiac healthy , diabetic diet", "a cardiac stent", "a catheter", "a cerclage", "a cholecystectomy", "a clean dressing", "a coronary artery bypass graft", "a coronary artery bypass graft procedure", "a counselor", "a cystoscopy transurethral resection of prostate placement", "a dextran infusion", "a diet of thin liquids and soft solids", "a dopamine gtt", "a dry dressing", "a dual chamber pacemaker", "a figure-of-eight clavicular splint", "a foley catheter", "a foley catheterization", "a full sphincterectomy", "a gentle laxative", "a glucagon drip", "a hepacoat stent", "a hepaticojejunostomy", "a hinged mcdonald brace", "a joint procedure", "a k sparing diuretic", "a large volume paracentesis", "a lasix drip", "a lasix drip iv", "a lasix gtt", "a left groin venous sheath", "a left radial fracture open reduction", "a left thoracentesis", "a left upper extremity splint", "a lidocaine patch", "a low fat , low residue diet", "a low fat / low cholesterol diet", "a low fat no dairy diet", "a morphine drip", "a mucolytic component", "a nasogastric tube", "a neo-synephrine drip", "a net diuresis", "a neutropenic diet", "a new chemotherapy protocol", "a nicotine patch", "a nitro drip", "a non-rebreather", "a nonrebreather", "a normal saline bolus", "a nrb", "a paced rhythm", "a paracentesis", "a partial hd session", "a patient-controlled analgesia", "a pca", "a percutaneous sphincterotomy", "a picc", "a picc line", "a portocaval shunt", "a prescription for ten pills", "a regular insulin sliding scale", "a replacement of transhepatic biliary drainage catheter", "a right femoral arterial line", "a right groin a line", "a right internal jugular vascular catheter", "a side plate", "a similar immunosuppressive regimen", "a single lead pacemaker", "a single phototherapy", "a sliding scale", "a stat cesarean section", "a statin", "a stent", "a stent procedure to the rca", "a stool softener", "a super coronary arch graft", "a swan", "a swan catheter", "a swan-ganz", "a swan-ganz catheter", "a thoracentesis", "a thoracotomy", "a tissue valve", "a tp3a inhibitor", "a transdermal nicotine patch", "a transplant", "a two week course of diflucan", "a whipple procedure", "a wire", "a-paced", "abx", "ac", "ace inhibitor", "ace inhibitors", "ace-i", "acetaminophen", "activated charcoal", "activities of daily life", "acute management", "acyclovir", "adaptive training", "additional a fib control", "additional oxygen", "admission", "advance calorie density", "aeroseb", "aggrenox", "aggresive upper extremity elevation", "aggressive bp management", "aggressive diuresis", "aggressive hydration", "aggressive intravenous hydration", "aggressive physical therapy", "aggressively hydrated", "airway protection", "alb nebs", "albumin", "albuterol", "albuterol inhaler", "albuterol multiple dose inhalers", "albuterol nebulizer", "albuterol nebulizer treatments", "albuterol sulfate", "albuterol sulfate solution", "albuterol-ipratropium", "albuterol-ipratroprium", "alcohol treatment programs", "all antibiotics", "all hypertension medications", "all medications", "all sedating medications", "allevyn foam adhesive", "allograft", "alprazolam", "aluminum - magnesi ...
# """
#
# Clinical Text Input
# """
# ﻿Admission Date :
# 2012-10-31
# Discharge Date :
# 2012-11-07
# Date of Birth :
# 1941-03-23
# Sex :
# M
# Service :
# MEDICINE
# Allergies :
# Nsaids/Anti-Inflammatory Classifier / Vancomycin
# Attending :
# Kristie R. Hamby , M.D.
# Chief Complaint :
# CC : Antonio M. Z. Eddings , M.D.
# Major Surgical or Invasive Procedure :
# Mesenteric angiograpm w/ coil embolization of bleeding vessel .
# Sigmoidoscopy .
# Colonoscopy .
# History of Present Illness :
# HPI: Pt is a 71 y/o male with h/o dm2 , cad s/p cabg , DVT/PE on long term anti-coagulation , ulcerative colitis on Asacol presents with brbpr starting at 9am of the morning of admission .
# He 'd been having lower abdominal pain for approximately the past week , a symptom for which he 's been admitted in the past .
# His PCP had recently started ciprofloxacin for a UTI .
# At 9am the morning of admission he passed a large , bloody bowel movement and came to the Michael . There , his vitals were intially stable with a hct of 36.7 , though he was felt to be hypovolemic and this hemoconcentrated ; his previous hct was 39 about five months ago .
# He refused an NG lavage .
# Although an initial DRE showed only clot , he later passed a large , bloody bowel movement , and his bp nadired to the low 90's but rested there only transiently and easily rebounded to the 130's-140's with fluid ; he then went to angiography for a tagged RBC scan where they found and embolized two vessels to the sigmoid colon .
# His HCT had dropped from 36.7 to 30.8 despite 2U PRBC and 3 U FFP .
# Is called out of the FICU as has been been HD and stable HCT .
# Currently denies CP , SOB , abd pain or continued BRBPR .
# Past Medical History :
# PMH :
# 1.) DM-2
# 2.) CAD s/p 3v-CABG 2003 and subsequent stenting of SVG and LIMA
# 3.) CHF with EF 30-35% on 07-10 echo
# 4.) Right parietal intracranial bleeding following 1996 cardiac cath
# 5.) LBBB
# 6.) Sinus node dysfunction s/p pacemaker
# 7.) H/O DVT ( right sided ) and subsequent PE , put onto lifetime warfarin
# 8.) Ulcerative colitis
# PSH :
# 1.) C4-7 anterior discectomies
# 2.) CABG 2003
# 3.) R intracerebral hemorrhage drainage
# Social History :
# SocHx : Mr Peres generally lives with his wife but has spent a great deal of time recently at rehab .
# He has no h/o ETOH/IVDA but quit tob 15 years ago .
# Family History :
# Noncontributory .
# Physical Exam :
# VS 98.4 , 62 , 103/37 , 15 97%2L
# gen - lying in bed , NAD
# heent - anicteric sclera , op clear with mmm
# neck - jvd flat
# cv - rrr , s1s2 , no m/r/g
# pul - CTAB without rales
# abd - soft , minimally distended , nt , no rebound/guarding , nabs
# extrm - trace edema at ankles , no cyanosis , warm/dry
# Pertinent Results :
# 2012-10-31 05:47PM URINE
# COLOR - Straw APPEAR - Clear SP Marquez - 1.021
# 2012-10-31 05:47PM URINE
# BLOOD - LG NITRITE - NEG PROTEIN - NEG
# GLUCOSE - NEG KETONE - NEG BILIRUBIN - NEG UROBILNGN - NEG PH - 7.0 LEUK - NEG
# 2012-10-31 05:47PM URINE
# RBC-21-50* WBC-0-2 BACTERIA - FEW
# YEAST - NONE EPI - <1
# 2012-10-31 02:32PM
# LACTATE - 1.8
# 2012-10-31 12:20PM
# GLUCOSE - 197* UREA N-25* CREAT - 0.8 SODIUM - 141
# POTASSIUM - 3.7 CHLORIDE - 105 TOTAL CO2 - 22 ANION GAP - 18
# 2012-10-31 12:20PM
# WBC - 5.6 RBC - 4.35* HGB - 12.6* HCT - 36.7* MCV - 84
# MCH - 28.9 MCHC - 34.3 RDW - 15.7*
# 2012-10-31 12:20PM
# NEUTS - 80.5* LYMPHS - 13.1* MONOS - 3.5 EOS - 2.5
# BASOS - 0.4
# 2012-10-31 12:20PM
# POIKILOCY - 1+ MICROCYT - 1+
# 2012-10-31 12:20PM
# PLT COUNT - 102*
# 2012-10-31 12:20PM
# PT - 20.5* PTT - 29.4 INR(PT) - 3.0
# GI BLEEDING STUDY
# 2012-10-31
# IMPRESSION : Increased tracer activity demonstrated within the left lower quadrant , most likely sigmoid colonic loops of bowel , consistent with active bleeding .
# CT ABDOMEN W/CONTRAST
# 2012-10-31 3:27 PM
# IMPRESSION :
# 1. No evidence of colitis or other bowel pathology present to explain the patient 's bright red blood per rectum .
# 2. Stable appearance of left adrenal fat-containing lesion consistent with a myelolipoma .
# 3. Stable appearance of hypodense lesion within the caudate lobe of the liver , too small to fully characterize .
# 4. Subcentimeter attenuation lesion within the lower pole of the right kidney , too small to characterize .
# 5. 3-mm noncalcified pulmonary nodule within the right lower lobe .
# If the patient does not have a history of a primary malignancy , followup CT of the chest in 1 year is recommended to evaluate for stability of this finding .
# Brief Hospital Course :
# Initial A/P :
# 71 y/o male with dm2 , cad , chf , uc presents with one week of lower abdominal pain and 2 episodes of brpbr on the day of admission .
# # BRBPR -- The patient was in the intensive care unit given his lower GI bleed .
# An angiography showed bleeding in two vessels off of the Minnie supplying the sigmoid that were succesfully embolized .
# The patient was transfused from a Hct 29 to 34 on the day of discharge .
# His coumadin was held during his stay given his acute bleed but restarted per his PCP with the guidance of GI on the day of discharge .
# - The patient underwent a flex sigmoidoscopy on Friday , 11-02 , which showed old blood in the rectal vault but no active source of bleeding .
# Given this , it was advised that the patient have a colonoscopy to rule out further bleeding .
# - The patient had a colonoscopy on Monday 11-05 but unfortunately , was unable to complete the study as his bowel
# prep was inadequate .
# Therefore , he had a repeat colonoscopy on 11-06 which showed expected mucosal signs of moderate ulcerative colitis , no polyps , w/ 8 mm ulcer at junction of distal descending colon and sigmoid colon .
# - Biopsies were obtained during his colonoscopy and he should follow up with gastroenterology for the results .
# # Ulcerative colitis -- The patient 's Asacol was originally held but restarted the day prior to discharge per GI .
# # CAD/CHF - The patient was restarted on his home regimen prior to discharge as it was held temporarily given his acute GI bleed .
# The exception is that per his PCP , Jason aspirin will be held for 2 weeks given that he was restarted on coumadin with
# his risk of bleeding .
# # DM-2 -- The patient was maintained on his home insulin regimen .
# # h/o DVT/PE :
# Coumadin was initially held .
# It was unclear at first as to why the patient required life-long anticoagulation .
# After discussing this with his PCP , Leon was clear that the patient had had recurrent DVTs and ultimately a PE and his PCP felt strongly that he required long-term anticoagulation .
# His goal INR should be 1.6-2.0 . If bleeding continues to occur , consider V. Winchester filter .
# # Access -- 2 large bore PIV's
# # Code -- full
# Medications on Admission :
# Meds on Admission :
# 1.) Spironolactone/hctz 25/25 daily
# 2.) Atenolol 12.5mg daily
# 3.) Insulin 45N/8R qAM and 33N qPM
# 4.) Furosemide 10 mg every other day
# 5.) Aspirin 81 mg daily
# 6.) Zoloft 40 mg qAM
# 7.) Flomax
# 8.) Atorvastatin 40 mg daily
# 9.) Ritalin 20 mg daily
# 10.) Ramipril 2.5 mg daily
# 11.) Asacol 400 mg 3 , TID
# 12.) Carafate 1 gm bid
# 13.) Actos 15 mg daily
# 14.) Folate 1 mg daily
# 15.) Warfarin 2 mg daily
# Discharge Medications :
# 1. Tamsulosin 0.4 mg Capsule , Sust . Release 24HR Sig : One ( 1 ) Capsule , Sust . Release 24HR PO HS ( at bedtime ) .
# 2. Atorvastatin 40 mg Tablet Sig : One ( 1 ) Tablet PO DAILY ( Daily ) .
# 3. Methylphenidate 10 mg Tablet Sig : Two ( 2 ) Tablet PO DAILY ( Daily ) .
# 4. Acetaminophen 325 mg Tablet Sig : One ( 1 ) Tablet PO Q4-6H ( every 4 to 6 hours ) as needed .
# 5. Folic Acid 1 mg Tablet Sig : One ( 1 ) Tablet PO DAILY ( Daily ) .
# 6. Atenolol 25 mg Tablet Sig : 0.5 Tablet PO DAILY ( Daily ) .
# 7. Spironolactone 25 mg Tablet Sig : One ( 1 ) Tablet PO DAILY ( Daily ) .
# 8. Ramipril 1.25 mg Capsule Sig : Two ( 2 ) Capsule PO DAILY ( Daily ) .
# 9. Hydrochlorothiazide 25 mg Tablet Sig : One ( 1 ) Tablet PO DAILY ( Daily ) .
# 10. Pioglitazone 15 mg Tablet Sig : One ( 1 ) Tablet PO DAILY ( Daily ) as needed for DM .
# 11. Mesalamine 400 mg Tablet , Delayed Release ( E.C. ) Sig : Three ( 3 ) Tablet , Delayed Release ( E.C. ) PO TID ( 3 times a day ) as needed for ulcerative colitis w/o recent severe flares .
# 12. Insulin 45 NPH in am with 33 NPH at bedtime
# Continue Sliding scale insulin as needed .
# 13. Sertraline 20 mg/mL Concentrate Sig : Two ( 2 )  PO at bedtime .
# 14. Coumadin 2 mg Tablet Sig : One ( 1 ) Tablet PO once a day .
# Discharge Disposition :
# Extended Care
# Facility :
# Oak Bluffs Of Greenfield
# Discharge Diagnosis :
# Rectal bleeding from inferior mesenteric artery tributaries supplying sigmoid colon .
# Discharge Condition : Good .
# Discharge Instructions :
# Please call physician if you develop shortness of breath , weakness in your legs or arms , sudden blurry vision or slurred speech , chest pain , faintness , or significant unexplained weight loss .
# Followup Instructions :
# Provider : Lucio Y. Matthews , M.D. Phone : ( 967 ) 675 1641 Date/Time : 2012-12-28 2:30
# Provider :  Greg CLINIC Phone : ( 212 ) 442 0438 Date/Time : 2013-01-11 1:30
# Provider : Lucio F. R. Matthews , M.D. Phone : ( 967 ) 675 1641 Date/Time : 2013-01-11 2:00
# Please call White , Leslie L. at ( 602 ) 743 8709 to schedule an appointment with him in 1 week .
# Please call your gastroenterologist to schedule a follow up appointment in 2 weeks .
# Alan John MD 54-745
# Completed by : Bertha Janice Motta MD 52-860 2012-11-07 @ 1207
# Signed electronically by : DR. Melody PARKS on: WED 2012-11-21 6:22 PM
# ( End of Report )
# """

# %% [markdown]
# Prompt: Entity Unseen

# %%
from pathlib import Path

# Path to the sample training file
sample_file_path = Path("../Data/processed/llm/entity_only/train/all_entities_but_test_0001_small.txt")

# Read and wrap with triple quotes
with open(sample_file_path, "r", encoding="utf-8") as f:
    all_entity_list_but_test = f.read().strip()

# print(all_entity_list)

# Define meaningful prompt parts
instruction = (
    "Your task is to extract entities from clinical text and categorize them into predefined labels "
    "based on their role in medical documentation."
)

source_info = (
    "The source text comes from Electronic Health Records (EHRs), which are digital versions of patients' medical histories, "
    "including diagnoses, medications, procedures, lab results, and physician notes."
)

category_definition = (
    "Entity Categories\n"
    "Each extracted entity should be classified into one of the following categories:\n"
    "Test: A diagnostic procedure, lab test, or medical examination performed to investigate or reveal a medical condition.\n"
    "Examples:\n"
    "entity=\"colonoscopy\" label=\"test\"\n"
    "entity=\"MRI scan\" label=\"test\"\n"
    "entity=\"blood glucose test\" label=\"test\"\n\n"
    "Treatment: A medication, procedure, or intervention administered to manage, improve, or prevent a medical problem.\n"
    "Examples:\n"
    "entity=\"ramipril\" label=\"treatment\"\n"
    "entity=\"chemotherapy\" label=\"treatment\"\n"
    "entity=\"insulin therapy\" label=\"treatment\"\n\n"
    "Problem: A medical condition, symptom, or diagnosis affecting a patient, which may require testing or treatment.\n"
    "Examples:\n"
    "entity=\"diabetes mellitus\" label=\"problem\"\n"
    "entity=\"chest pain\" label=\"problem\"\n"
    "entity=\"hypertension\" label=\"problem\""
)

output_format = (
    "Expected Output Format\n"
    "Entities should be extracted and presented in the following format:\n"
    "entity=\"<extracted medical entity>\" label=\"<assigned category>\""
)

uncertain_handling = (
    "Handling Uncertain Cases\n"
    "If an entity cannot be clearly classified as test, treatment, or problem based on the information provided, "
    "label it as:\n"
    "entity=\"<extracted medical entity>\" label=\"unknown\""
)

sample_training_entity_all_but_test = (
    "Sample Training Entities\n"
    "You will be given a list of sample entities enclosed within triple quotes (\"\"\" \"\"\"). "
    "You will find the list of test, treatment, and problem entities.\n\n"
    "These examples serve as a training guide and should help the system understand how medical terms are categorized based on their role in clinical documentation.\n"
    "You should use these examples to infer how to extract and label entities from the testing clinical text.\n\n"
    "Below is the list of training entities enclosed into square bracket. Each entity is comma separated.\n"
    f"\"\"\"\n{all_entity_list_but_test}\n\"\"\""
)

triple_quote_note = (
    "Clinical Text Input\n"
    "Below, you will be given a clinical text document enclosed within triple quotes (\"\"\" \"\"\"). "
    "Your task is to extract relevant medical entities and assign them the appropriate labels based on the definitions provided above."
)

# Format with triple quotes
clinical_text = f'""" \n{clinical_text_content}\n"""'

# Combine all into one prompt
full_prompt = "\n\n".join([
    instruction,
    source_info,
    category_definition,
    output_format,
    uncertain_handling,
    triple_quote_note,
    sample_training_entity_all_but_test, 
    f"Clinical Text Input\n{clinical_text}"  # ← actual test input
])



print(full_prompt)
# Out:
# Your task is to extract entities from clinical text and categorize them into predefined labels based on their role in medical documentation.
#
# The source text comes from Electronic Health Records (EHRs), which are digital versions of patients' medical histories, including diagnoses, medications, procedures, lab results, and physician notes.
#
# Entity Categories
# Each extracted entity should be classified into one of the following categories:
# Test: A diagnostic procedure, lab test, or medical examination performed to investigate or reveal a medical condition.
# Examples:
# entity="colonoscopy" label="test"
# entity="MRI scan" label="test"
# entity="blood glucose test" label="test"
#
# Treatment: A medication, procedure, or intervention administered to manage, improve, or prevent a medical problem.
# Examples:
# entity="ramipril" label="treatment"
# entity="chemotherapy" label="treatment"
# entity="insulin therapy" label="treatment"
#
# Problem: A medical condition, symptom, or diagnosis affecting a patient, which may require testing or treatment.
# Examples:
# entity="diabetes mellitus" label="problem"
# entity="chest pain" label="problem"
# entity="hypertension" label="problem"
#
# Expected Output Format
# Entities should be extracted and presented in the following format:
# entity="<extracted medical entity>" label="<assigned category>"
#
# Handling Uncertain Cases
# If an entity cannot be clearly classified as test, treatment, or problem based on the information provided, label it as:
# entity="<extracted medical entity>" label="unknown"
#
# Clinical Text Input
# Below, you will be given a clinical text document enclosed within triple quotes (""" """). Your task is to extract relevant medical entities and assign them the appropriate labels based on the definitions provided above.
#
# Sample Training Entities
# You will be given a list of sample entities enclosed within triple quotes (""" """). You will find the list of test, treatment, and problem entities.
#
# These examples serve as a training guide and should help the system understand how medical terms are categorized based on their role in clinical documentation.
# You should use these examples to infer how to extract and label entities from the testing clinical text.
#
# Below is the list of training entities enclosed into square bracket. Each entity is comma separated.
# """
# problem = ["+ blood cultures", "+distension", "+loc", "+s3", "02 requirement", "1+ edema bilaterally", "1+ le edema", "1+ lower extremity edema", "1+ mitral regurgitation", "1-vessel disease", "10/10 substernal chest pain", "100% occlusion of the proximal left anterior descending artery", "11% bandemia", "1st deg block", "2 vessel cord", "2+ edema both upper extremities", "2+ pitting edema bilateral le", "2+ pitting edema to knees b/l", "2-pillow orthopnea", "2/6 systolic murmur at lusb", "2/6 systolic murmur radiating to axilla", "3+ tricuspid regurgitation", "3/6 systolic ejection murmur", "4 mm left upper lobe lung nodule", "5 cm circular full thickness defect", "5 cores of varices", "50% stenosis d1", "50% stenosis of first diagonal", "60-69% stenosis of the right internal carotid artery", "70% stenoses of the left circumflex and oblique marginal artery", "80 percent mid lad lesion", "80% lm lesion", "80% stenosis of the mid left anterior descending", "80-99% stenosis of the left internal carotid artery", "90% stenosis of the posterior descending artery", "99% stenosis", "a 1-2/6 holosystolic murmur", "a 1.5 cm diameter hyperdense mass in the pons", "a 1.8 cm exophytic renal cyst", "a 10 pound weight gain", "a 3 cm laceration in the lower leg", "a 5 cm laceration", "a 90% lesion", "a 95% stenosis", "a bacterial pna", "a band-like opacity in the left lower lobe", "a bandemia", "a baseline renal insufficiency", "a bile leak", "a bile leak at the duct of luschka", "a bile leak from the duct of luschka", "a bleed from femoral access site", "a bleeding source in your colon", "a breech presentation", "a change in mental status", "a chf exacerbation", "a chronic problem", "a clot", "a coloboma", "a colovesicular fistula", "a complex plaque", "a complication", "a confirmatory elevation", "a cystic lesion", "a decreased and sluggish flow within the right and left hepatic veins", "a definitive epidural abscess", "a depressed respiratory drive", "a dilated aortic root", "a dilated common bile duct", "a distal stricture of the common bile duct", "a documented alpha streptococcal septicemia", "a dry cough", "a fever", "a fib", "a forming pseudocyst", "a fracture of the proximal right humerus", "a headache", "a hematoma", "a high co", "a hip and arm fracture", "a iii/vi systolic ejection murmur", "a keyhole appearance", "a large omental mass", "a large pericardial effusion", "a large right and small left pleural effusion", "a larger cystic lesion in the tail of the pancreas", "a leak from relaford pouch", "a left clavicular deformity", "a left facial mass", "a left frontal headache", "a left humeral fracuture", "a left occipital scalp contusion", "a left pleural effusion", "a left shoulder fracture", "a linear nondepressed right temporal calvarial fracture", "a linear right temporal calvarial fracture", "a little bit icteric", "a little bit out of it", "a long lad lesion", "a long nipple like papilla", "a low hct", "a mass in the right pelvis", "a mechanical fall", "a meniscal tear", "a mid rca lesion of 80-90%", "a mild cough", "a mild left pronator drift", "a mildly dilated ascending aorta", "a mildly dilated left atrium", "a mildly widened right palpable fissure", "a minor stepoff", "a moderately dilated aortic root", "a more pervasive process", "a multifocal pneumonic process", "a murmur", "a myocardial infarction", "a new fever", "a new humerus fracture distal to the hardware", "a non specific dysfunction in midline structures", "a non-displaced comminuted fracture of the proximal fibular diaphysis", "a non-q wave myocardial infarction", "a non-st elevation mi", "a partial biliary obstruction", "a patchy area of increased opacity", "a pea arrest", "a pelvic fracture", "a persistent acidemia", "a persistent cough", "a persistent flow", "a pins and needle feeling in the face , hands and feet bilaterally", "a pna", "a pneumonia", "a positive exercise tolerance test", "a posterior scalp laceration", "a preexisting alkalosis", "a preren ...
#
#
# test = ["2 echocardiograms", "2+ dp pulses bilaterally", "2+ femoral pulses", "25 polys", "2d", "a b/l creatinine", "a bedside echocardiogram", "a bedside transthoracic echocardiogram", "a blood culture", "a bnp", "a bone biopsy", "a car seat positioning test", "a cardiac cath", "a cardiac catheterization", "a cardiac output index", "a cardiopulmonary monitor", "a cbc", "a cervical mri scan", "a chest x ray", "a chest x-ray", "a chloride", "a ck", "a ck peak", "a co2", "a complete blood count", "a computerized axial tomography scan of his head", "a cosyntropin stimulation test", "a creatinine", "a ct scan", "a ct scan angiogram", "a ct scan of her abdomen", "a ct scan of your abdomen", "a ct scan with po contrast", "a ct-guided aspiration / biopsy at the l3-4 disc space", "a cta", "a culture", "a cxr", "a cystoscopy", "a d-dimer", "a delirium work-up", "a dental consultation", "a duplex evaluation of the right lower extremity", "a endocarditis work-up", "a follow up examination", "a head and neck ct scan , non-contrast", "a head ct", "a head ct scan", "a head ultrasound", "a heart rate", "a hematocrit", "a heparin independent antibody", "a hida scan", "a hit panel", "a left kidney size", "a left ventricular ejection fraction", "a lipid panel", "a lumbar puncture", "a map", "a mean", "a mean gradient", "a mean ra pressure", "a mean wedge pressure", "a pa", "a panorex x-ray", "a peak ck mb", "a peak gradient", "a pelvic ultrasound", "a pharmacological stress test", "a platelet count", "a postoperative hematocrit", "a potassium", "a previous study", "a prior ct scan", "a pulse", "a rate", "a rebound bilirubin level", "a recent catheterization", "a relook catheterization", "a renal consultation", "a renal ultrasound", "a repeat ct", "a repeat ct scan", "a repeat head ct scan", "a repeat mri", "a repeat outpatient ct colonoscopy", "a right kidney size", "a right sided thoracentesis", "a right upper quadrant ultrasound", "a serum bilirubin", "a signal-averaged ekg", "a sodium", "a staging ct scan torso", "a strong doppler signal", "a successful endoscopic retrograde cholangiopancreatography", "a sugar", "a swan", "a systolic blood pressure", "a tee", "a temperature", "a therapeudic inr", "a thoracentesis", "a total co2", "a total white count", "a transesophageal echocardiogram", "a transthoracic echocardiogram", "a troponin", "a tte", "a ultrasound", "a urine culture", "a video swallow", "a weight", "a white blood cell count", "a white count", "aado2", "abd ct", "abdominal ct", "abdominal ct scan of the abdomen", "abdominal exam", "abdominal examination", "abg", "abnormal liver function tests", "ac", "acetmnp", "acetmnphn", "acid fast culture", "admission examination", "admission pe", "afterload", "air-fluid levels", "airway monitoring", "albumin", "alk phos", "alk phos is", "alkaline phosphatase", "alkphos", "all culture data", "all cultures", "alt", "alt ( sgpt )-", "alt(sgpt)", "ammonia", "amniocentesis", "amphetmn", "amylase", "an abdomen and pelvis ct", "an abdominal ct", "an abdominal ultrasound", "an abg", "an alt", "an angiogram", "an aortic valve area", "an attempted ercp", "an av surface area", "an ecg", "an echo", "an echocardiogram", "an eeg", "an ejection fraction", "an endoscopic retrograde cholangiopancreatography", "an endoscopic retrogram cholangiopancreatography", "an ep evaluation", "an ercp", "an immediate head ct", "an lf ef", "an lp", "an lvedp", "an magnetic resonance cholangiopancreatography", "an mrcp", "an mri", "an mri of the knee", "an obtainable wedge pressure", "an outpatient gi workup", "an outpatient thrombophilia work-up", "an outside study", "an oxygen saturation", "an ra pressure", "an ultrasound", "an ultrasound guided biopsy", "an ultrasound of the right upper quadrant", "an xray of the l femur", "angap", "angap -", "anisocy", "anisocyt", "another echo", "antibody", "ap and lateral compression", "ap s", "apgar scores", "apgars", "art", "art po2", "arterial blood gas", "asa", "asculation", "assess ...
#
#
# treatment = ["", "02", "1 mg coumadin", "1 unit of platelets", "1 unit prbcs", "100% nonrebreather", "1l nc", "2 liters nasal cannula", "2 surgs.", "200 mg iv lasix", "2l ns", "2lnc", "2nd surgery", "3 cardiac surgeries", "3 fluid boluses", "3 u packed cells", "3-vessel percutaneous transluminal coronary angioplasty", "3l nc", "3l o2", "4 leather restraints", "4 surgeries", "4l nc", "4u ffp", "60%fm", "a #21 mosaic porcine valve", "a .................... graft", "a 1:1 sitter", "a 3-0 silk", "a 500 cc fluid bolus", "a 6 cuffless shiley", "a 8 week course of antibiotics", "a amiodarone gtt", "a back brace", "a barium swallow", "a beta blocker", "a beta elmore", "a bid protonix regimen", "a bioprosthetic aortic valve prosthesis", "a brat diet", "a cabg", "a calcium and glucagon drip", "a calcium gtt", "a cane", "a cardiac healthy , diabetic diet", "a cardiac stent", "a catheter", "a cerclage", "a cholecystectomy", "a clean dressing", "a coronary artery bypass graft", "a coronary artery bypass graft procedure", "a counselor", "a cystoscopy transurethral resection of prostate placement", "a dextran infusion", "a diet of thin liquids and soft solids", "a dopamine gtt", "a dry dressing", "a dual chamber pacemaker", "a figure-of-eight clavicular splint", "a foley catheter", "a foley catheterization", "a full sphincterectomy", "a gentle laxative", "a glucagon drip", "a hepacoat stent", "a hepaticojejunostomy", "a hinged mcdonald brace", "a joint procedure", "a k sparing diuretic", "a large volume paracentesis", "a lasix drip", "a lasix drip iv", "a lasix gtt", "a left groin venous sheath", "a left radial fracture open reduction", "a left thoracentesis", "a left upper extremity splint", "a lidocaine patch", "a low fat , low residue diet", "a low fat / low cholesterol diet", "a low fat no dairy diet", "a morphine drip", "a mucolytic component", "a nasogastric tube", "a neo-synephrine drip", "a net diuresis", "a neutropenic diet", "a new chemotherapy protocol", "a nicotine patch", "a nitro drip", "a non-rebreather", "a nonrebreather", "a normal saline bolus", "a nrb", "a paced rhythm", "a paracentesis", "a partial hd session", "a patient-controlled analgesia", "a pca", "a percutaneous sphincterotomy", "a picc", "a picc line", "a portocaval shunt", "a prescription for ten pills", "a regular insulin sliding scale", "a replacement of transhepatic biliary drainage catheter", "a right femoral arterial line", "a right groin a line", "a right internal jugular vascular catheter", "a side plate", "a similar immunosuppressive regimen", "a single lead pacemaker", "a single phototherapy", "a sliding scale", "a stat cesarean section", "a statin", "a stent", "a stent procedure to the rca", "a stool softener", "a super coronary arch graft", "a swan", "a swan catheter", "a swan-ganz", "a swan-ganz catheter", "a thoracentesis", "a thoracotomy", "a tissue valve", "a tp3a inhibitor", "a transdermal nicotine patch", "a transplant", "a two week course of diflucan", "a whipple procedure", "a wire", "a-paced", "abx", "ac", "ace inhibitor", "ace inhibitors", "ace-i", "activated charcoal", "activities of daily life", "acute management", "acyclovir", "adaptive training", "additional a fib control", "additional oxygen", "admission", "advance calorie density", "aeroseb", "aggrenox", "aggresive upper extremity elevation", "aggressive bp management", "aggressive diuresis", "aggressive hydration", "aggressive intravenous hydration", "aggressive physical therapy", "aggressively hydrated", "airway protection", "alb nebs", "albumin", "albuterol", "albuterol inhaler", "albuterol multiple dose inhalers", "albuterol nebulizer", "albuterol nebulizer treatments", "albuterol sulfate", "albuterol sulfate solution", "albuterol-ipratropium", "albuterol-ipratroprium", "alcohol treatment programs", "all antibiotics", "all hypertension medications", "all medications", "all sedating medications", "allevyn foam adhesive", "allograft", "alprazolam", "aluminum - magnesium hydroxide", "a ...
# """
#
# Clinical Text Input
# """
# ﻿Admission Date :
# 2012-10-31
# Discharge Date :
# 2012-11-07
# Date of Birth :
# 1941-03-23
# Sex :
# M
# Service :
# MEDICINE
# Allergies :
# Nsaids/Anti-Inflammatory Classifier / Vancomycin
# Attending :
# Kristie R. Hamby , M.D.
# Chief Complaint :
# CC : Antonio M. Z. Eddings , M.D.
# Major Surgical or Invasive Procedure :
# Mesenteric angiograpm w/ coil embolization of bleeding vessel .
# Sigmoidoscopy .
# Colonoscopy .
# History of Present Illness :
# HPI: Pt is a 71 y/o male with h/o dm2 , cad s/p cabg , DVT/PE on long term anti-coagulation , ulcerative colitis on Asacol presents with brbpr starting at 9am of the morning of admission .
# He 'd been having lower abdominal pain for approximately the past week , a symptom for which he 's been admitted in the past .
# His PCP had recently started ciprofloxacin for a UTI .
# At 9am the morning of admission he passed a large , bloody bowel movement and came to the Michael . There , his vitals were intially stable with a hct of 36.7 , though he was felt to be hypovolemic and this hemoconcentrated ; his previous hct was 39 about five months ago .
# He refused an NG lavage .
# Although an initial DRE showed only clot , he later passed a large , bloody bowel movement , and his bp nadired to the low 90's but rested there only transiently and easily rebounded to the 130's-140's with fluid ; he then went to angiography for a tagged RBC scan where they found and embolized two vessels to the sigmoid colon .
# His HCT had dropped from 36.7 to 30.8 despite 2U PRBC and 3 U FFP .
# Is called out of the FICU as has been been HD and stable HCT .
# Currently denies CP , SOB , abd pain or continued BRBPR .
# Past Medical History :
# PMH :
# 1.) DM-2
# 2.) CAD s/p 3v-CABG 2003 and subsequent stenting of SVG and LIMA
# 3.) CHF with EF 30-35% on 07-10 echo
# 4.) Right parietal intracranial bleeding following 1996 cardiac cath
# 5.) LBBB
# 6.) Sinus node dysfunction s/p pacemaker
# 7.) H/O DVT ( right sided ) and subsequent PE , put onto lifetime warfarin
# 8.) Ulcerative colitis
# PSH :
# 1.) C4-7 anterior discectomies
# 2.) CABG 2003
# 3.) R intracerebral hemorrhage drainage
# Social History :
# SocHx : Mr Peres generally lives with his wife but has spent a great deal of time recently at rehab .
# He has no h/o ETOH/IVDA but quit tob 15 years ago .
# Family History :
# Noncontributory .
# Physical Exam :
# VS 98.4 , 62 , 103/37 , 15 97%2L
# gen - lying in bed , NAD
# heent - anicteric sclera , op clear with mmm
# neck - jvd flat
# cv - rrr , s1s2 , no m/r/g
# pul - CTAB without rales
# abd - soft , minimally distended , nt , no rebound/guarding , nabs
# extrm - trace edema at ankles , no cyanosis , warm/dry
# Pertinent Results :
# 2012-10-31 05:47PM URINE
# COLOR - Straw APPEAR - Clear SP Marquez - 1.021
# 2012-10-31 05:47PM URINE
# BLOOD - LG NITRITE - NEG PROTEIN - NEG
# GLUCOSE - NEG KETONE - NEG BILIRUBIN - NEG UROBILNGN - NEG PH - 7.0 LEUK - NEG
# 2012-10-31 05:47PM URINE
# RBC-21-50* WBC-0-2 BACTERIA - FEW
# YEAST - NONE EPI - <1
# 2012-10-31 02:32PM
# LACTATE - 1.8
# 2012-10-31 12:20PM
# GLUCOSE - 197* UREA N-25* CREAT - 0.8 SODIUM - 141
# POTASSIUM - 3.7 CHLORIDE - 105 TOTAL CO2 - 22 ANION GAP - 18
# 2012-10-31 12:20PM
# WBC - 5.6 RBC - 4.35* HGB - 12.6* HCT - 36.7* MCV - 84
# MCH - 28.9 MCHC - 34.3 RDW - 15.7*
# 2012-10-31 12:20PM
# NEUTS - 80.5* LYMPHS - 13.1* MONOS - 3.5 EOS - 2.5
# BASOS - 0.4
# 2012-10-31 12:20PM
# POIKILOCY - 1+ MICROCYT - 1+
# 2012-10-31 12:20PM
# PLT COUNT - 102*
# 2012-10-31 12:20PM
# PT - 20.5* PTT - 29.4 INR(PT) - 3.0
# GI BLEEDING STUDY
# 2012-10-31
# IMPRESSION : Increased tracer activity demonstrated within the left lower quadrant , most likely sigmoid colonic loops of bowel , consistent with active bleeding .
# CT ABDOMEN W/CONTRAST
# 2012-10-31 3:27 PM
# IMPRESSION :
# 1. No evidence of colitis or other bowel pathology present to explain the patient 's bright red blood per rectum .
# 2. Stable appearance of left adrenal fat-containing lesion consistent with a myelolipoma .
# 3. Stable appearance of hypodense lesion within the caudate lobe of the liver , too small to fully characterize .
# 4. Subcentimeter attenuation lesion within the lower pole of the right kidney , too small to characterize .
# 5. 3-mm noncalcified pulmonary nodule within the right lower lobe .
# If the patient does not have a history of a primary malignancy , followup CT of the chest in 1 year is recommended to evaluate for stability of this finding .
# Brief Hospital Course :
# Initial A/P :
# 71 y/o male with dm2 , cad , chf , uc presents with one week of lower abdominal pain and 2 episodes of brpbr on the day of admission .
# # BRBPR -- The patient was in the intensive care unit given his lower GI bleed .
# An angiography showed bleeding in two vessels off of the Minnie supplying the sigmoid that were succesfully embolized .
# The patient was transfused from a Hct 29 to 34 on the day of discharge .
# His coumadin was held during his stay given his acute bleed but restarted per his PCP with the guidance of GI on the day of discharge .
# - The patient underwent a flex sigmoidoscopy on Friday , 11-02 , which showed old blood in the rectal vault but no active source of bleeding .
# Given this , it was advised that the patient have a colonoscopy to rule out further bleeding .
# - The patient had a colonoscopy on Monday 11-05 but unfortunately , was unable to complete the study as his bowel
# prep was inadequate .
# Therefore , he had a repeat colonoscopy on 11-06 which showed expected mucosal signs of moderate ulcerative colitis , no polyps , w/ 8 mm ulcer at junction of distal descending colon and sigmoid colon .
# - Biopsies were obtained during his colonoscopy and he should follow up with gastroenterology for the results .
# # Ulcerative colitis -- The patient 's Asacol was originally held but restarted the day prior to discharge per GI .
# # CAD/CHF - The patient was restarted on his home regimen prior to discharge as it was held temporarily given his acute GI bleed .
# The exception is that per his PCP , Jason aspirin will be held for 2 weeks given that he was restarted on coumadin with
# his risk of bleeding .
# # DM-2 -- The patient was maintained on his home insulin regimen .
# # h/o DVT/PE :
# Coumadin was initially held .
# It was unclear at first as to why the patient required life-long anticoagulation .
# After discussing this with his PCP , Leon was clear that the patient had had recurrent DVTs and ultimately a PE and his PCP felt strongly that he required long-term anticoagulation .
# His goal INR should be 1.6-2.0 . If bleeding continues to occur , consider V. Winchester filter .
# # Access -- 2 large bore PIV's
# # Code -- full
# Medications on Admission :
# Meds on Admission :
# 1.) Spironolactone/hctz 25/25 daily
# 2.) Atenolol 12.5mg daily
# 3.) Insulin 45N/8R qAM and 33N qPM
# 4.) Furosemide 10 mg every other day
# 5.) Aspirin 81 mg daily
# 6.) Zoloft 40 mg qAM
# 7.) Flomax
# 8.) Atorvastatin 40 mg daily
# 9.) Ritalin 20 mg daily
# 10.) Ramipril 2.5 mg daily
# 11.) Asacol 400 mg 3 , TID
# 12.) Carafate 1 gm bid
# 13.) Actos 15 mg daily
# 14.) Folate 1 mg daily
# 15.) Warfarin 2 mg daily
# Discharge Medications :
# 1. Tamsulosin 0.4 mg Capsule , Sust . Release 24HR Sig : One ( 1 ) Capsule , Sust . Release 24HR PO HS ( at bedtime ) .
# 2. Atorvastatin 40 mg Tablet Sig : One ( 1 ) Tablet PO DAILY ( Daily ) .
# 3. Methylphenidate 10 mg Tablet Sig : Two ( 2 ) Tablet PO DAILY ( Daily ) .
# 4. Acetaminophen 325 mg Tablet Sig : One ( 1 ) Tablet PO Q4-6H ( every 4 to 6 hours ) as needed .
# 5. Folic Acid 1 mg Tablet Sig : One ( 1 ) Tablet PO DAILY ( Daily ) .
# 6. Atenolol 25 mg Tablet Sig : 0.5 Tablet PO DAILY ( Daily ) .
# 7. Spironolactone 25 mg Tablet Sig : One ( 1 ) Tablet PO DAILY ( Daily ) .
# 8. Ramipril 1.25 mg Capsule Sig : Two ( 2 ) Capsule PO DAILY ( Daily ) .
# 9. Hydrochlorothiazide 25 mg Tablet Sig : One ( 1 ) Tablet PO DAILY ( Daily ) .
# 10. Pioglitazone 15 mg Tablet Sig : One ( 1 ) Tablet PO DAILY ( Daily ) as needed for DM .
# 11. Mesalamine 400 mg Tablet , Delayed Release ( E.C. ) Sig : Three ( 3 ) Tablet , Delayed Release ( E.C. ) PO TID ( 3 times a day ) as needed for ulcerative colitis w/o recent severe flares .
# 12. Insulin 45 NPH in am with 33 NPH at bedtime
# Continue Sliding scale insulin as needed .
# 13. Sertraline 20 mg/mL Concentrate Sig : Two ( 2 )  PO at bedtime .
# 14. Coumadin 2 mg Tablet Sig : One ( 1 ) Tablet PO once a day .
# Discharge Disposition :
# Extended Care
# Facility :
# Oak Bluffs Of Greenfield
# Discharge Diagnosis :
# Rectal bleeding from inferior mesenteric artery tributaries supplying sigmoid colon .
# Discharge Condition : Good .
# Discharge Instructions :
# Please call physician if you develop shortness of breath , weakness in your legs or arms , sudden blurry vision or slurred speech , chest pain , faintness , or significant unexplained weight loss .
# Followup Instructions :
# Provider : Lucio Y. Matthews , M.D. Phone : ( 967 ) 675 1641 Date/Time : 2012-12-28 2:30
# Provider :  Greg CLINIC Phone : ( 212 ) 442 0438 Date/Time : 2013-01-11 1:30
# Provider : Lucio F. R. Matthews , M.D. Phone : ( 967 ) 675 1641 Date/Time : 2013-01-11 2:00
# Please call White , Leslie L. at ( 602 ) 743 8709 to schedule an appointment with him in 1 week .
# Please call your gastroenterologist to schedule a follow up appointment in 2 weeks .
# Alan John MD 54-745
# Completed by : Bertha Janice Motta MD 52-860 2012-11-07 @ 1207
# Signed electronically by : DR. Melody PARKS on: WED 2012-11-21 6:22 PM
# ( End of Report )
# """

# %% [markdown]
# Generic code for all prompts. Only change the output_file_name

# %%
output_dir = Path("../Results/test/GPT/")
output_file_name = "0001_zeroshot_2.txt"
predicted_file = output_dir / output_file_name

# %%
import requests
import time

# Replace with your actual OpenAI API key
api_key = "Your API Key"

# OpenAI Chat API URL
api_url = "https://api.openai.com/v1/chat/completions"
headers = {
    "Authorization": f"Bearer {api_key}",
    "Content-Type": "application/json"
}

data = {
    "model": "gpt-4o",  
    "messages": [
        {"role": "system", "content": "You are a clinical information extractor."},
        {"role": "user", "content": full_prompt}
    ],
    "temperature": 0.3,
    "top_p": 1.0
}

# %%
# Start timer
start_time = time.time()

# Send request
response = requests.post(api_url, headers=headers, json=data)

# End timer
end_time = time.time()
response_time = end_time - start_time
print(f"Response time: {response_time:.2f} seconds")

# Parse and save response
output_text = response.json()['choices'][0]['message']['content']

# Save to a text file
with open(predicted_file, "w", encoding="utf-8") as f:
    f.write(output_text)

print("Output saved to:", predicted_file)
# Out:
# Response time: 5.72 seconds
# Output saved to: ..\Results\test\GPT\0001_zeroshot_2.txt

# %%
'''
{
    "error": {
        "message": "Request too large for gpt-4o in organization org-eHMc6WjJvjEtKB4cX7h6RyoU on tokens per min (TPM): Limit 30000, Requested 31582. The input or output tokens must be reduced in order to run successfully. Visit https://platform.openai.com/account/rate-limits to learn more.",
        "type": "tokens",
        "param": null,
        "code": "rate_limit_exceeded"
    }
}
'''
# Out:
# '\n{\n    "error": {\n        "message": "Request too large for gpt-4o in organization org-eHMc6WjJvjEtKB4cX7h6RyoU on tokens per min (TPM): Limit 30000, Requested 31582. The input or output tokens must be reduced in order to run successfully. Visit https://platform.openai.com/account/rate-limits to learn more.",\n        "type": "tokens",\n        "param": null,\n        "code": "rate_limit_exceeded"\n    }\n}\n'

# %%
pip install nltk
# Out:
# Collecting nltk
#   Using cached nltk-3.9.1-py3-none-any.whl.metadata (2.9 kB)
# Collecting click (from nltk)
#   Using cached click-8.1.8-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: joblib in c:\users\nipua\appdata\local\anaconda3\envs\ner\lib\site-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\nipua\appdata\local\anaconda3\envs\ner\lib\site-packages (from nltk) (2024.11.6)
# Requirement already satisfied: tqdm in c:\users\nipua\appdata\local\anaconda3\envs\ner\lib\site-packages (from nltk) (4.67.1)
# Requirement already satisfied: colorama in c:\users\nipua\appdata\local\anaconda3\envs\ner\lib\site-packages (from click->nltk) (0.4.6)
# Using cached nltk-3.9.1-py3-none-any.whl (1.5 MB)
# Using cached click-8.1.8-py3-none-any.whl (98 kB)
# Installing collected packages: click, nltk
# Successfully installed click-8.1.8 nltk-3.9.1
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Code to generate random 100 sentences from the first five documents

# %%
import os
import random
import nltk
from pathlib import Path

# Make sure you have punkt tokenizer
nltk.download('punkt')
from nltk.tokenize import sent_tokenize

def sample_sentences_from_files(input_dir, output_file, sample_size=100):
    all_sentences = []
    
    # Get first five files (sorted for consistency)
    files = sorted(os.listdir(input_dir))[:5]
    
    for fname in files:
        fpath = os.path.join(input_dir, fname)
        if os.path.isfile(fpath):
            with open(fpath, 'r', encoding='utf-8') as f:
                text = f.read()
                sentences = sent_tokenize(text)
                all_sentences.extend(sentences)

    # Randomly sample 100 sentences
    sampled_sentences = random.sample(all_sentences, min(sample_size, len(all_sentences)))

    # Save to output file
    with open(output_file, 'w', encoding='utf-8') as out:
        for sentence in sampled_sentences:
            out.write(sentence.strip() + "\n")

input_dir = Path("../Data/processed/llm/tag_sentences/train")
output_file_name = "random_100_sentences.txt"
output_file = input_dir / output_file_name
# Example usage
sample_sentences_from_files(input_dir, output_file)
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\nipua\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
